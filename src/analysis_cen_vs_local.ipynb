# %%
import numpy as np
import pandas as pd


from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns

from psql_functions import execQuery
from miss_data import add_missing_dates, add_missing_counts
from make_plots import dict_error_plot_epsilons, dict_error_plot_n

import warnings
warnings.filterwarnings('ignore')

import sys
import os
import re
owd = os.getcwd()

# %%
param_dic = {
    "host"      : "localhost",
    "database"  : "bachelorBesoeg2014",
    "user"      : "postgres",
    "password"  : "password",
    "port"      : "5432"
}

query = """select time_ from _775147;"""
result = execQuery(param_dic, query)
dates = [(date[0]) for date in result]

query = """select count_ from _775147;"""
result = execQuery(param_dic, query)

counts = [(count[0]) for count in result]

all_dates = add_missing_dates(dates)
all_counts =  add_missing_counts(counts, dates, all_dates)
# Out:
# Executed query and closed connection.
# Executed query and closed connection.

# %% [markdown]
# # Variabels

# %%
epsilons = np.array([2, 1.4, 1.2, 1, 0.8, 0.6, 0.4, 0.2])
n = np.array([32, 128, 256, 512, 1024, 2048])
degrees = np.array([2,3,4])

n_data_structures = 50

# %%
onlydirs = [f for f in os.listdir(os.getcwd()) if os.path.isdir(os.path.join(os.getcwd(), f)) and f[0] != '.']

# %%
onlydirs
# Out:
# ['Data', 'plots', 'range_queries', 'results', '__pycache__']

# %%
def make_results_lookup_dict_n(epsilons, n):
    epsilon_dict = dict.fromkeys(epsilons)
    n_dicts = []

    for e_key in epsilon_dict:
        #print(e_key)
        epsilon_dict[e_key] = dict.fromkeys(n)
        n_dict = epsilon_dict[e_key]
        #print(epsilon_dict[e_key])
        for n_key in n_dict:
            n_dict[n_key] = dict.fromkeys(degrees)
    return epsilon_dict

def fill_up_results_lookup_dict_n(epsilons, n, path, files):
    dict_ = make_results_lookup_dict_n(epsilons, n)
    for idx, f in enumerate(files):
        e = re.search(r'e=[-+]?[0-9]*\.?[0-9]*', f).group(0)
        e = e.split("e=")[1]
        N = re.search(r'N=\d+', f).group(0)
        N = N.split("N=")[1]

        dict_[float(e)][int(N)] = np.loadtxt(path + f, delimiter=',')
    return dict_

# %%
def make_lookup_results_dict_n_degree(epsilons, n, degrees):
    epsilon_dict = dict.fromkeys(epsilons)

    for e_key in epsilon_dict:
        #print(e_key)
        epsilon_dict[e_key] = dict.fromkeys(n)
        n_dict = epsilon_dict[e_key]
        #print(epsilon_dict[e_key])
        for n_key in n_dict:
            n_dict[n_key] = dict.fromkeys(degrees)

        #print(epsilon_dict)
    return epsilon_dict


def fill_up_lookup_results_dict_n_degree(epsilons, n, degrees, path, files):
    dict_ = make_lookup_results_dict_n_degree(epsilons, n, degrees)
    for idx, f in enumerate(files):
        e = re.search(r'e=[-+]?[0-9]*\.?[0-9]*', f).group(0)
        e = e.split("e=")[1]
        here_n = re.search(r'N=\d+', f).group(0)
        here_n = here_n.split("N=")[1]
        here_degree = re.search(r'B=\d+', f).group(0) 
        here_degree = here_degree.split("B=")[1]

        dict_[float(e)][int(here_n)][int(here_degree)] = np.loadtxt(path + f, delimiter=',')
    return dict_

def find_error_different_queries(est, cor):
    erorrs = est - cor
    max_error = np.amax(erorrs)
    min_error = np.amin(erorrs)
    rmse = mean_squared_error(cor, est, squared = False)
    error_dict = {'rmse': rmse, 'max': max_error, 'min': min_error, 'abs': np.mean(erorrs)}
    return error_dict

# %%
def load_split_est_n_cor_files(path):
    files_cor = [f for f in os.listdir(path) if re.match(r'(cor).*\.csv', f)]
    files_est = [f for f in os.listdir(path) if re.match(r'(est).*\.csv', f)]

    #Where flat beats hh
    cor_flat_better = [f for f in files_cor if re.match(r'.*(_flat_).*\.csv', f)]
    #Where hh beats flat
    cor_hh_better = flat_files_cor = [f for f in files_cor if re.match(r'.*(_hh_).*\.csv', f)]

    #Where flat beats hh
    est_flat_better =  [f for f in files_est if re.match(r'.*(_flat_).*\.csv', f)]
    #Where hh beats flat
    est_hh_better = [f for f in files_est if re.match(r'.*(_hh_).*\.csv', f)]
    
    return est_flat_better, cor_flat_better, est_hh_better, cor_hh_better

# %% [markdown]
# # Loading the data from the con obs

# %%
path = owd + '/results/sample_querys/con_obs/local_hh/'

hh_files_est_flat, hh_files_cor_flat, hh_files_est_hh, hh_files_cor_hh = load_split_est_n_cor_files(path)

# %%
cen_hh_cor_flat_dict = fill_up_lookup_results_dict_n_degree(epsilons, n, degrees, path, hh_files_cor_flat)
cen_hh_cor_hh_dict = fill_up_lookup_results_dict_n_degree(epsilons, n, degrees, path, hh_files_cor_hh)

cen_hh_est_flat_dict = fill_up_lookup_results_dict_n_degree(epsilons, n, degrees, path, hh_files_est_flat)
cen_hh_est_hh_dict = fill_up_lookup_results_dict_n_degree(epsilons, n, degrees, path, hh_files_est_hh)

# %%
cen_hh_cor_flat_dict
# Out:
# {2.0: {32: {2: array([1066., 1273.,  957., ..., 1247., 1008., 1077.]),
#    3: array([1066., 1273.,  957., ..., 1247., 1008., 1077.]),
#    4: array([1066., 1273.,  957., ..., 1247., 1008., 1077.])},
#   128: {2: array([1042., 2217., 1906., ..., 2340., 2338., 1931.]),
#    3: array([1042., 2217., 1906., ..., 2340., 2338., 1931.]),
#    4: array([1042., 2217., 1906., ..., 2340., 2338., 1931.])},
#   256: {2: array([4009., 3845., 4497., ..., 4145., 3983., 3417.]),
#    3: array([4009., 3845., 4497., ..., 4145., 3983., 3417.]),
#    4: array([4009., 3845., 4497., ..., 4145., 3983., 3417.])},
#   512: {2: array([7332., 7058., 9128., ..., 9877., 7308., 9083.]),
#    3: array([7332., 7058., 9128., ..., 9877., 7308., 9083.]),
#    4: array([7332., 7058., 9128., ..., 9877., 7308., 9083.])},
#   1024: {2: array([ 9144.,  8803.,  9561., ..., 10498.,  9862.,  5846.]),
#    3: array([ 9144.,  8803.,  9561., ..., 10498.,  9862.,  5846.]),
#    4: array([ 9144.,  8803.,  9561., ..., 10498.,  9862.,  5846.])},
#   2048: {2: array([10487.,   550., 13806., ...,  8614.,     0., 10158.]),
#    3: array([10487.,   550., 13806., ...,  8614.,     0., 10158.]),
#    4: array([10487.,   550., 13806., ...,  8614.,     0., 10158.])}},
#  1.4: {32: {2: array([1066., 1273.,  957., ..., 1247., 1008., 1077.]),
#    3: array([1066., 1273.,  957., ..., 1247., 1008., 1077.]),
#    4: array([1066., 1273.,  957., ..., 1247., 1008., 1077.])},
#   128: {2: array([1042., 2217., 1906., ..., 2340., 2338., 1931.]),
#    3: array([1042., 2217., 1906., ..., 2340., 2338., 1931.]),
#    4: array([1042., 2217., 1906., ..., 2340., 2338., 1931.])},
#   256: {2: array([4009., 3845., 4497., ..., 4145., 3983., 3417.]),
#    3: array([4009., 3845., 4497., ..., 4145., 3983., 3417.]),
#    4: array([4009., 3845., 4497., ..., 4145., 3983., 3417.])},
#   512: {2: array([7332., 7058., 9128., ..., 9877., 7308., 9083.]),
#    3: array([7332., 7058., 9128., ..., 9877., 7308., 9083.]),
#    4: array([7332., 7058., 9128., ..., 9877., 7308., 9083.])},
#   1024: {2: array([ 9144.,  8803.,  9561., ..., 10498.,  9862.,  5846.]),
#    3: array([ 9144.,  8803.,  9561., ..., 10498.,  9862.,  5846.]),
#    4: array([ 9144.,  8803.,  9561., ..., 10498.,  9862.,  5846.])},
#   2048: {2: array([10487.,   550., 13806., ...,  8614.,     0., 10158.]),
#    3: array([10487.,   550., 13806., ...,  8614.,     0., 10158.]),
#    4: array([10487.,   550., 13806., ...,  8614.,     0., 10158.])}},
#  1.2: {32: {2: array([1066., 1273.,  957., ..., 1247., 1008., 1077.]),
#    3: array([1066., 1273.,  957., ..., 1247., 1008., 1077.]),
#    4: array([1066., 1273.,  957., ..., 1247., 1008., 1077.])},
#   128: {2: array([1042., 2217., 1906., ..., 2340., 2338., 1931.]),
#    3: array([1042., 2217., 1906., ..., 2340., 2338., 1931.]),
#    4: array([1042., 2217., 1906., ..., 2340., 2338., 1931.])},
#   256: {2: array([4009., 3845., 4497., ..., 4145., 3983., 3417.]),
#    3: array([4009., 3845., 4497., ..., 4145., 3983., 3417.]),
#    4: array([4009., 3845., 4497., ..., 4145., 3983., 3417.])},
#   512: {2: array([7332., 7058., 9128., ..., 9877., 7308., 9083.]),
#    3: array([7332., 7058., 9128., ..., 9877., 7308., 9083.]),
#    4: array([7332., 7058., 9128., ..., 9877., 7308., 9083.])},
#   1024: {2: array([ 9144.,  8803.,  9561., ..., 10498.,  9862.,  5846.]),
#    3: array([ 9144.,  8803.,  9561., ..., 10498.,  9862.,  5846.]),
#    4: array([ 9144.,  8803.,  9561., ..., 10498.,  9862.,  5846.])},
#   2048: {2: array([10487.,   550., 13806., ...,  8614.,     0., 10158.]),
#    3: array([10487.,   550., 13806., ...,  8614.,     0., 10158.]),
#    4: array([10487.,   550., 13806., ...,  8614.,     0., 10158.])}},
#  1.0: {32: {2: array([1066., 1273.,  957., ..., 1247., 1008., 1077.]),
#    3: array([1066., 1273.,  957., ..., 1247., 1008., 1077.]),
#    4: array([1066., 1273.,  957., ..., 1247., 1008., 1077.])},
#   128: {2: array([1042., 2217., 1906., ..., 2340., 2338., 1931.]),
#    3: array([1042., 2217., 1906., ..., 2340., 2338., 1931.]),
#    4: array([1042., 2217., 1906., ..., 2340., 2338., 1931.])},
#   256: {2: array([4009., 3845., 4497., ..., 4145., 3983., 3417.]),
#    3: array([4009., 3845., 4497., ..., 4145., 3983., 3417.]),
#    4: array([4009., 3845., 4497., ..., 4145., 3983., 3417.])},
#   512: {2: array([7332., 7058., 9128., ..., 9877., 7308., 9083.]),
#    3: array([7332., 7058., 9128., ..., 9877., 7308., 9083.]),
#    4: array([7332., 7058., 9128., ..., 9877., 7308., 9083.])},
#   1024: {2: array([ 9144.,  8803.,  9561., ..., 10498.,  9862.,  5846.]),
#    3: array([ 9144.,  8803.,  9561., ..., 10498.,  9862.,  5846.]),
#    4: array([ 9144.,  8803.,  9561., ..., 10498.,  9862.,  5846.])},
#   2048: {2: array([10487.,   550., 13806., ...,  8614.,     0., 10158.]),
#    3: array([10487.,   550., 13806., ...,  8614.,     0., 10158.]),
#    4: array([10487.,   550., 13806., ...,  8614.,     0., 10158.])}},
#  0.8: {32: {2: array([1066., 1273.,  957., ..., 1247., 1008., 1077.]),
#    3: array([1066., 1273.,  957., ..., 1247., 1008., 1077.]),
#    4: array([1066., 1273.,  957., ..., 1247., 1008., 1077.])},
#   128: {2: array([1042., 2217., 1906., ..., 2340., 2338., 1931.]),
#    3: array([1042., 2217., 1906., ..., 2340., 2338., 1931.]),
#    4: array([1042., 2217., 1906., ..., 2340., 2338., 1931.])},
#   256: {2: array([4009., 3845., 4497., ..., 4145., 3983., 3417.]),
#    3: array([4009., 3845., 4497., ..., 4145., 3983., 3417.]),
#    4: array([4009., 3845., 4497., ..., 4145., 3983., 3417.])},
#   512: {2: array([7332., 7058., 9128., ..., 9877., 7308., 9083.]),
#    3: array([7332., 7058., 9128., ..., 9877., 7308., 9083.]),
#    4: array([7332., 7058., 9128., ..., 9877., 7308., 9083.])},
#   1024: {2: array([ 9144.,  8803.,  9561., ..., 10498.,  9862.,  5846.]),
#    3: array([ 9144.,  8803.,  9561., ..., 10498.,  9862.,  5846.]),
#    4: array([ 9144.,  8803.,  9561., ..., 10498.,  9862.,  5846.])},
#   2048: {2: array([10487.,   550., 13806., ...,  8614.,     0., 10158.]),
#    3: array([10487.,   550., 13806., ...,  8614.,     0., 10158.]),
#    4: array([10487.,   550., 13806., ...,  8614.,     0., 10158.])}},
#  0.6: {32: {2: array([1066., 1273.,  957., ..., 1247., 1008., 1077.]),
#    3: array([1066., 1273.,  957., ..., 1247., 1008., 1077.]),
#    4: array([1066., 1273.,  957., ..., 1247., 1008., 1077.])},
#   128: {2: array([1042., 2217., 1906., ..., 2340., 2338., 1931.]),
#    3: array([1042., 2217., 1906., ..., 2340., 2338., 1931.]),
#    4: array([1042., 2217., 1906., ..., 2340., 2338., 1931.])},
#   256: {2: array([4009., 3845., 4497., ..., 4145., 3983., 3417.]),
#    3: array([4009., 3845., 4497., ..., 4145., 3983., 3417.]),
#    4: array([4009., 3845., 4497., ..., 4145., 3983., 3417.])},
#   512: {2: array([7332., 7058., 9128., ..., 9877., 7308., 9083.]),
#    3: array([7332., 7058., 9128., ..., 9877., 7308., 9083.]),
#    4: array([7332., 7058., 9128., ..., 9877., 7308., 9083.])},
#   1024: {2: array([ 9144.,  8803.,  9561., ..., 10498.,  9862.,  5846.]),
#    3: array([ 9144.,  8803.,  9561., ..., 10498.,  9862.,  5846.]),
#    4: array([ 9144.,  8803.,  9561., ..., 10498.,  9862.,  5846.])},
#   2048: {2: array([10487.,   550., 13806., ...,  8614.,     0., 10158.]),
#    3: array([10487.,   550., 13806., ...,  8614.,     0., 10158.]),
#    4: array([10487.,   550., 13806., ...,  8614.,     0., 10158.])}},
#  0.4: {32: {2: array([1066., 1273.,  957., ..., 1247., 1008., 1077.]),
#    3: array([1066., 1273.,  957., ..., 1247., 1008., 1077.]),
#    4: array([1066., 1273.,  957., ..., 1247., 1008., 1077.])},
#   128: {2: array([1042., 2217., 1906., ..., 2340., 2338., 1931.]),
#    3: array([1042., 2217., 1906., ..., 2340., 2338., 1931.]),
#    4: array([1042., 2217., 1906., ..., 2340., 2338., 1931.])},
#   256: {2: array([4009., 3845., 4497., ..., 4145., 3983., 3417.]),
#    3: array([4009., 3845., 4497., ..., 4145., 3983., 3417.]),
#    4: array([4009., 3845., 4497., ..., 4145., 3983., 3417.])},
#   512: {2: array([7332., 7058., 9128., ..., 9877., 7308., 9083.]),
#    3: array([7332., 7058., 9128., ..., 9877., 7308., 9083.]),
#    4: array([7332., 7058., 9128., ..., 9877., 7308., 9083.])},
#   1024: {2: array([ 9144.,  8803.,  9561., ..., 10498.,  9862.,  5846.]),
#    3: array([ 9144.,  8803.,  9561., ..., 10498.,  9862.,  5846.]),
#    4: array([ 9144.,  8803.,  9561., ..., 10498.,  9862.,  5846.])},
#   2048: {2: array([10487.,   550., 13806., ...,  8614.,     0., 10158.]),
#    3: array([10487.,   550., 13806., ...,  8614.,     0., 10158.]),
#    4: array([10487.,   550., 13806., ...,  8614.,     0., 10158.])}},
#  0.2: {32: {2: array([1066., 1273.,  957., ..., 1247., 1008., 1077.]),
#    3: array([1066., 1273.,  957., ..., 1247., 1008., 1077.]),
#    4: array([1066., 1273.,  957., ..., 1247., 1008., 1077.])},
#   128: {2: array([1042., 2217., 1906., ..., 2340., 2338., 1931.]),
#    3: array([1042., 2217., 1906., ..., 2340., 2338., 1931.]),
#    4: array([1042., 2217., 1906., ..., 2340., 2338., 1931.])},
#   256: {2: array([4009., 3845., 4497., ..., 4145., 3983., 3417.]),
#    3: array([4009., 3845., 4497., ..., 4145., 3983., 3417.]),
#    4: array([4009., 3845., 4497., ..., 4145., 3983., 3417.])},
#   512: {2: array([7332., 7058., 9128., ..., 9877., 7308., 9083.]),
#    3: array([7332., 7058., 9128., ..., 9877., 7308., 9083.]),
#    4: array([7332., 7058., 9128., ..., 9877., 7308., 9083.])},
#   1024: {2: array([ 9144.,  8803.,  9561., ..., 10498.,  9862.,  5846.]),
#    3: array([ 9144.,  8803.,  9561., ..., 10498.,  9862.,  5846.]),
#    4: array([ 9144.,  8803.,  9561., ..., 10498.,  9862.,  5846.])},
#   2048: {2: array([10487.,   550., 13806., ...,  8614.,     0., 10158.]),
#    3: array([10487.,   550., 13806., ...,  8614.,     0., 10158.]),
#    4: array([10487.,   550., 13806., ...,  8614.,     0., 10158.])}}}

# %%
path = owd + '/results/sample_querys/local_hh/'

hh_files_est_flat, hh_files_cor_flat, hh_files_est_hh, hh_files_cor_hh = load_split_est_n_cor_files(path)

# %%
loc_hh_cor_flat_dict = fill_up_lookup_results_dict_n_degree(epsilons, n, degrees, path, hh_files_cor_flat)
loc_hh_cor_hh_dict = fill_up_lookup_results_dict_n_degree(epsilons, n, degrees, path, hh_files_cor_hh)

loc_hh_est_flat_dict = fill_up_lookup_results_dict_n_degree(epsilons, n, degrees, path, hh_files_est_flat)
loc_hh_est_hh_dict = fill_up_lookup_results_dict_n_degree(epsilons, n, degrees, path, hh_files_est_hh)

# %% [markdown]
# # Loading the data from the cen flat

# %%
path = owd + '/results/sample_querys/central_flat/flat/'

flat_files_est_flat, flat_files_cor_flat, flat_files_est_hh, flat_files_cor_hh = load_split_est_n_cor_files(path)

# %%
cen_flat_cor_flat_dict = fill_up_results_lookup_dict_n(epsilons, n, path, flat_files_cor_flat)
cen_flat_cor_hh_dict = fill_up_lookup_results_dict_n_degree(epsilons, n, degrees, path, flat_files_cor_hh)

cen_flat_est_flat_dict = fill_up_results_lookup_dict_n(epsilons, n, path, flat_files_est_flat)
cen_flat_est_hh_dict = fill_up_lookup_results_dict_n_degree(epsilons, n, degrees, path, flat_files_est_hh)

# %%
path = owd + '/results/sample_querys/flat/'

flat_files_est_flat, flat_files_cor_flat, flat_files_est_hh, flat_files_cor_hh = load_split_est_n_cor_files(path)

# %%
loc_flat_cor_flat_dict = fill_up_results_lookup_dict_n(epsilons, n, path, flat_files_cor_flat)
loc_flat_cor_hh_dict = fill_up_lookup_results_dict_n_degree(epsilons, n, degrees, path, flat_files_cor_hh)

loc_flat_est_flat_dict = fill_up_results_lookup_dict_n(epsilons, n, path, flat_files_est_flat)
loc_flat_est_hh_dict = fill_up_lookup_results_dict_n_degree(epsilons, n, degrees, path, flat_files_est_hh)

# %%
def make_flat_errors_dict(epsilons, n, degrees):
    epsilon_dict = dict.fromkeys(epsilons)
    
    n_dicts = []
    for i in range(0,len(epsilons)):
        n_dict = dict.fromkeys(n)
        n_dicts.append(n_dict)
    
    model_dicts = []
    for i in range(0,len(n)*len(epsilons)):
        model_dict = dict.fromkeys(['flat', 'hh'])

        model_dicts.append(model_dict)
    
    degree_dicts = []
    for i in range(0,len(n)*len(epsilons)):
        degree_dict = dict.fromkeys(degrees)
        degree_dicts.append(degree_dict)

    for e_key in epsilon_dict:
        #print(e_key)
        epsilon_dict[e_key] = dict.fromkeys(n)
        n_dict = epsilon_dict[e_key]
        #print(epsilon_dict[e_key])
        for n_key in n_dict:
            n_dict[n_key] = dict.fromkeys(['flat', 'hh'])
            n_dict[n_key]['hh'] = dict.fromkeys(degrees)

        #print(epsilon_dict)
    return epsilon_dict

def fill_up_flat_errors_dict(epsilons, n, degrees, flat_est_dict, flat_cor_dict, hh_est_dict, hh_cor_dict):
    dict_ = make_flat_errors_dict(epsilons, n, degrees)
    for e in epsilons:
        for N in n:

            flat_cor = flat_cor_dict[e][N]
            flat_est = flat_est_dict[e][N]
            dict_[e][N]['flat'] = find_error_different_queries(flat_est, flat_cor) 

            for degree in degrees:

                hh_cor = hh_cor_dict[e][N][degree]
                hh_est = hh_est_dict[e][N][degree]
                hh_rmse = find_error_different_queries(hh_est, hh_cor)

                dict_[e][N]['hh'][degree] = find_error_different_queries(hh_est, hh_cor)
    return dict_

# %%
cen_flat_error_dict = fill_up_flat_errors_dict(epsilons, n, degrees, cen_flat_est_flat_dict, cen_flat_cor_flat_dict, cen_hh_est_flat_dict, cen_hh_cor_flat_dict)
cen_flat_error_dict
# Out:
# {2.0: {32: {'flat': {'rmse': 1.7145706652575146,
#     'max': 7.082161349269882,
#     'min': -6.76880795369857,
#     'abs': 0.005932139039750291},
#    'hh': {2: {'rmse': 3.8210874699316255,
#      'max': 14.265179244732963,
#      'min': -15.629003634433957,
#      'abs': -0.03253519769968161},
#     3: {'rmse': 4.09875950550944,
#      'max': 16.88936725886265,
#      'min': -25.110316107129847,
#      'abs': 0.5614300689908527},
#     4: {'rmse': 3.769548151869408,
#      'max': 14.138752394193489,
#      'min': -14.06792053556228,
#      'abs': -0.5426242302949693}}},
#   128: {'flat': {'rmse': 2.177891666779391,
#     'max': 8.837652855951319,
#     'min': -8.819077411297485,
#     'abs': -0.1395406136285371},
#    'hh': {2: {'rmse': 5.804371377312019,
#      'max': 23.54120977572893,
#      'min': -33.19051662092693,
#      'abs': -0.4536799654945073},
#     3: {'rmse': 4.765712525734771,
#      'max': 18.857693463549367,
#      'min': -18.22361724234929,
#      'abs': -0.05987173003324547},
#     4: {'rmse': 4.655651113503488,
#      'max': 24.035466635653847,
#      'min': -18.295420932026445,
#      'abs': -0.10720679972750245}}},
#   256: {'flat': {'rmse': 3.3790432442937437,
#     'max': 15.430611656320252,
#     'min': -10.634887724548207,
#     'abs': 0.09039333730890721},
#    'hh': {2: {'rmse': 8.079939247556833,
#      'max': 37.45019176832648,
#      'min': -29.595034097750613,
#      'abs': 0.2699304232992306},
#     3: {'rmse': 7.056137607155167,
#      'max': 28.041873078310346,
#      'min': -35.468987831348386,
#      'abs': -0.2909662013022837},
#     4: {'rmse': 5.783016756681464,
#      'max': 22.296053622584623,
#      'min': -25.01303417643885,
#      'abs': 0.05971921145823853}}},
#   512: {'flat': {'rmse': 4.17130207361657,
#     'max': 17.022581412884392,
#     'min': -14.441988048653911,
#     'abs': 0.00951120807616935},
#    'hh': {2: {'rmse': 8.06961957506178,
#      'max': 35.02532410856293,
#      'min': -34.27194227641303,
#      'abs': -0.8109089068023583},
#     3: {'rmse': 7.181730821957709,
#      'max': 31.210328957447928,
#      'min': -19.592500289102645,
#      'abs': 0.548406185614078},
#     4: {'rmse': 6.969184864088994,
#      'max': 34.25625338529608,
#      'min': -25.05841349379807,
#      'abs': 0.4515086470519196}}},
#   1024: {'flat': {'rmse': 4.499569422862048,
#     'max': 14.09385356248822,
#     'min': -14.574277619278291,
#     'abs': 0.10924775356750178},
#    'hh': {2: {'rmse': 9.408586316378877,
#      'max': 44.014441267225266,
#      'min': -45.183301580082116,
#      'abs': 0.3531489252745876},
#     3: {'rmse': 7.72169755732299,
#      'max': 28.572187663432487,
#      'min': -30.895285805509047,
#      'abs': 0.09816298578092064},
#     4: {'rmse': 6.534520416999637,
#      'max': 21.572590269943248,
#      'min': -28.73873316544268,
#      'abs': -0.04574071050814491}}},
#   2048: {'flat': {'rmse': 5.53539530897585,
#     'max': 18.719107699413144,
#     'min': -22.89939654189584,
#     'abs': -0.03957631972413903},
#    'hh': {2: {'rmse': 10.483631144613662,
#      'max': 48.171325738554515,
#      'min': -50.91822113797207,
#      'abs': 0.868041866472045},
#     3: {'rmse': 8.194838114259754,
#      'max': 42.84104391959772,
#      'min': -42.914175583824544,
#      'abs': -0.7165025717762752},
#     4: {'rmse': 7.70614631326624,
#      'max': 27.483923081234025,
#      'min': -43.408519565766255,
#      'abs': 0.06873329906731862}}}},
#  1.4: {32: {'flat': {'rmse': 2.43647965906805,
#     'max': 8.817896693782586,
#     'min': -8.479384446994572,
#     'abs': 0.18011491545785976},
#    'hh': {2: {'rmse': 6.546297165880189,
#      'max': 23.246860946363995,
#      'min': -26.64897184505162,
#      'abs': 0.18302962722352253},
#     3: {'rmse': 5.701651784369545,
#      'max': 21.374605073713383,
#      'min': -26.87267949901218,
#      'abs': 0.4229507122236375},
#     4: {'rmse': 5.494888954515293,
#      'max': 22.825324210355575,
#      'min': -21.787382686564342,
#      'abs': -0.5240369945584911}}},
#   128: {'flat': {'rmse': 3.0890676245748696,
#     'max': 10.014505222812204,
#     'min': -11.063635822421475,
#     'abs': -0.07299982499072598},
#    'hh': {2: {'rmse': 9.337233999832796,
#      'max': 40.15145995642547,
#      'min': -41.021922300035385,
#      'abs': -0.00906961830392397},
#     3: {'rmse': 7.190426335754818,
#      'max': 33.60552146804616,
#      'min': -29.10589495425029,
#      'abs': 0.4483882559262004},
#     4: {'rmse': 7.172992776141757,
#      'max': 36.49487035124116,
#      'min': -36.70253688550201,
#      'abs': 0.5003415625361167}}},
#   256: {'flat': {'rmse': 4.84848736309934,
#     'max': 14.797906528257045,
#     'min': -16.197464477374524,
#     'abs': -0.3667661184241164},
#    'hh': {2: {'rmse': 10.497377489134674,
#      'max': 37.58875376744163,
#      'min': -38.562863812657724,
#      'abs': 0.20999241884517034},
#     3: {'rmse': 9.930272377176104,
#      'max': 40.40292575451713,
#      'min': -36.07461568038161,
#      'abs': 0.3164906949873141},
#     4: {'rmse': 7.580796403180013,
#      'max': 39.466785307969076,
#      'min': -35.96410611576721,
#      'abs': -0.5701716829862132}}},
#   512: {'flat': {'rmse': 5.895581514606601,
#     'max': 20.7138501772406,
#     'min': -24.59970733890259,
#     'abs': -0.2604208618959343},
#    'hh': {2: {'rmse': 12.059448678904909,
#      'max': 61.83635234582107,
#      'min': -40.05341483996472,
#      'abs': -0.2904640432300457},
#     3: {'rmse': 10.367808603290138,
#      'max': 46.3721144005367,
#      'min': -36.977515385633524,
#      'abs': 0.9307598074120534},
#     4: {'rmse': 9.136409910453004,
#      'max': 39.309045807522125,
#      'min': -45.405069894704866,
#      'abs': 0.16577203651602648}}},
#   1024: {'flat': {'rmse': 6.693582507829371,
#     'max': 22.00868444822936,
#     'min': -25.930331274605123,
#     'abs': 0.19785449426080196},
#    'hh': {2: {'rmse': 12.576587047056154,
#      'max': 56.5500777467405,
#      'min': -69.18364401870349,
#      'abs': -0.9146185860358459},
#     3: {'rmse': 10.84048257265864,
#      'max': 38.32905783771275,
#      'min': -48.55919446443477,
#      'abs': -0.19743425997675296},
#     4: {'rmse': 9.800505205490976,
#      'max': 41.38201234014923,
#      'min': -36.26179741112355,
#      'abs': 0.1838440094359652}}},
#   2048: {'flat': {'rmse': 8.07792504334979,
#     'max': 26.528758801061485,
#     'min': -26.43302654587933,
#     'abs': -0.3643846827169983},
#    'hh': {2: {'rmse': 14.3080323531303,
#      'max': 59.24941041006423,
#      'min': -57.35941254701356,
#      'abs': -0.16997148236523088},
#     3: {'rmse': 11.706312263905552,
#      'max': 45.32405905397536,
#      'min': -56.9848203143265,
#      'abs': 0.1528817305270354},
#     4: {'rmse': 11.18581465438397,
#      'max': 43.637220617172716,
#      'min': -50.91345087858281,
#      'abs': -0.5876333393173964}}}},
#  1.2: {32: {'flat': {'rmse': 3.1143373744794514,
#     'max': 10.168758703526919,
#     'min': -9.861350277505721,
#     'abs': 0.13855026275003074},
#    'hh': {2: {'rmse': 7.313871962053904,
#      'max': 28.343621521452633,
#      'min': -32.909408508783486,
#      'abs': 0.7806951603549036},
#     3: {'rmse': 7.303053812425409,
#      'max': 18.554824741567018,
#      'min': -33.785162356621186,
#      'abs': -1.1387857846457006},
#     4: {'rmse': 6.151055828006287,
#      'max': 22.433439529065254,
#      'min': -34.28762452677188,
#      'abs': 0.3224535520392664}}},
#   128: {'flat': {'rmse': 3.5831415771343353,
#     'max': 12.374140020679306,
#     'min': -13.10479693197567,
#     'abs': 0.08936759093523078},
#    'hh': {2: {'rmse': 10.19050326473419,
#      'max': 33.93085193946354,
#      'min': -55.615730779177284,
#      'abs': 0.03428585223550581},
#     3: {'rmse': 8.733345184642046,
#      'max': 47.046877273216296,
#      'min': -33.10558694724182,
#      'abs': -0.654885670182242},
#     4: {'rmse': 7.278335910580392,
#      'max': 44.94535381554033,
#      'min': -33.57874336408668,
#      'abs': 0.2792616000419452}}},
#   256: {'flat': {'rmse': 5.70699013734031,
#     'max': 19.416194056222594,
#     'min': -19.595261752254373,
#     'abs': 0.21478182596044754},
#    'hh': {2: {'rmse': 12.596449323640899,
#      'max': 47.57155463577692,
#      'min': -46.63047698641549,
#      'abs': -0.14718082015697984},
#     3: {'rmse': 11.030918030184356,
#      'max': 47.12038711391688,
#      'min': -40.66777618167998,
#      'abs': -0.4200478208063341},
#     4: {'rmse': 9.428097995366436,
#      'max': 35.73106576759619,
#      'min': -28.8613937700311,
#      'abs': 0.8704889101920235}}},
#   512: {'flat': {'rmse': 6.776587845017445,
#     'max': 23.34714643521329,
#     'min': -23.325001367054938,
#     'abs': -0.5725049732848987},
#    'hh': {2: {'rmse': 14.163268556751198,
#      'max': 61.640305409453504,
#      'min': -63.37623474020802,
#      'abs': 0.3520830162402341},
#     3: {'rmse': 12.005192707794105,
#      'max': 47.263697733959816,
#      'min': -48.14964879172385,
#      'abs': -1.0366339551884547},
#     4: {'rmse': 10.607690887252183,
#      'max': 38.45008163778766,
#      'min': -53.0108793744439,
#      'abs': -0.09793624962998947}}},
#   1024: {'flat': {'rmse': 8.143963144787271,
#     'max': 28.64809253819476,
#     'min': -28.205454421037757,
#     'abs': 0.10895570367613036},
#    'hh': {2: {'rmse': 15.281004761958073,
#      'max': 58.17019591041026,
#      'min': -63.916471234783785,
#      'abs': 0.30181331906206943},
#     3: {'rmse': 13.429051968131382,
#      'max': 51.80116798036033,
#      'min': -44.693006330498974,
#      'abs': 0.6143580100701547},
#     4: {'rmse': 11.589362109777746,
#      'max': 43.796818591737974,
#      'min': -46.179642050692564,
#      'abs': -0.13456290495308312}}},
#   2048: {'flat': {'rmse': 9.60715893944258,
#     'max': 31.915023163994192,
#     'min': -37.56116146480781,
#     'abs': 0.028037582393350625},
#    'hh': {2: {'rmse': 16.338251371753127,
#      'max': 56.97054163034409,
#      'min': -49.63153428530313,
#      'abs': 0.21988295532454094},
#     3: {'rmse': 13.396983386829485,
#      'max': 54.760475807419425,
#      'min': -60.067801016035446,
#      'abs': 0.004386225771410386},
#     4: {'rmse': 13.938781961684844,
#      'max': 48.42575157860665,
#      'min': -63.994082318416986,
#      'abs': -0.14534270831077115}}}},
#  1.0: {32: {'flat': {'rmse': 3.5165921601370647,
#     'max': 9.96078903225657,
#     'min': -17.078960382664263,
#     'abs': -0.17172619509746642},
#    'hh': {2: {'rmse': 8.911366039925252,
#      'max': 42.12507186141784,
#      'min': -39.09659463635512,
#      'abs': 1.248032975550833},
#     3: {'rmse': 7.930735530374019,
#      'max': 23.556162980062027,
#      'min': -37.00206601348236,
#      'abs': 0.6239489745980197},
#     4: {'rmse': 7.312465524853718,
#      'max': 28.26715565046743,
#      'min': -39.68149735128554,
#      'abs': -0.23188728440872397}}},
#   128: {'flat': {'rmse': 4.096766286797886,
#     'max': 13.035493416199188,
#     'min': -16.119533440966734,
#     'abs': 0.16639610706303284},
#    'hh': {2: {'rmse': 12.888426962908134,
#      'max': 49.00472143395791,
#      'min': -56.68961943893191,
#      'abs': 0.1498108936511217},
#     3: {'rmse': 10.096867240890447,
#      'max': 39.91519080712237,
#      'min': -42.540411149021566,
#      'abs': -0.03368620561811363},
#     4: {'rmse': 8.620207866783614,
#      'max': 31.862332882298006,
#      'min': -30.71378904994981,
#      'abs': 0.5997922858519554}}},
#   256: {'flat': {'rmse': 6.647015260918514,
#     'max': 25.59075011034747,
#     'min': -21.704896764455043,
#     'abs': 0.17372856660192065},
#    'hh': {2: {'rmse': 14.498774395173493,
#      'max': 61.11922496729767,
#      'min': -64.09426372800863,
#      'abs': 1.476999206150798},
#     3: {'rmse': 13.44326749218975,
#      'max': 49.641192493989365,
#      'min': -70.26512112960063,
#      'abs': 0.5870034303740082},
#     4: {'rmse': 10.715840517244509,
#      'max': 45.491724458880526,
#      'min': -42.07795281761992,
#      'abs': -0.018569710850143382}}},
#   512: {'flat': {'rmse': 8.303600796300548,
#     'max': 25.833235922980748,
#     'min': -29.374580867168333,
#     'abs': 0.5343515236538046},
#    'hh': {2: {'rmse': 17.0265823423929,
#      'max': 73.83397447620064,
#      'min': -70.30749194287546,
#      'abs': -0.9302581733950043},
#     3: {'rmse': 13.976754398796349,
#      'max': 63.048641052615494,
#      'min': -53.375161919775564,
#      'abs': 0.868564031816967},
#     4: {'rmse': 12.709557551107036,
#      'max': 55.04965873706897,
#      'min': -40.297862977938166,
#      'abs': 0.0712067728776492}}},
#   1024: {'flat': {'rmse': 9.494380083417516,
#     'max': 29.384854136582362,
#     'min': -29.37255340516458,
#     'abs': 0.27992431787816274},
#    'hh': {2: {'rmse': 18.820081455317723,
#      'max': 67.7443991810942,
#      'min': -84.44241944637724,
#      'abs': 0.030698182240562893},
#     3: {'rmse': 15.748695749051999,
#      'max': 52.28692388165655,
#      'min': -56.69690781288955,
#      'abs': 0.1689162367158482},
#     4: {'rmse': 13.562991412152288,
#      'max': 48.141540744312806,
#      'min': -59.02970069241928,
#      'abs': -0.11553593495940258}}},
#   2048: {'flat': {'rmse': 11.319077029979113,
#     'max': 34.85832964180372,
#     'min': -37.3314715696979,
#     'abs': -0.1478345197117933},
#    'hh': {2: {'rmse': 20.879810524308294,
#      'max': 76.52299544587186,
#      'min': -83.12600560266037,
#      'abs': 1.2517548582552782},
#     3: {'rmse': 16.523614678787535,
#      'max': 63.243739983878186,
#      'min': -61.4290592252933,
#      'abs': -1.009377330444757},
#     4: {'rmse': 16.1516160152596,
#      'max': 74.55242304238709,
#      'min': -66.20548801208315,
#      'abs': -1.2165894791999907}}}},
#  0.8: {32: {'flat': {'rmse': 4.34077752925147,
#     'max': 12.987179617938182,
#     'min': -17.629222837352245,
#     'abs': -0.13477913119040758},
#    'hh': {2: {'rmse': 10.981930814018453,
#      'max': 37.85020150446803,
#      'min': -45.05987617607764,
#      'abs': -0.17575203901986783},
#     3: {'rmse': 9.82588241734027,
#      'max': 42.315747317190244,
#      'min': -38.831786377700155,
#      'abs': 0.09490235362753774},
#     4: {'rmse': 8.982848049694155,
#      'max': 40.77333613300493,
#      'min': -34.908598989570464,
#      'abs': 1.214000475585326}}},
#   128: {'flat': {'rmse': 5.155408256690526,
#     'max': 20.038623406844636,
#     'min': -22.940143975325782,
#     'abs': 0.08774856950747931},
#    'hh': {2: {'rmse': 14.447451968442527,
#      'max': 48.96846842620744,
#      'min': -63.679778385020654,
#      'abs': -0.34804621292587234},
#     3: {'rmse': 13.2549050727564,
#      'max': 70.25735258890177,
#      'min': -46.65260497726513,
#      'abs': 0.6222779238951835},
#     4: {'rmse': 11.469143680088733,
#      'max': 40.65158473198335,
#      'min': -52.891720665559205,
#      'abs': 0.9945165864549613}}},
#   256: {'flat': {'rmse': 8.642897876791146,
#     'max': 28.575705738121997,
#     'min': -30.544882279419653,
#     'abs': 0.17744519122774619},
#    'hh': {2: {'rmse': 18.84025709159397,
#      'max': 67.98256554150794,
#      'min': -74.65918152935683,
#      'abs': -0.20044394298536228},
#     3: {'rmse': 16.897786340926206,
#      'max': 57.66668439823616,
#      'min': -64.88344245240023,
#      'abs': 0.18368824459028038},
#     4: {'rmse': 14.319233538357508,
#      'max': 56.73885714154676,
#      'min': -56.60188411555464,
#      'abs': 0.4172532084793769}}},
#   512: {'flat': {'rmse': 10.881419032962096,
#     'max': 29.52365968525919,
#     'min': -42.308917506170474,
#     'abs': -0.9532552626569369},
#    'hh': {2: {'rmse': 20.826741722921074,
#      'max': 73.45644024043759,
#      'min': -67.5758992926776,
#      'abs': -0.030957483326806687},
#     3: {'rmse': 17.593766737663547,
#      'max': 71.54990930238819,
#      'min': -70.32124592749005,
#      'abs': 0.21189451588363772},
#     4: {'rmse': 16.756252364052166,
#      'max': 71.30555935803113,
#      'min': -60.404234473913675,
#      'abs': 1.0613903526133952}}},
#   1024: {'flat': {'rmse': 11.546705729036368,
#     'max': 41.2404636195015,
#     'min': -48.090671698015285,
#     'abs': -0.07369349111740739},
#    'hh': {2: {'rmse': 23.94377786905103,
#      'max': 91.47783086661912,
#      'min': -98.51517102595062,
#      'abs': -0.4135947268289954},
#     3: {'rmse': 19.4384963758155,
#      'max': 78.84083990419367,
#      'min': -82.89076414633018,
#      'abs': -0.5302492827394839},
#     4: {'rmse': 17.05234914380562,
#      'max': 79.08117673318884,
#      'min': -63.94195179055896,
#      'abs': 0.28251539435020384}}},
#   2048: {'flat': {'rmse': 13.745708975816541,
#     'max': 51.05616217538409,
#     'min': -48.20239906112329,
#     'abs': 0.6679384509433952},
#    'hh': {2: {'rmse': 25.54845698654614,
#      'max': 114.71586033349377,
#      'min': -110.4672030191141,
#      'abs': -1.2506671638333748},
#     3: {'rmse': 20.486304753026552,
#      'max': 84.32168609412656,
#      'min': -82.53287128123603,
#      'abs': 0.3760363659915063},
#     4: {'rmse': 19.12817707280194,
#      'max': 87.6605584150384,
#      'min': -74.12607713020589,
#      'abs': 0.7126533802335586}}}},
#  0.6: {32: {'flat': {'rmse': 5.628084803174077,
#     'max': 17.885883538315966,
#     'min': -21.689552761620007,
#     'abs': 0.2319839243484169},
#    'hh': {2: {'rmse': 13.041993028091351,
#      'max': 42.358531326427965,
#      'min': -51.90481223631616,
#      'abs': 0.4150108608712284},
#     3: {'rmse': 11.781305166757239,
#      'max': 37.39366814673167,
#      'min': -44.70121997370461,
#      'abs': -0.1903382644401247},
#     4: {'rmse': 10.818849253997572,
#      'max': 43.48411927927282,
#      'min': -31.415723909882445,
#      'abs': -0.7697003147855674}}},
#   128: {'flat': {'rmse': 7.337234345936353,
#     'max': 25.746247379878696,
#     'min': -22.335204329704993,
#     'abs': -0.20233155296918134},
#    'hh': {2: {'rmse': 21.12143305684566,
#      'max': 107.6336195089873,
#      'min': -76.43232511320957,
#      'abs': 0.8370573619471746},
#     3: {'rmse': 17.402118329804974,
#      'max': 62.82836454112203,
#      'min': -87.0853393006413,
#      'abs': 0.23182168913766119},
#     4: {'rmse': 14.872778582112526,
#      'max': 68.43477497802587,
#      'min': -62.71046290602317,
#      'abs': 0.5389252986018932}}},
#   256: {'flat': {'rmse': 11.353082118133091,
#     'max': 56.75886643564081,
#     'min': -42.7075543894025,
#     'abs': -0.5324787992456556},
#    'hh': {2: {'rmse': 23.593040509360822,
#      'max': 111.27391815339888,
#      'min': -87.52286585522597,
#      'abs': -0.29746399728331396},
#     3: {'rmse': 21.400984521483988,
#      'max': 87.31665921369495,
#      'min': -73.76453090035284,
#      'abs': -0.23684893551697023},
#     4: {'rmse': 17.43235125448744,
#      'max': 68.35302744378987,
#      'min': -74.21700670317932,
#      'abs': 0.3918384470770887}}},
#   512: {'flat': {'rmse': 13.59601354739762,
#     'max': 43.434520656262976,
#     'min': -52.53626066076322,
#     'abs': -0.26228099678441325},
#    'hh': {2: {'rmse': 27.749067680786613,
#      'max': 141.07503256923974,
#      'min': -131.08716991126857,
#      'abs': 0.3581289987097778},
#     3: {'rmse': 22.938273911674326,
#      'max': 70.76742902167189,
#      'min': -103.74118416295096,
#      'abs': 0.6393289957514505},
#     4: {'rmse': 21.65172432193413,
#      'max': 82.8511814424246,
#      'min': -85.29357026305661,
#      'abs': 0.09145787715232327}}},
#   1024: {'flat': {'rmse': 15.861116127627678,
#     'max': 48.70867399652889,
#     'min': -59.311219448014526,
#     'abs': -0.5941316277335267},
#    'hh': {2: {'rmse': 30.602252890490828,
#      'max': 136.40773022106805,
#      'min': -119.57817422149128,
#      'abs': 0.3222106036741574},
#     3: {'rmse': 24.958961417258706,
#      'max': 124.91404062838228,
#      'min': -98.06355551981869,
#      'abs': -0.8158653934795155},
#     4: {'rmse': 22.60340632960384,
#      'max': 93.48408012139498,
#      'min': -88.84970286808675,
#      'abs': 0.13892716083893028}}},
#   2048: {'flat': {'rmse': 18.62148620006505,
#     'max': 62.88696552542751,
#     'min': -72.73959888812897,
#     'abs': -0.30520994322926437},
#    'hh': {2: {'rmse': 33.42227818798359,
#      'max': 117.88366348003728,
#      'min': -127.35709289930128,
#      'abs': -0.9971161268334529},
#     3: {'rmse': 27.63720542654646,
#      'max': 130.44366784820522,
#      'min': -130.8066062314665,
#      'abs': 0.17938909462650054},
#     4: {'rmse': 26.81709735635632,
#      'max': 96.59200951829916,
#      'min': -109.20193802953509,
#      'abs': -0.10739301974384298}}}},
#  0.4: {32: {'flat': {'rmse': 8.477663664933099,
#     'max': 29.934985003460497,
#     'min': -29.94824859273365,
#     'abs': -1.1550042134104646},
#    'hh': {2: {'rmse': 22.450387218343636,
#      'max': 86.28764659795343,
#      'min': -127.9070140026331,
#      'abs': -0.33141682856444116},
#     3: {'rmse': 19.922739460497294,
#      'max': 72.97082167193298,
#      'min': -68.7222112018103,
#      'abs': -2.38003949744952},
#     4: {'rmse': 18.37077176402858,
#      'max': 61.70938837740505,
#      'min': -70.98438868625271,
#      'abs': 0.4871574891408023}}},
#   128: {'flat': {'rmse': 10.682881586689033,
#     'max': 39.823775069885414,
#     'min': -44.738178942958484,
#     'abs': 0.022055908021547884},
#    'hh': {2: {'rmse': 28.190988318608163,
#      'max': 109.63848271146435,
#      'min': -96.7396205213181,
#      'abs': -1.645191775545536},
#     3: {'rmse': 25.15215757100364,
#      'max': 111.690830818118,
#      'min': -137.12748785552594,
#      'abs': 1.343388017536083},
#     4: {'rmse': 22.484965660339277,
#      'max': 124.23857157412749,
#      'min': -86.7085985105507,
#      'abs': 0.9217995992303384}}},
#   256: {'flat': {'rmse': 17.024460427780642,
#     'max': 53.69273005823925,
#     'min': -55.1643578425992,
#     'abs': 0.7231506386584852},
#    'hh': {2: {'rmse': 37.16270047148677,
#      'max': 144.19026831478732,
#      'min': -126.13209627482456,
#      'abs': -2.4936280198349223},
#     3: {'rmse': 33.609051787173605,
#      'max': 208.15520209326223,
#      'min': -140.6486867448284,
#      'abs': -2.4924943653619143},
#     4: {'rmse': 27.0894501515129,
#      'max': 97.21723769046002,
#      'min': -128.72937708501559,
#      'abs': -0.7802471019491717}}},
#   512: {'flat': {'rmse': 21.066991607637664,
#     'max': 63.20127628810769,
#     'min': -85.21244236077655,
#     'abs': -0.6451163246166827},
#    'hh': {2: {'rmse': 41.36873254763475,
#      'max': 164.7356886588932,
#      'min': -170.3955924736556,
#      'abs': -1.6454803248037424},
#     3: {'rmse': 33.949116548824264,
#      'max': 121.00246018063353,
#      'min': -117.06450932213738,
#      'abs': -1.6579216206408138},
#     4: {'rmse': 31.16232228469305,
#      'max': 105.1766369742827,
#      'min': -131.16216458383315,
#      'abs': -2.1417308360701974}}},
#   1024: {'flat': {'rmse': 23.968952477185855,
#     'max': 86.91892310633011,
#     'min': -84.33038589484386,
#     'abs': -0.2511512407272297},
#    'hh': {2: {'rmse': 45.47110299309424,
#      'max': 184.37472075222468,
#      'min': -226.28613494715682,
#      'abs': -0.4995361254082618},
#     3: {'rmse': 39.484262162246154,
#      'max': 156.5695612165273,
#      'min': -145.88852699980453,
#      'abs': -2.273344313098342},
#     4: {'rmse': 33.921207731670115,
#      'max': 135.1139158104197,
#      'min': -135.61315551468215,
#      'abs': -0.6850997334994535}}},
#   2048: {'flat': {'rmse': 28.564535631390562,
#     'max': 113.4076687373672,
#     'min': -101.95638121959928,
#     'abs': 0.9784208301095078},
#    'hh': {2: {'rmse': 49.589333457904864,
#      'max': 159.05083034185554,
#      'min': -195.42970008303564,
#      'abs': -0.9776371146469304},
#     3: {'rmse': 40.70042184085182,
#      'max': 218.4342540780599,
#      'min': -165.44133718438025,
#      'abs': -0.08391056531443364},
#     4: {'rmse': 39.31716747002935,
#      'max': 159.81214934006857,
#      'min': -215.34325285314844,
#      'abs': 0.04104434800690897}}}},
#  0.2: {32: {'flat': {'rmse': 18.922287497682408,
#     'max': 111.30110147462824,
#     'min': -61.803472366194455,
#     'abs': -0.8187154156942432},
#    'hh': {2: {'rmse': 46.824347082058026,
#      'max': 274.04932903765416,
#      'min': -139.16239887114148,
#      'abs': 1.018490206291764},
#     3: {'rmse': 44.10143309962004,
#      'max': 118.11744111320036,
#      'min': -165.66467596953316,
#      'abs': -0.6981824456257946},
#     4: {'rmse': 34.49228353658308,
#      'max': 186.94976738122932,
#      'min': -160.86957744626068,
#      'abs': 2.4945968835351398}}},
#   128: {'flat': {'rmse': 21.593340676720576,
#     'max': 84.45574803985619,
#     'min': -76.49167572190368,
#     'abs': 0.29500876142776017},
#    'hh': {2: {'rmse': 60.69939434243358,
#      'max': 307.4062248226546,
#      'min': -269.23121270654246,
#      'abs': -1.8461153121600313},
#     3: {'rmse': 51.31178796172929,
#      'max': 228.12753189977457,
#      'min': -232.5810998057284,
#      'abs': -2.9296025344243843},
#     4: {'rmse': 47.51628164179754,
#      'max': 167.48389962761667,
#      'min': -200.38735788661643,
#      'abs': -1.9592403476944922}}},
#   256: {'flat': {'rmse': 36.845762475576336,
#     'max': 162.52533869767285,
#     'min': -117.73515275905902,
#     'abs': -0.6111870359264402},
#    'hh': {2: {'rmse': 70.70562912990742,
#      'max': 250.89804495840872,
#      'min': -291.17503941698897,
#      'abs': -1.382265129880888},
#     3: {'rmse': 71.35813398374441,
#      'max': 267.2188043877868,
#      'min': -338.1575907998408,
#      'abs': 1.5133179424266372},
#     4: {'rmse': 55.32909533700434,
#      'max': 262.6502190467345,
#      'min': -220.5020290716093,
#      'abs': -1.084871294853854}}},
#   512: {'flat': {'rmse': 41.63524703953396,
#     'max': 131.75309768559418,
#     'min': -170.52575024077942,
#     'abs': 0.11620099804054516},
#    'hh': {2: {'rmse': 86.30912205079241,
#      'max': 448.433256520796,
#      'min': -292.86117829488103,
#      'abs': -3.6792619161597635},
#     3: {'rmse': 71.22885087188412,
#      'max': 313.4731313944012,
#      'min': -257.4068864191577,
#      'abs': 1.7201827839562058},
#     4: {'rmse': 65.57389170650784,
#      'max': 228.23762714679106,
#      'min': -287.85545531268235,
#      'abs': 0.971730787377273}}},
#   1024: {'flat': {'rmse': 47.088716783061564,
#     'max': 194.14720267449047,
#     'min': -179.89389017462236,
#     'abs': -0.5783732305189231},
#    'hh': {2: {'rmse': 94.56127855457613,
#      'max': 392.4947393305847,
#      'min': -391.8555286300725,
#      'abs': 1.4757915166055073},
#     3: {'rmse': 81.13225499664838,
#      'max': 424.4952658266411,
#      'min': -310.7568917119006,
#      'abs': -1.1573655432795293},
#     4: {'rmse': 68.13641350477008,
#      'max': 299.5330825760975,
#      'min': -261.17988283662817,
#      'abs': 6.2078690197447886}}},
#   2048: {'flat': {'rmse': 57.83204617269362,
#     'max': 172.92456370731088,
#     'min': -201.4591017132916,
#     'abs': -1.7254974559672518},
#    'hh': {2: {'rmse': 98.29742487666313,
#      'max': 502.63012888832964,
#      'min': -313.92205400888287,
#      'abs': -1.4820107982808277},
#     3: {'rmse': 81.23860677356363,
#      'max': 325.3384851818482,
#      'min': -290.65414504122054,
#      'abs': 0.9474442211427413},
#     4: {'rmse': 80.66034650171262,
#      'max': 338.6578845483673,
#      'min': -401.241885291427,
#      'abs': -0.42334659030125843}}}}}

# %%
loc_flat_error_dict = fill_up_flat_errors_dict(epsilons, n, degrees, loc_flat_est_flat_dict, loc_flat_cor_flat_dict, loc_hh_est_flat_dict, loc_hh_cor_flat_dict)
loc_flat_error_dict
# Out:
# {2.0: {32: {'flat': {'rmse': 147.156419020598,
#     'max': 452.91395938796177,
#     'min': -540.9010507145824,
#     'abs': 5.909452346571899},
#    'hh': {2: {'rmse': 260.333156483884,
#      'max': 836.1895610503484,
#      'min': -1003.3600907494707,
#      'abs': -3.668602823529264},
#     3: {'rmse': 393.4920682615496,
#      'max': 1508.1026414336538,
#      'min': -1539.057077077286,
#      'abs': -0.5817328980573268},
#     4: {'rmse': 342.260102910508,
#      'max': 1137.332726122721,
#      'min': -987.5016052789081,
#      'abs': -40.472278022905634}}},
#   128: {'flat': {'rmse': 787.4035508123478,
#     'max': 2698.9651080073927,
#     'min': -2521.931430291857,
#     'abs': 10.903752741479977},
#    'hh': {2: {'rmse': 999.1236861313329,
#      'max': 4219.10867148692,
#      'min': -3592.5439095978877,
#      'abs': -17.35296371388003},
#     3: {'rmse': 1400.6153661044832,
#      'max': 5189.479659022669,
#      'min': -5103.483658762848,
#      'abs': -73.60993277125525},
#     4: {'rmse': 1488.1237586295033,
#      'max': 5928.190832940615,
#      'min': -4944.261357085296,
#      'abs': -67.73760686011167}}},
#   256: {'flat': {'rmse': 2361.031799941691,
#     'max': 7029.670715738845,
#     'min': -6746.8707160156055,
#     'abs': -105.2104087958897},
#    'hh': {2: {'rmse': 2137.139987856412,
#      'max': 9582.573581851031,
#      'min': -9023.38365643972,
#      'abs': -30.27594959816467},
#     3: {'rmse': 3657.345759877421,
#      'max': 15181.462351992104,
#      'min': -12105.200394323669,
#      'abs': -1.3282271474718117},
#     4: {'rmse': 2245.8460381121376,
#      'max': 9283.428856158347,
#      'min': -8520.409877130518,
#      'abs': -7.0995028547472}}},
#   512: {'flat': {'rmse': 5682.973186196912,
#     'max': 18512.81015018336,
#     'min': -16876.48131144936,
#     'abs': -75.63933126615277},
#    'hh': {2: {'rmse': 4682.5077317917785,
#      'max': 16178.048006809626,
#      'min': -14487.756813834338,
#      'abs': 81.71551412440007},
#     3: {'rmse': 5590.829509620887,
#      'max': 22297.016938325578,
#      'min': -19101.38569942467,
#      'abs': -167.39234138733104},
#     4: {'rmse': 7074.247767457393,
#      'max': 33181.75753059208,
#      'min': -21813.29126402226,
#      'abs': -315.1216422876891}}},
#   1024: {'flat': {'rmse': 13177.710568815084,
#     'max': 40454.38256644799,
#     'min': -52998.389827526655,
#     'abs': -477.5432083250826},
#    'hh': {2: {'rmse': 9630.128872074078,
#      'max': 41768.28949658724,
#      'min': -37464.50806184543,
#      'abs': -414.62175552174756},
#     3: {'rmse': 14590.423923448969,
#      'max': 62458.701065375906,
#      'min': -45885.55927197101,
#      'abs': -286.35344027131543},
#     4: {'rmse': 9653.33956274569,
#      'max': 34818.28830747028,
#      'min': -33778.2126243925,
#      'abs': -165.81067895395873}}},
#   2048: {'flat': {'rmse': 29636.219773546967,
#     'max': 106659.20740402846,
#     'min': -93498.07274993601,
#     'abs': 19.38799414365138},
#    'hh': {2: {'rmse': 19153.095591395904,
#      'max': 91211.50716374902,
#      'min': -67150.93340412846,
#      'abs': -121.14603674543281},
#     3: {'rmse': 19720.947243362734,
#      'max': 81478.94536425783,
#      'min': -99419.2989384834,
#      'abs': -110.81603068350582},
#     4: {'rmse': 29228.75603130044,
#      'max': 114335.46424669084,
#      'min': -135883.92396563946,
#      'abs': -855.7220322816264}}}},
#  1.4: {32: {'flat': {'rmse': 257.0055741816979,
#     'max': 922.152972771471,
#     'min': -601.7048036637154,
#     'abs': -0.48042552160466295},
#    'hh': {2: {'rmse': 396.5719579308849,
#      'max': 1480.863888777667,
#      'min': -1332.117634846043,
#      'abs': 31.963568452371586},
#     3: {'rmse': 635.7950161336623,
#      'max': 2125.6026909243114,
#      'min': -2065.561345674727,
#      'abs': 43.15084111450283},
#     4: {'rmse': 596.572045076703,
#      'max': 3003.174419854972,
#      'min': -2481.5184115820666,
#      'abs': 9.373350284630707}}},
#   128: {'flat': {'rmse': 1386.9333144097986,
#     'max': 4542.81318212063,
#     'min': -4953.3064431104885,
#     'abs': -22.982209287818936},
#    'hh': {2: {'rmse': 1836.2298657289377,
#      'max': 6935.632280737627,
#      'min': -5729.177989067386,
#      'abs': -34.222199912232654},
#     3: {'rmse': 2524.2421237510675,
#      'max': 8894.931563730523,
#      'min': -9729.39501463126,
#      'abs': 62.41621109563032},
#     4: {'rmse': 2687.2930823235365,
#      'max': 11655.553279326836,
#      'min': -9657.052723797808,
#      'abs': -112.3712372372956}}},
#   256: {'flat': {'rmse': 4139.654852539687,
#     'max': 15806.239292031645,
#     'min': -12842.58890094507,
#     'abs': 75.00771251823541},
#    'hh': {2: {'rmse': 3658.4283781083104,
#      'max': 14377.941382728794,
#      'min': -15912.119046993572,
#      'abs': -26.781397631229286},
#     3: {'rmse': 6697.472726748335,
#      'max': 26488.871177868292,
#      'min': -20437.373854205365,
#      'abs': -145.71568173414101},
#     4: {'rmse': 3864.9652421885526,
#      'max': 18259.072789163216,
#      'min': -15068.215064517455,
#      'abs': 26.4156601960861}}},
#   512: {'flat': {'rmse': 10997.867970341,
#     'max': 41564.3951784952,
#     'min': -31152.758877312423,
#     'abs': 75.81797314549189},
#    'hh': {2: {'rmse': 8369.77750982564,
#      'max': 34418.846538329075,
#      'min': -23122.100955706577,
#      'abs': 228.25151326268184},
#     3: {'rmse': 10354.529106612128,
#      'max': 35449.20372633066,
#      'min': -31824.206765109957,
#      'abs': -104.04718272094551},
#     4: {'rmse': 12459.364102537045,
#      'max': 41992.74874369125,
#      'min': -36147.67977763421,
#      'abs': -507.8298181420035}}},
#   1024: {'flat': {'rmse': 23783.0228364195,
#     'max': 84625.17793296861,
#     'min': -82582.08540467621,
#     'abs': 545.3809196062504},
#    'hh': {2: {'rmse': 17730.034084037656,
#      'max': 77244.61845167226,
#      'min': -67977.60751488768,
#      'abs': -916.0138309004727},
#     3: {'rmse': 26441.127656008033,
#      'max': 90986.47979795655,
#      'min': -84839.84043891155,
#      'abs': 94.68830748630576},
#     4: {'rmse': 18143.996230152166,
#      'max': 61881.47915925601,
#      'min': -62716.89302450166,
#      'abs': 684.5557218953164}}},
#   2048: {'flat': {'rmse': 54461.75264117507,
#     'max': 182706.17851681059,
#     'min': -177440.91789118375,
#     'abs': 1447.6591291950879},
#    'hh': {2: {'rmse': 35559.1992763088,
#      'max': 170472.8157765154,
#      'min': -138441.84926679338,
#      'abs': 291.89426063496967},
#     3: {'rmse': 35470.348112869586,
#      'max': 130979.20443404996,
#      'min': -121408.84451199856,
#      'abs': -324.85003661564343},
#     4: {'rmse': 55689.20907096711,
#      'max': 225435.67792205256,
#      'min': -206382.86807600767,
#      'abs': 4.2242778165848}}}},
#  1.2: {32: {'flat': {'rmse': 292.5162046224498,
#     'max': 1014.9071187397476,
#     'min': -891.6570283598269,
#     'abs': 17.12823545642048},
#    'hh': {2: {'rmse': 458.98560736858826,
#      'max': 1315.5691811811039,
#      'min': -1280.0485025754626,
#      'abs': 6.830480724900498},
#     3: {'rmse': 790.3655334693725,
#      'max': 3064.367305637262,
#      'min': -2577.0774150329435,
#      'abs': 14.203299323846277},
#     4: {'rmse': 698.4542114858665,
#      'max': 2457.508619091932,
#      'min': -2070.3736431221664,
#      'abs': -11.73074327133707}}},
#   128: {'flat': {'rmse': 1531.524080312675,
#     'max': 4739.440599665657,
#     'min': -5267.217303982513,
#     'abs': 4.510664160453858},
#    'hh': {2: {'rmse': 2240.1935536168976,
#      'max': 8630.635108230075,
#      'min': -7147.067154521079,
#      'abs': -2.1676396894327876},
#     3: {'rmse': 3105.8740261678436,
#      'max': 14598.379167014245,
#      'min': -9956.696782194831,
#      'abs': -42.62379403417543},
#     4: {'rmse': 3357.8779652288335,
#      'max': 13538.416969959708,
#      'min': -12870.06538316251,
#      'abs': -209.07584447801406}}},
#   256: {'flat': {'rmse': 4921.911270892779,
#     'max': 14560.804430437762,
#     'min': -14883.3880308015,
#     'abs': -155.1719125437763},
#    'hh': {2: {'rmse': 4593.326040376126,
#      'max': 16978.64999694286,
#      'min': -16447.959003213044,
#      'abs': -37.97390962449337},
#     3: {'rmse': 7994.97123988301,
#      'max': 34377.827065557525,
#      'min': -28174.774906271523,
#      'abs': 22.546322388293746},
#     4: {'rmse': 4712.849015695549,
#      'max': 19192.23137670851,
#      'min': -14142.767371928338,
#      'abs': 209.76894237222075}}},
#   512: {'flat': {'rmse': 12605.943993303696,
#     'max': 41276.00212640239,
#     'min': -45139.90040466061,
#     'abs': -208.73146999566876},
#    'hh': {2: {'rmse': 10139.94224023387,
#      'max': 36682.15824724957,
#      'min': -37159.1532291171,
#      'abs': -312.2649328490274},
#     3: {'rmse': 12013.949822334864,
#      'max': 47045.76776506506,
#      'min': -41436.10882660966,
#      'abs': 212.91952889449877},
#     4: {'rmse': 15859.664163307898,
#      'max': 55754.2512512693,
#      'min': -49543.14495482667,
#      'abs': -39.3990196945095}}},
#   1024: {'flat': {'rmse': 29556.268137530275,
#     'max': 118304.62097664678,
#     'min': -117451.09825842454,
#     'abs': 1.1307691796213388},
#    'hh': {2: {'rmse': 21214.060241218725,
#      'max': 80334.97284115833,
#      'min': -68725.07640668176,
#      'abs': 101.12579140851106},
#     3: {'rmse': 31946.508342469533,
#      'max': 133525.2223218606,
#      'min': -100121.19293694197,
#      'abs': 194.17463282352284},
#     4: {'rmse': 22059.34805428286,
#      'max': 90900.28458869836,
#      'min': -78441.59448241186,
#      'abs': 68.18540554955196}}},
#   2048: {'flat': {'rmse': 69186.42347126588,
#     'max': 250464.557846835,
#     'min': -218924.96455754197,
#     'abs': 1886.5727692242444},
#    'hh': {2: {'rmse': 44460.47594861999,
#      'max': 195993.73846820602,
#      'min': -181578.14699415455,
#      'abs': -303.83687189834484},
#     3: {'rmse': 43072.3437811832,
#      'max': 153046.09752012684,
#      'min': -179808.98614954745,
#      'abs': -1504.5167405974953},
#     4: {'rmse': 66712.48853383827,
#      'max': 264655.36212993815,
#      'min': -226352.89424158592,
#      'abs': 637.0367616409727}}}},
#  1.0: {32: {'flat': {'rmse': 393.55256085168816,
#     'max': 1176.628290911256,
#     'min': -1248.330465472763,
#     'abs': -6.292985744085763},
#    'hh': {2: {'rmse': 484.05697670741193,
#      'max': 1674.293351416953,
#      'min': -2190.389111677734,
#      'abs': -19.195577007799958},
#     3: {'rmse': 977.0448596226531,
#      'max': 3993.09222510144,
#      'min': -2843.174888761256,
#      'abs': -12.617473394643294},
#     4: {'rmse': 807.8879576852686,
#      'max': 3658.88530629268,
#      'min': -2787.1407590064327,
#      'abs': 12.296554250453195}}},
#   128: {'flat': {'rmse': 2073.7269813785324,
#     'max': 6714.305924882869,
#     'min': -6271.469777454292,
#     'abs': 35.31768848559711},
#    'hh': {2: {'rmse': 2679.544418028559,
#      'max': 9170.743790472712,
#      'min': -8554.247513387338,
#      'abs': 67.96712900505433},
#     3: {'rmse': 3798.3592202822865,
#      'max': 15879.272526100154,
#      'min': -12968.631217924823,
#      'abs': 19.721293187077478},
#     4: {'rmse': 4037.733348683495,
#      'max': 14319.079263889555,
#      'min': -18018.686184886494,
#      'abs': 73.19113121111496}}},
#   256: {'flat': {'rmse': 6313.721842215051,
#     'max': 20011.643748965114,
#     'min': -17572.63707055278,
#     'abs': -210.1276236491107},
#    'hh': {2: {'rmse': 5660.823131995379,
#      'max': 22291.453586297346,
#      'min': -24218.4284233133,
#      'abs': 52.36226626654773},
#     3: {'rmse': 9702.35996479063,
#      'max': 35465.399169373995,
#      'min': -35397.34728516902,
#      'abs': -91.30356930839093},
#     4: {'rmse': 5839.058491761602,
#      'max': 21705.05495071927,
#      'min': -21196.548817237803,
#      'abs': 228.87254453716605}}},
#   512: {'flat': {'rmse': 16032.066988873026,
#     'max': 46604.11949645133,
#     'min': -47437.363439641435,
#     'abs': 234.86966725058082},
#    'hh': {2: {'rmse': 12431.498969192737,
#      'max': 52202.76073189023,
#      'min': -38177.070277777675,
#      'abs': -137.80070580379348},
#     3: {'rmse': 14547.925410493981,
#      'max': 45894.00583652571,
#      'min': -49756.344331753644,
#      'abs': -538.3314725101884},
#     4: {'rmse': 18915.996307019883,
#      'max': 76742.23601056504,
#      'min': -77650.7464252566,
#      'abs': -515.6179272568127}}},
#   1024: {'flat': {'rmse': 36245.10096124835,
#     'max': 116939.68292892478,
#     'min': -147119.19157712904,
#     'abs': -185.29316861945978},
#    'hh': {2: {'rmse': 25827.563370210155,
#      'max': 114043.39988311926,
#      'min': -109926.00546224104,
#      'abs': 879.5264694276826},
#     3: {'rmse': 39202.07958621369,
#      'max': 168157.18487059197,
#      'min': -119178.0702093457,
#      'abs': 1442.7140255936197},
#     4: {'rmse': 27150.04085985932,
#      'max': 113031.80760271533,
#      'min': -84779.02772707923,
#      'abs': -303.41083910677173}}},
#   2048: {'flat': {'rmse': 83742.61335168092,
#     'max': 252391.17720775527,
#     'min': -340982.23266762844,
#     'abs': -463.2982674591361},
#    'hh': {2: {'rmse': 52947.89991420441,
#      'max': 207256.08298284776,
#      'min': -211777.14486084483,
#      'abs': 873.2389845124158},
#     3: {'rmse': 53247.67281580247,
#      'max': 228058.72810264415,
#      'min': -237931.0480242828,
#      'abs': -354.1585648848014},
#     4: {'rmse': 78857.6141559318,
#      'max': 280098.7303405303,
#      'min': -277184.8654153901,
#      'abs': -1446.718221607402}}}},
#  0.8: {32: {'flat': {'rmse': 455.6576103609734,
#     'max': 1383.7241064067784,
#     'min': -1412.8059513899084,
#     'abs': -5.727247305764636},
#    'hh': {2: {'rmse': 673.0530496443848,
#      'max': 2683.804917431283,
#      'min': -3820.128753804534,
#      'abs': -24.053585802170463},
#     3: {'rmse': 1089.4407620586007,
#      'max': 4050.0182444374022,
#      'min': -3244.3415136030208,
#      'abs': 7.952751313030027},
#     4: {'rmse': 924.1564554666669,
#      'max': 3923.697334604668,
#      'min': -3233.2338502415723,
#      'abs': -119.51471009438625}}},
#   128: {'flat': {'rmse': 2217.82967616321,
#     'max': 8641.20023639691,
#     'min': -7678.678613839941,
#     'abs': 35.70259199253695},
#    'hh': {2: {'rmse': 3106.328903356401,
#      'max': 10232.802092854921,
#      'min': -12300.532298843747,
#      'abs': -19.13817088168005},
#     3: {'rmse': 4462.894666069969,
#      'max': 17045.654123659173,
#      'min': -16635.38603802393,
#      'abs': -132.87052200719282},
#     4: {'rmse': 4811.148546628369,
#      'max': 17676.173144292905,
#      'min': -20370.236825016764,
#      'abs': 34.409419386912276}}},
#   256: {'flat': {'rmse': 7665.746047487537,
#     'max': 21701.241427932182,
#     'min': -24067.997368624838,
#     'abs': 21.224195247432455},
#    'hh': {2: {'rmse': 6435.457797294988,
#      'max': 28025.85276055461,
#      'min': -23132.497979401604,
#      'abs': 207.64662999589174},
#     3: {'rmse': 12389.692811601619,
#      'max': 51338.258215826696,
#      'min': -44134.434266406395,
#      'abs': 199.08352711562222},
#     4: {'rmse': 7026.6286141999435,
#      'max': 25633.793707457087,
#      'min': -25125.35724584489,
#      'abs': -117.37115963380243}}},
#   512: {'flat': {'rmse': 20731.720475549817,
#     'max': 63571.31541488947,
#     'min': -65107.33906419756,
#     'abs': 487.40670763955603},
#    'hh': {2: {'rmse': 14828.4025924055,
#      'max': 54588.019358535996,
#      'min': -47114.04748862825,
#      'abs': 391.27490174826653},
#     3: {'rmse': 18303.14742527161,
#      'max': 59194.59690125141,
#      'min': -56110.059190364365,
#      'abs': 307.57239359240884},
#     4: {'rmse': 23278.061418928763,
#      'max': 91476.25956792783,
#      'min': -79385.88736404772,
#      'abs': 378.35787820722004}}},
#   1024: {'flat': {'rmse': 42351.581095072506,
#     'max': 152172.60632995065,
#     'min': -149119.6789506715,
#     'abs': 329.0586567651667},
#    'hh': {2: {'rmse': 31175.0655168591,
#      'max': 141650.5615059399,
#      'min': -129198.69384043329,
#      'abs': -75.41886865643579},
#     3: {'rmse': 47588.18182610942,
#      'max': 196545.48251005827,
#      'min': -148251.73828556156,
#      'abs': -157.20929729732444},
#     4: {'rmse': 32010.811358411698,
#      'max': 134218.05704586874,
#      'min': -91872.40563634827,
#      'abs': 4.234561390335252}}},
#   2048: {'flat': {'rmse': 100658.120667467,
#     'max': 293879.4621345827,
#     'min': -342438.4527231029,
#     'abs': 466.38217415739484},
#    'hh': {2: {'rmse': 64510.592461074884,
#      'max': 260365.30261590576,
#      'min': -278062.13098939444,
#      'abs': -3573.5593681964224},
#     3: {'rmse': 64412.52856864486,
#      'max': 332966.76205497974,
#      'min': -252515.47082637687,
#      'abs': 1153.194701345294},
#     4: {'rmse': 98820.6664774449,
#      'max': 454049.12980106164,
#      'min': -364157.50491332053,
#      'abs': -292.38113002215607}}}},
#  0.6: {32: {'flat': {'rmse': 537.1641319442599,
#     'max': 1682.2445507269194,
#     'min': -1784.4533966506183,
#     'abs': 47.20710708415407},
#    'hh': {2: {'rmse': 745.2036434640204,
#      'max': 2715.467624957856,
#      'min': -2919.2825950523206,
#      'abs': 3.6150039258990336},
#     3: {'rmse': 1368.1579954993936,
#      'max': 4712.209656529709,
#      'min': -4433.266766200055,
#      'abs': -75.84943754071372},
#     4: {'rmse': 1168.192414337648,
#      'max': 3845.153269259956,
#      'min': -3881.598744746548,
#      'abs': 79.38886896126448}}},
#   128: {'flat': {'rmse': 3103.989389455836,
#     'max': 10939.430747420736,
#     'min': -9563.195354409847,
#     'abs': 40.45372267542808},
#    'hh': {2: {'rmse': 3827.1441426426777,
#      'max': 14441.421900289242,
#      'min': -12623.712610559138,
#      'abs': -15.679151890246827},
#     3: {'rmse': 5769.721388127131,
#      'max': 21890.80953906757,
#      'min': -17802.504882583373,
#      'abs': 122.80894596070384},
#     4: {'rmse': 5926.506827837545,
#      'max': 22583.36950206714,
#      'min': -19227.68984963105,
#      'abs': 115.1421731922965}}},
#   256: {'flat': {'rmse': 9403.119364895672,
#     'max': 29637.782154872446,
#     'min': -30271.15620198188,
#     'abs': 248.33290887878522},
#    'hh': {2: {'rmse': 8137.093327511457,
#      'max': 40153.69138924218,
#      'min': -31482.371844888978,
#      'abs': 61.00801961335455},
#     3: {'rmse': 14710.65722310981,
#      'max': 52417.746466213364,
#      'min': -51691.391342707604,
#      'abs': 825.5077024147079},
#     4: {'rmse': 8723.912255327677,
#      'max': 33647.1857946021,
#      'min': -29736.642016548838,
#      'abs': -75.69858544398919}}},
#   512: {'flat': {'rmse': 23426.972834287677,
#     'max': 76674.83252346431,
#     'min': -84083.18919790702,
#     'abs': 18.49425606555494},
#    'hh': {2: {'rmse': 18563.007711130096,
#      'max': 61034.59661605641,
#      'min': -57750.81146174506,
#      'abs': -462.1235980655739},
#     3: {'rmse': 22057.484287517582,
#      'max': 88287.42963329943,
#      'min': -69613.0995309365,
#      'abs': -426.29403354953286},
#     4: {'rmse': 27833.412443482823,
#      'max': 106890.07682080602,
#      'min': -83841.29637260169,
#      'abs': 146.14704426835812}}},
#   1024: {'flat': {'rmse': 50498.823724639245,
#     'max': 168432.5194161047,
#     'min': -159244.37674392492,
#     'abs': 983.4504749261883},
#    'hh': {2: {'rmse': 38455.62684956983,
#      'max': 165803.55502769043,
#      'min': -189244.26312950545,
#      'abs': -14.00030350508634},
#     3: {'rmse': 59326.15133786198,
#      'max': 217868.43489960022,
#      'min': -221109.69888678996,
#      'abs': 51.637705815984496},
#     4: {'rmse': 39915.44636556334,
#      'max': 167421.80572799203,
#      'min': -139018.20688845793,
#      'abs': -247.38401274731189}}},
#   2048: {'flat': {'rmse': 122701.30979407176,
#     'max': 484066.6675120207,
#     'min': -478401.7465604368,
#     'abs': 1547.4335239585455},
#    'hh': {2: {'rmse': 79210.74469045803,
#      'max': 323638.60522712994,
#      'min': -307027.2235841922,
#      'abs': 1117.8170803882572},
#     3: {'rmse': 78550.4206901147,
#      'max': 326654.1931586856,
#      'min': -282772.0313261211,
#      'abs': 930.271529045665},
#     4: {'rmse': 119122.63371087215,
#      'max': 455933.109310817,
#      'min': -422640.41298701,
#      'abs': 1245.9917490940225}}}},
#  0.4: {32: {'flat': {'rmse': 706.5575082304506,
#     'max': 1917.8758288700042,
#     'min': -2104.4482208322734,
#     'abs': -9.064668828805562},
#    'hh': {2: {'rmse': 888.0558499248648,
#      'max': 2830.1023505700186,
#      'min': -2379.713544977139,
#      'abs': 13.404883791303797},
#     3: {'rmse': 1520.0415169047653,
#      'max': 5312.640538380824,
#      'min': -5698.699232294876,
#      'abs': -47.339798465109595},
#     4: {'rmse': 1419.2025260095745,
#      'max': 4509.746092579831,
#      'min': -4218.732432558665,
#      'abs': -9.590304818256635}}},
#   128: {'flat': {'rmse': 3516.2006824809264,
#     'max': 11016.960148190195,
#     'min': -11991.13841775314,
#     'abs': 68.75167760736491},
#    'hh': {2: {'rmse': 4215.6358976710035,
#      'max': 18940.617117169408,
#      'min': -13546.144950750542,
#      'abs': -43.4248700090725},
#     3: {'rmse': 6367.5589895778085,
#      'max': 23509.36206233512,
#      'min': -21544.21530390458,
#      'abs': 142.97528423103566},
#     4: {'rmse': 6564.109487232008,
#      'max': 25233.590397560525,
#      'min': -21477.614188793585,
#      'abs': -123.26081250121474}}},
#   256: {'flat': {'rmse': 11141.491776764387,
#     'max': 34001.888164964694,
#     'min': -38762.79909501776,
#     'abs': 249.76937445897488},
#    'hh': {2: {'rmse': 9384.958221585663,
#      'max': 37086.62825801521,
#      'min': -34158.83471493107,
#      'abs': -35.00555630401154},
#     3: {'rmse': 16674.753288445856,
#      'max': 65710.26456972552,
#      'min': -52563.24546075159,
#      'abs': 530.8308898176753},
#     4: {'rmse': 9654.68784435109,
#      'max': 51812.02282863369,
#      'min': -34635.39625449965,
#      'abs': 332.7054146628147}}},
#   512: {'flat': {'rmse': 30578.862275470034,
#     'max': 99876.0402889786,
#     'min': -111027.48834783895,
#     'abs': -370.6038936340221},
#    'hh': {2: {'rmse': 19800.271613017965,
#      'max': 83551.64727998718,
#      'min': -65685.03316592607,
#      'abs': 347.97083441666683},
#     3: {'rmse': 25515.0993743136,
#      'max': 87865.33376278257,
#      'min': -76098.714087825,
#      'abs': 0.29157584455315955},
#     4: {'rmse': 32047.680688124798,
#      'max': 108656.17716872212,
#      'min': -107216.55776288647,
#      'abs': 182.98778141268258}}},
#   1024: {'flat': {'rmse': 65798.82446611278,
#     'max': 239537.01097760422,
#     'min': -188459.91882805488,
#     'abs': -750.8228465039225},
#    'hh': {2: {'rmse': 41960.206314503615,
#      'max': 170488.27040794608,
#      'min': -139349.30071398226,
#      'abs': 1507.5190033027463},
#     3: {'rmse': 62275.19266452826,
#      'max': 282776.452936839,
#      'min': -204434.4205384128,
#      'abs': -779.6076833480007},
#     4: {'rmse': 44176.84428110686,
#      'max': 182267.14481913092,
#      'min': -146651.5156850353,
#      'abs': 239.2921484593917}}},
#   2048: {'flat': {'rmse': 150741.3481397312,
#     'max': 525900.515687413,
#     'min': -448824.4529234446,
#     'abs': 1476.6812742170719},
#    'hh': {2: {'rmse': 87030.22409515601,
#      'max': 363560.1968773322,
#      'min': -291933.38545581326,
#      'abs': 2875.1838987931305},
#     3: {'rmse': 84426.72118965662,
#      'max': 354431.04304091656,
#      'min': -283116.550294867,
#      'abs': 2770.0407616854286},
#     4: {'rmse': 135709.88342020012,
#      'max': 599577.0063689016,
#      'min': -402564.9590366919,
#      'abs': 6747.917889206225}}}},
#  0.2: {32: {'flat': {'rmse': 790.57427693593,
#     'max': 2753.7838486578075,
#     'min': -2246.449833444826,
#     'abs': -11.259063406551537},
#    'hh': {2: {'rmse': 1073.7429600920427,
#      'max': 3521.6725792549023,
#      'min': -4327.221040520108,
#      'abs': 17.327277487573742},
#     3: {'rmse': 1862.1530543169656,
#      'max': 6682.274791493123,
#      'min': -5595.9597733446535,
#      'abs': -52.13890118017978},
#     4: {'rmse': 1519.671828784403,
#      'max': 5377.593070208206,
#      'min': -5048.472259610242,
#      'abs': -2.0713211942891996}}},
#   128: {'flat': {'rmse': 4508.032509528745,
#     'max': 17041.71678532202,
#     'min': -16371.585797203548,
#     'abs': -88.22707576539523},
#    'hh': {2: {'rmse': 4951.132464042323,
#      'max': 18076.33961592361,
#      'min': -16940.181479737133,
#      'abs': -10.019003212066426},
#     3: {'rmse': 7104.719310512776,
#      'max': 28315.79827271362,
#      'min': -30778.05334426382,
#      'abs': -82.71530806520151},
#     4: {'rmse': 7847.814884033327,
#      'max': 30548.842706762414,
#      'min': -25998.219052253404,
#      'abs': 291.50317825015065}}},
#   256: {'flat': {'rmse': 14773.63728921201,
#     'max': 47211.307735752554,
#     'min': -51703.90204674826,
#     'abs': -359.84019647973645},
#    'hh': {2: {'rmse': 11122.314844904009,
#      'max': 52618.72330001654,
#      'min': -43754.79788214601,
#      'abs': -89.79135899200803},
#     3: {'rmse': 20009.619912100545,
#      'max': 100915.15082260664,
#      'min': -72829.50895950185,
#      'abs': 372.6935525291666},
#     4: {'rmse': 11256.164466189033,
#      'max': 46383.8323391917,
#      'min': -40684.866401856554,
#      'abs': 348.28271373942545}}},
#   512: {'flat': {'rmse': 33938.55917563308,
#     'max': 102417.1147917147,
#     'min': -107568.56393829246,
#     'abs': -1015.4752050462059},
#    'hh': {2: {'rmse': 24241.35062424899,
#      'max': 109571.86355767587,
#      'min': -84064.3307367069,
#      'abs': -394.32521663016496},
#     3: {'rmse': 29879.095823455777,
#      'max': 120267.44437586372,
#      'min': -95506.62649437056,
#      'abs': -998.660807443155},
#     4: {'rmse': 37882.632913775786,
#      'max': 133145.5587584338,
#      'min': -120990.6140509149,
#      'abs': -417.16807238428663}}},
#   1024: {'flat': {'rmse': 79495.40577190835,
#     'max': 288831.8507202086,
#     'min': -312680.664964916,
#     'abs': 1135.3218490124445},
#    'hh': {2: {'rmse': 50515.3969292142,
#      'max': 193006.82179811347,
#      'min': -212702.01520058612,
#      'abs': -276.36342451962474},
#     3: {'rmse': 78718.67549712655,
#      'max': 267631.38783844106,
#      'min': -208516.8363745246,
#      'abs': 757.4858672995637},
#     4: {'rmse': 54601.09057234685,
#      'max': 283231.05601193605,
#      'min': -171420.48511135008,
#      'abs': 1292.6223858485967}}},
#   2048: {'flat': {'rmse': 194148.37603147965,
#     'max': 595462.5008935978,
#     'min': -704350.1857641144,
#     'abs': 4418.637094347932},
#    'hh': {2: {'rmse': 106491.6385996339,
#      'max': 440570.1607770199,
#      'min': -430864.12655449193,
#      'abs': 734.1264626243038},
#     3: {'rmse': 109293.6142476022,
#      'max': 593403.1289029339,
#      'min': -381377.20428794104,
#      'abs': -2311.0692071843855},
#     4: {'rmse': 162001.11843851118,
#      'max': 800145.0757934904,
#      'min': -674579.1941718912,
#      'abs': -1472.4002628909857}}}}}

# %%
def make_hh_errors_dict(epsilons, n, degrees):
    epsilon_dict = dict.fromkeys(epsilons)
    
    for e_key in epsilon_dict:
        #print(e_key)
        epsilon_dict[e_key] = dict.fromkeys(n)
        n_dict = epsilon_dict[e_key]
        #print(epsilon_dict[e_key])
        for n_key in n_dict:
            n_dict[n_key] = dict.fromkeys(['flat', 'hh'])
            n_dict[n_key]['flat'] = dict.fromkeys(degrees)
            n_dict[n_key]['hh'] = dict.fromkeys(degrees)

        #print(epsilon_dict)
    return epsilon_dict

def fill_up_hh_errors_dict(epsilons, n, degrees, flat_est_dict, flat_cor_dict, hh_est_dict, hh_cor_dict):
    dict_ = make_hh_errors_dict(epsilons, n, degrees)
    for e in epsilons:
        for N in n:
            for degree in degrees:

                flat_cor = flat_cor_dict[e][N][degree]
                flat_est = flat_est_dict[e][N][degree]

                hh_cor = hh_cor_dict[e][N][degree]
                hh_est = hh_est_dict[e][N][degree]
                #print(f'e = {e}, n = {n} degree = {degree}' )
                
                if len(flat_est) !=0 or len(flat_cor) !=0 or  len(hh_est) !=0 or  len(hh_cor) !=0 :
                    dict_[e][N]['flat'][degree] = find_error_different_queries(flat_est, flat_cor) 
                    dict_[e][N]['hh'][degree] = find_error_different_queries(hh_est, hh_cor)
                    
    return dict_

# %%
cen_hh_error_dict = fill_up_hh_errors_dict(epsilons, n, degrees, cen_flat_est_hh_dict, cen_flat_cor_hh_dict, cen_hh_est_hh_dict, cen_hh_cor_hh_dict)
cen_hh_error_dict
# Out:
# {2.0: {32: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   128: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   256: {'flat': {2: {'rmse': 4.82065288956576,
#      'max': 16.665395765527137,
#      'min': -17.197702962475887,
#      'abs': -0.03307960028196139},
#     3: {'rmse': 9.605424228449289,
#      'max': 19.052149655857647,
#      'min': -28.632124668598408,
#      'abs': -0.22192147126585768},
#     4: {'rmse': 9.541878470981406,
#      'max': 21.81540628977382,
#      'min': -29.206055937444034,
#      'abs': -0.1355722060546017}},
#    'hh': {2: {'rmse': 8.951119036657905,
#      'max': 37.82017063243984,
#      'min': -35.97690266894824,
#      'abs': -0.04697081298857738},
#     3: {'rmse': 9.15678800707594,
#      'max': 27.272816347613116,
#      'min': -28.342473856340803,
#      'abs': 0.8047636002785846},
#     4: {'rmse': 7.082766941735129,
#      'max': 31.319013421867567,
#      'min': -20.582127696943644,
#      'abs': -0.5850140294202574}}},
#   512: {'flat': {2: {'rmse': 13.804155795355697,
#      'max': 54.62443262929446,
#      'min': -28.813779921998503,
#      'abs': 2.447890834805847},
#     3: {'rmse': 12.20314212433648,
#      'max': 46.33111285988707,
#      'min': -27.550380946922814,
#      'abs': 1.5701311697746219},
#     4: {'rmse': 12.322748425619842,
#      'max': 50.65729075710988,
#      'min': -27.840469556031167,
#      'abs': 1.3391922209058509}},
#    'hh': {2: {'rmse': 12.915015355533155,
#      'max': 33.789502984582214,
#      'min': -43.37827197667502,
#      'abs': -3.314251431552932},
#     3: {'rmse': 8.989131146995545,
#      'max': 42.03659457604226,
#      'min': -24.76391682602116,
#      'abs': 1.8903646151368185},
#     4: {'rmse': 9.44334578715405,
#      'max': 37.13009402645548,
#      'min': -32.32077401650895,
#      'abs': 1.7007300433930825}}},
#   1024: {'flat': {2: {'rmse': 14.01423475798044,
#      'max': 42.70538083855354,
#      'min': -34.381116494128946,
#      'abs': 2.295785708850849},
#     3: {'rmse': 14.57447166486251,
#      'max': 43.909854121739045,
#      'min': -30.88013133118511,
#      'abs': 2.1938879485694227},
#     4: {'rmse': 11.377837360606762,
#      'max': 37.90012195367308,
#      'min': -32.40332335390849,
#      'abs': 1.3451861106071854}},
#    'hh': {2: {'rmse': 12.494200266473513,
#      'max': 37.92468125920277,
#      'min': -49.484894031484146,
#      'abs': -0.13436961604356765},
#     3: {'rmse': 9.855397035809482,
#      'max': 37.28157951806497,
#      'min': -39.51457562424184,
#      'abs': 0.8657441715589317},
#     4: {'rmse': 8.649156551616946,
#      'max': 27.513962054552394,
#      'min': -36.668934138120676,
#      'abs': -0.8755092602428107}}},
#   2048: {'flat': {2: {'rmse': 15.938833164688383,
#      'max': 45.46667815328692,
#      'min': -51.75982858588395,
#      'abs': -0.5688942557456321},
#     3: {'rmse': 19.424142361971217,
#      'max': 57.58632681230665,
#      'min': -64.84214216368855,
#      'abs': -0.40144262083488286},
#     4: {'rmse': 13.168842625240094,
#      'max': 41.6541300205281,
#      'min': -47.03233754687244,
#      'abs': -0.5208903956135124}},
#    'hh': {2: {'rmse': 13.35848039383354,
#      'max': 52.89765342413739,
#      'min': -43.89263125535217,
#      'abs': -0.3591736057367059},
#     3: {'rmse': 9.985308862427337,
#      'max': 35.98072133192909,
#      'min': -36.14801865874324,
#      'abs': 0.5540854818782187},
#     4: {'rmse': 9.07753658733469,
#      'max': 29.94503823519335,
#      'min': -30.582022270638845,
#      'abs': 0.05259018359212205}}}},
#  1.4: {32: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   128: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   256: {'flat': {2: {'rmse': 6.634059671472293,
#      'max': 18.681996135690497,
#      'min': -22.094710100145676,
#      'abs': -0.694200154711627},
#     3: {'rmse': 15.293532984931348,
#      'max': 28.722109385562362,
#      'min': -39.27139532403817,
#      'abs': -2.9013283197593904},
#     4: {'rmse': 13.879800984404605,
#      'max': 34.54909433754801,
#      'min': -39.73992971770349,
#      'abs': -2.742666674531993}},
#    'hh': {2: {'rmse': 12.324260125482292,
#      'max': 52.45149144680727,
#      'min': -40.29156826984763,
#      'abs': 0.4762299574640765},
#     3: {'rmse': 12.431515089068595,
#      'max': 43.3940303207346,
#      'min': -42.45028732856008,
#      'abs': 0.8419267951457121},
#     4: {'rmse': 9.239786611029848,
#      'max': 32.96073254161456,
#      'min': -31.784394745140162,
#      'abs': 0.5503664397850166}}},
#   512: {'flat': {2: {'rmse': 21.50544009957563,
#      'max': 58.20135004472104,
#      'min': -54.982430390839,
#      'abs': -4.459818773574755},
#     3: {'rmse': 18.602416087144185,
#      'max': 54.84460663511709,
#      'min': -47.46679976697487,
#      'abs': -3.938652028722479},
#     4: {'rmse': 18.277328852614183,
#      'max': 53.90315107500646,
#      'min': -48.56636464083567,
#      'abs': -4.084754073672736}},
#    'hh': {2: {'rmse': 17.113947773861454,
#      'max': 53.08557789874612,
#      'min': -46.29816013909294,
#      'abs': -0.5109437262558088},
#     3: {'rmse': 13.984342827735876,
#      'max': 57.08861634132336,
#      'min': -45.365374314496876,
#      'abs': 2.809118285190771},
#     4: {'rmse': 12.006819348982765,
#      'max': 41.08129146405554,
#      'min': -33.240396904802765,
#      'abs': 2.730421869482292}}},
#   1024: {'flat': {2: {'rmse': 21.250772447656846,
#      'max': 83.05642309389077,
#      'min': -70.88581218633044,
#      'abs': 4.612306074523111},
#     3: {'rmse': 22.672800276908006,
#      'max': 83.07791331478802,
#      'min': -66.92536155937705,
#      'abs': 5.86407391264491},
#     4: {'rmse': 16.626315649942526,
#      'max': 64.10728477753582,
#      'min': -57.894469474565994,
#      'abs': 2.4642332605801696}},
#    'hh': {2: {'rmse': 17.650278025122944,
#      'max': 57.02607635948516,
#      'min': -73.37409608070448,
#      'abs': -1.1926448420202242},
#     3: {'rmse': 14.338107627036335,
#      'max': 51.14348875802534,
#      'min': -57.832629244730924,
#      'abs': -0.12020267907484085},
#     4: {'rmse': 11.778372916900606,
#      'max': 41.97386465486488,
#      'min': -48.562730354693485,
#      'abs': 1.1424731953187408}}},
#   2048: {'flat': {2: {'rmse': 23.74352074843637,
#      'max': 59.727530982519966,
#      'min': -72.57952067523729,
#      'abs': -2.9842809022433996},
#     3: {'rmse': 30.553288324693625,
#      'max': 70.97734885377577,
#      'min': -89.23857375010266,
#      'abs': -4.761175116133725},
#     4: {'rmse': 20.113777305020434,
#      'max': 51.044442138052545,
#      'min': -67.09833159238042,
#      'abs': -1.6742414165900992}},
#    'hh': {2: {'rmse': 18.227307198290642,
#      'max': 69.57131754804868,
#      'min': -62.82586032814288,
#      'abs': 1.1404651553630247},
#     3: {'rmse': 16.043990453193075,
#      'max': 64.36028901446844,
#      'min': -55.155686089914525,
#      'abs': 0.6559984131784178},
#     4: {'rmse': 13.420553561785686,
#      'max': 51.78499979697517,
#      'min': -62.44297413859749,
#      'abs': -0.9028982001687371}}}},
#  1.2: {32: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   128: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   256: {'flat': {2: {'rmse': 7.61801168912166,
#      'max': 26.55631974069729,
#      'min': -27.10671819406525,
#      'abs': 0.2481333356590985},
#     3: {'rmse': 14.971929855427556,
#      'max': 40.46986735106475,
#      'min': -35.520357683744805,
#      'abs': 2.122922406130194},
#     4: {'rmse': 13.373513654258117,
#      'max': 36.744520838867174,
#      'min': -33.68694618832524,
#      'abs': 1.656849044438466}},
#    'hh': {2: {'rmse': 13.82215757031543,
#      'max': 53.99806826081385,
#      'min': -58.89557462564153,
#      'abs': -0.0871848836698111},
#     3: {'rmse': 13.072691898355986,
#      'max': 54.13636985393532,
#      'min': -32.91158087669464,
#      'abs': 0.6608777884719195},
#     4: {'rmse': 12.594723392976443,
#      'max': 34.1377906364869,
#      'min': -45.15123356249387,
#      'abs': 0.9298459658035164}}},
#   512: {'flat': {2: {'rmse': 23.35284262247031,
#      'max': 69.63008646704839,
#      'min': -68.49607878045936,
#      'abs': -2.493916417161911},
#     3: {'rmse': 20.35080701085209,
#      'max': 63.17709767575434,
#      'min': -56.65923641162226,
#      'abs': -1.4889920150700084},
#     4: {'rmse': 20.4705006393349,
#      'max': 64.859581752753,
#      'min': -58.5520849727327,
#      'abs': -1.6809376437846921}},
#    'hh': {2: {'rmse': 19.064610602127104,
#      'max': 68.76734070376551,
#      'min': -62.668367830861825,
#      'abs': -0.24873396656184923},
#     3: {'rmse': 15.787402999575987,
#      'max': 41.3172177606757,
#      'min': -78.33741251337051,
#      'abs': -2.617251753429664},
#     4: {'rmse': 14.16130878106736,
#      'max': 42.16262117972656,
#      'min': -51.081686503275705,
#      'abs': -0.2554754431019683}}},
#   1024: {'flat': {2: {'rmse': 24.82458798328787,
#      'max': 68.0470422472572,
#      'min': -81.99724006603356,
#      'abs': -2.4346189217401495},
#     3: {'rmse': 25.263810529714,
#      'max': 65.0921722043422,
#      'min': -72.83659296021506,
#      'abs': -2.7681168627760315},
#     4: {'rmse': 20.78548675331994,
#      'max': 52.39247251948109,
#      'min': -62.648177168215625,
#      'abs': -1.2589001127252908}},
#    'hh': {2: {'rmse': 19.460209113609544,
#      'max': 75.64938511322543,
#      'min': -63.754105397863896,
#      'abs': 0.4418786407434498},
#     3: {'rmse': 15.113551564786713,
#      'max': 62.585481767586316,
#      'min': -59.87192438452621,
#      'abs': 1.5111045768301004},
#     4: {'rmse': 14.980101535862113,
#      'max': 48.55161482456606,
#      'min': -52.546850519182044,
#      'abs': -1.3824717042364443}}},
#   2048: {'flat': {2: {'rmse': 24.580380998839864,
#      'max': 77.22251490823692,
#      'min': -64.86738092760788,
#      'abs': 1.7285412046584476},
#     3: {'rmse': 29.29302947400159,
#      'max': 86.64804437954444,
#      'min': -94.65315125862253,
#      'abs': 1.667295838887256},
#     4: {'rmse': 20.905784498459926,
#      'max': 67.04539903381374,
#      'min': -69.9880599604221,
#      'abs': 1.432178337656494}},
#    'hh': {2: {'rmse': 20.477667577965697,
#      'max': 56.22983094396477,
#      'min': -84.76197920639243,
#      'abs': 1.023544639948639},
#     3: {'rmse': 17.056373062885132,
#      'max': 52.85212196482462,
#      'min': -66.61847786096041,
#      'abs': -0.14654157178975874},
#     4: {'rmse': 15.748290851077305,
#      'max': 79.11497522395803,
#      'min': -60.31685954137356,
#      'abs': -0.3912826020315726}}}},
#  1.0: {32: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   128: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   256: {'flat': {2: {'rmse': 9.241538872060337,
#      'max': 34.326079301965365,
#      'min': -30.67207863787553,
#      'abs': -0.010781709787421278},
#     3: {'rmse': 22.25671698096483,
#      'max': 53.96817797108088,
#      'min': -63.45817783743405,
#      'abs': -0.11406825990230428},
#     4: {'rmse': 21.225621957953,
#      'max': 57.249016227113316,
#      'min': -62.11515341127233,
#      'abs': -0.5360012437016878}},
#    'hh': {2: {'rmse': 15.795484373100468,
#      'max': 86.84072397031923,
#      'min': -69.42275179639819,
#      'abs': 1.800496310489704},
#     3: {'rmse': 17.97141359904794,
#      'max': 68.91224288405647,
#      'min': -38.906463860817894,
#      'abs': 5.043036156919052},
#     4: {'rmse': 14.596739849326582,
#      'max': 51.9179821815851,
#      'min': -48.99674534986116,
#      'abs': -1.2611330716833327}}},
#   512: {'flat': {2: {'rmse': 24.879875366039347,
#      'max': 66.58498969905486,
#      'min': -62.80752573507198,
#      'abs': 2.5394381738573606},
#     3: {'rmse': 21.609060147768894,
#      'max': 52.41009924739774,
#      'min': -71.10485522189992,
#      'abs': 2.2553501668705196},
#     4: {'rmse': 21.36626726514172,
#      'max': 55.214328114561795,
#      'min': -71.10485522189992,
#      'abs': 1.8464795010422268}},
#    'hh': {2: {'rmse': 21.84504938110855,
#      'max': 75.58850292694115,
#      'min': -79.09487243970216,
#      'abs': -2.2914531032750673},
#     3: {'rmse': 17.819752337719244,
#      'max': 63.04553294138168,
#      'min': -54.151455461345904,
#      'abs': 1.7782508659615879},
#     4: {'rmse': 18.671255249291764,
#      'max': 71.24434717063559,
#      'min': -66.56483110482804,
#      'abs': -0.07566599693913886}}},
#   1024: {'flat': {2: {'rmse': 34.949566524154726,
#      'max': 122.89573841051606,
#      'min': -75.84713632777857,
#      'abs': 5.902121147548995},
#     3: {'rmse': 37.22530524746665,
#      'max': 125.2475122193282,
#      'min': -74.89315380470362,
#      'abs': 6.92124920548285},
#     4: {'rmse': 27.41570416123196,
#      'max': 96.59948145609815,
#      'min': -70.90318762880634,
#      'abs': 4.461998164694844}},
#    'hh': {2: {'rmse': 23.84417959132859,
#      'max': 103.04829387336213,
#      'min': -121.95066069881432,
#      'abs': -1.8237784437840514},
#     3: {'rmse': 18.9339412535114,
#      'max': 76.24608762646676,
#      'min': -62.48595211155771,
#      'abs': -0.8318621638137381},
#     4: {'rmse': 17.722117662922,
#      'max': 60.21607381806825,
#      'min': -65.65055319456587,
#      'abs': -0.2707382002341561}}},
#   2048: {'flat': {2: {'rmse': 32.26419105178323,
#      'max': 118.25899248567293,
#      'min': -93.26119377446594,
#      'abs': 0.061640560102817835},
#     3: {'rmse': 42.610271110344264,
#      'max': 154.80245482583996,
#      'min': -116.4046984789311,
#      'abs': -0.9669483899950865},
#     4: {'rmse': 26.619089986267852,
#      'max': 90.45477216586005,
#      'min': -83.15031452098629,
#      'abs': -0.5927050469575246}},
#    'hh': {2: {'rmse': 25.050035079340667,
#      'max': 88.8675874727196,
#      'min': -91.43008687043039,
#      'abs': 1.5127326070923242},
#     3: {'rmse': 22.52538320897494,
#      'max': 70.98366735453601,
#      'min': -87.21191002236446,
#      'abs': -1.9533232143523753},
#     4: {'rmse': 19.703855314716574,
#      'max': 59.568198421635316,
#      'min': -81.25083168323908,
#      'abs': -2.226610738036045}}}},
#  0.8: {32: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   128: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   256: {'flat': {2: {'rmse': 11.525469317719814,
#      'max': 35.357715194200864,
#      'min': -40.22815648555934,
#      'abs': -0.2579027122856951},
#     3: {'rmse': 28.46014875766976,
#      'max': 68.46781892211584,
#      'min': -72.19834598868329,
#      'abs': 1.1526074483254256},
#     4: {'rmse': 25.12711929751974,
#      'max': 56.031821476375626,
#      'min': -65.82798389767413,
#      'abs': 0.24082518651894935}},
#    'hh': {2: {'rmse': 20.81026092528639,
#      'max': 65.63965242465565,
#      'min': -67.30452740780493,
#      'abs': -0.46003373776875994},
#     3: {'rmse': 18.87150708977978,
#      'max': 65.37889012032974,
#      'min': -60.95890412419976,
#      'abs': -1.7239116493984912},
#     4: {'rmse': 17.176883886298953,
#      'max': 82.03966735584254,
#      'min': -51.82501227942703,
#      'abs': -0.3232144236048276}}},
#   512: {'flat': {2: {'rmse': 31.29156324027412,
#      'max': 95.42736035003327,
#      'min': -86.81083358221804,
#      'abs': -5.417258486329246},
#     3: {'rmse': 28.018602172719596,
#      'max': 84.77634054415103,
#      'min': -84.45378595829243,
#      'abs': -4.29233173640366},
#     4: {'rmse': 28.088594414798777,
#      'max': 87.11268190483679,
#      'min': -83.49006341323548,
#      'abs': -3.881337013793414}},
#    'hh': {2: {'rmse': 28.750372657244448,
#      'max': 88.05175285151927,
#      'min': -92.73832706114626,
#      'abs': -0.9770507681428978},
#     3: {'rmse': 21.84176250111637,
#      'max': 77.40818075145944,
#      'min': -69.26695503707742,
#      'abs': 2.9708427439761262},
#     4: {'rmse': 22.64452720659567,
#      'max': 87.37236566105275,
#      'min': -66.31451679234306,
#      'abs': 1.8317029123126645}}},
#   1024: {'flat': {2: {'rmse': 35.27527800403646,
#      'max': 139.76338884001598,
#      'min': -122.56213774104253,
#      'abs': -0.20385210975070367},
#     3: {'rmse': 37.70672762259517,
#      'max': 144.2803319732775,
#      'min': -124.40186277567409,
#      'abs': -0.0007995767568820156},
#     4: {'rmse': 29.369859584463256,
#      'max': 108.88420709883212,
#      'min': -88.46185160438472,
#      'abs': -0.2590291145461466}},
#    'hh': {2: {'rmse': 30.442265620844758,
#      'max': 106.7392378851655,
#      'min': -122.99554004291713,
#      'abs': 1.9432222035893938},
#     3: {'rmse': 23.42295165511663,
#      'max': 74.54005280038109,
#      'min': -84.82901709871658,
#      'abs': -0.7479514081280446},
#     4: {'rmse': 20.473536124013492,
#      'max': 96.53723433397681,
#      'min': -93.52913883305155,
#      'abs': 0.6230858300459746}}},
#   2048: {'flat': {2: {'rmse': 38.498100271846525,
#      'max': 145.81132005630934,
#      'min': -121.38147422700422,
#      'abs': 4.733920982677245},
#     3: {'rmse': 46.192973841861026,
#      'max': 164.8831114124041,
#      'min': -167.25863730206038,
#      'abs': 6.82850793483227},
#     4: {'rmse': 31.602989336272124,
#      'max': 123.82576075127872,
#      'min': -98.40393124258844,
#      'abs': 3.244248117167334}},
#    'hh': {2: {'rmse': 32.57593099974789,
#      'max': 141.95953985693632,
#      'min': -166.2207522103272,
#      'abs': -1.0135909621378407},
#     3: {'rmse': 27.42993119430731,
#      'max': 127.65367364152917,
#      'min': -78.152200602839,
#      'abs': 2.685825740453601},
#     4: {'rmse': 23.213942540647594,
#      'max': 102.21769212307117,
#      'min': -86.64690889917256,
#      'abs': 1.4633332698042125}}}},
#  0.6: {32: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   128: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   256: {'flat': {2: {'rmse': 15.33781704916544,
#      'max': 64.11175633631683,
#      'min': -44.52322927358,
#      'abs': -1.2318032312333658},
#     3: {'rmse': 34.66688283801703,
#      'max': 92.02374988320662,
#      'min': -110.01021529349964,
#      'abs': -6.742096989559723},
#     4: {'rmse': 32.934300157085964,
#      'max': 94.55047156175715,
#      'min': -97.5550437822094,
#      'abs': -5.009044998623323}},
#    'hh': {2: {'rmse': 25.771644734059755,
#      'max': 90.49519852120102,
#      'min': -117.04468526250821,
#      'abs': -0.3858921397894643},
#     3: {'rmse': 25.782255100752902,
#      'max': 63.56293755507795,
#      'min': -97.15534664203005,
#      'abs': 2.954340738314687},
#     4: {'rmse': 20.248261641441708,
#      'max': 77.42571128422423,
#      'min': -61.85122851782944,
#      'abs': 0.2361659486095159}}},
#   512: {'flat': {2: {'rmse': 45.30506440097401,
#      'max': 104.92914089467376,
#      'min': -156.4654287444573,
#      'abs': 4.105170885165955},
#     3: {'rmse': 38.439060564046606,
#      'max': 103.21600477297034,
#      'min': -146.95959735606448,
#      'abs': 1.610597532731673},
#     4: {'rmse': 37.96553093055496,
#      'max': 109.15382947507896,
#      'min': -142.31243790732697,
#      'abs': 2.0701031183593295}},
#    'hh': {2: {'rmse': 38.32678707464223,
#      'max': 124.94081745922449,
#      'min': -134.17600708919053,
#      'abs': -3.7898385934453747},
#     3: {'rmse': 28.480533682356132,
#      'max': 113.71642676733609,
#      'min': -123.81709097281419,
#      'abs': -0.24243872705309186},
#     4: {'rmse': 30.724039880358344,
#      'max': 114.67017773055704,
#      'min': -92.52119840623345,
#      'abs': 1.6782512123116118}}},
#   1024: {'flat': {2: {'rmse': 52.23127377665363,
#      'max': 134.30573691886093,
#      'min': -178.34042978478828,
#      'abs': -9.266397555782524},
#     3: {'rmse': 56.105104426669755,
#      'max': 164.214860185195,
#      'min': -191.1262455971737,
#      'abs': -11.177677053438767},
#     4: {'rmse': 42.24710235196345,
#      'max': 142.02765832272416,
#      'min': -154.02046468641493,
#      'abs': -7.084911918971539}},
#    'hh': {2: {'rmse': 38.85813429743642,
#      'max': 142.31250588526018,
#      'min': -151.97467886688537,
#      'abs': 0.751986619106715},
#     3: {'rmse': 32.06437202284849,
#      'max': 126.09253089994309,
#      'min': -121.32780624058796,
#      'abs': -1.7521556648088967},
#     4: {'rmse': 26.588083456182538,
#      'max': 104.08705000503687,
#      'min': -112.81939537730796,
#      'abs': 2.0821205550489976}}},
#   2048: {'flat': {2: {'rmse': 56.18468294624003,
#      'max': 170.21397409160272,
#      'min': -180.07710551032505,
#      'abs': 0.026238141915854066},
#     3: {'rmse': 67.01582059550671,
#      'max': 176.4169926570612,
#      'min': -216.44914522994077,
#      'abs': 0.5722458495924365},
#     4: {'rmse': 45.059573883164674,
#      'max': 152.4834024992888,
#      'min': -136.36070090220164,
#      'abs': -0.23529479789907637}},
#    'hh': {2: {'rmse': 43.32142339190836,
#      'max': 141.97977004095446,
#      'min': -169.8876828129287,
#      'abs': -6.1241931618759935},
#     3: {'rmse': 36.52404606561899,
#      'max': 164.7830084307352,
#      'min': -107.97465293481946,
#      'abs': 4.203916971404618},
#     4: {'rmse': 30.902676726186204,
#      'max': 125.24949651265342,
#      'min': -132.29793379102193,
#      'abs': -0.3930854616251367}}}},
#  0.4: {32: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   128: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   256: {'flat': {2: {'rmse': 23.327137553265676,
#      'max': 70.09376582496952,
#      'min': -64.29211032366038,
#      'abs': 0.039088392807416314},
#     3: {'rmse': 48.22309428909309,
#      'max': 173.85157830156095,
#      'min': -110.09695045841363,
#      'abs': 2.930140467701963},
#     4: {'rmse': 47.35655706142684,
#      'max': 175.24624920957285,
#      'min': -111.95012781764672,
#      'abs': 3.1268968569581834}},
#    'hh': {2: {'rmse': 40.35102677946489,
#      'max': 141.39603128875024,
#      'min': -144.73937006026154,
#      'abs': -5.624519638906446},
#     3: {'rmse': 40.048393594474504,
#      'max': 150.20562605027953,
#      'min': -103.68728243237274,
#      'abs': 1.479648784559383},
#     4: {'rmse': 38.749303439672055,
#      'max': 121.61461206387321,
#      'min': -140.46107259385462,
#      'abs': -3.497131610060789}}},
#   512: {'flat': {2: {'rmse': 70.40938210273663,
#      'max': 203.12479433507542,
#      'min': -186.70757263999258,
#      'abs': -10.992061275886412},
#     3: {'rmse': 61.721712909433286,
#      'max': 196.47843073675904,
#      'min': -181.574589642536,
#      'abs': -9.399838101028354},
#     4: {'rmse': 62.556293824161244,
#      'max': 204.1606534873281,
#      'min': -181.574589642536,
#      'abs': -9.627144255958457}},
#    'hh': {2: {'rmse': 62.49672755141521,
#      'max': 195.70259531935153,
#      'min': -221.74716392542177,
#      'abs': -7.9850790698520315},
#     3: {'rmse': 45.054798394793785,
#      'max': 165.52241163620783,
#      'min': -179.9590771876974,
#      'abs': 5.450077149516245},
#     4: {'rmse': 41.47172417504322,
#      'max': 160.21774003229802,
#      'min': -127.68846277562989,
#      'abs': -0.4499450961221999}}},
#   1024: {'flat': {2: {'rmse': 76.12067940279866,
#      'max': 218.84151290432783,
#      'min': -254.2211344607349,
#      'abs': -4.3217005836079885},
#     3: {'rmse': 78.79437022699128,
#      'max': 216.2585071384965,
#      'min': -270.4253443216585,
#      'abs': -2.6172784835000815},
#     4: {'rmse': 62.28873816925384,
#      'max': 249.33037384433555,
#      'min': -198.6315482538921,
#      'abs': -2.702606910516412}},
#    'hh': {2: {'rmse': 58.55593246916818,
#      'max': 238.34419756478746,
#      'min': -220.21729829300602,
#      'abs': -2.16123520299925},
#     3: {'rmse': 48.920113663047424,
#      'max': 197.8341001394001,
#      'min': -187.69647102463932,
#      'abs': -3.5249317878369415},
#     4: {'rmse': 39.669224761801956,
#      'max': 138.70621613130788,
#      'min': -143.41283343944087,
#      'abs': -1.4608576908887567}}},
#   2048: {'flat': {2: {'rmse': 75.46171575462057,
#      'max': 274.4241759731667,
#      'min': -237.3797104905534,
#      'abs': 0.6982012752809096},
#     3: {'rmse': 91.866200115792,
#      'max': 287.91016419333755,
#      'min': -271.77440880739596,
#      'abs': -1.5763551246158196},
#     4: {'rmse': 64.90607747555264,
#      'max': 200.00462006713497,
#      'min': -194.42248520444264,
#      'abs': 0.6798007946512982}},
#    'hh': {2: {'rmse': 59.96236132724164,
#      'max': 236.83854243486712,
#      'min': -240.59450088135782,
#      'abs': -4.713309593971143},
#     3: {'rmse': 52.80494603286135,
#      'max': 179.4021591822675,
#      'min': -185.94767249102006,
#      'abs': -2.0371889550118008},
#     4: {'rmse': 46.77627683949235,
#      'max': 191.62894279049942,
#      'min': -231.63720769790234,
#      'abs': -0.6581530288015638}}}},
#  0.2: {32: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   128: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   256: {'flat': {2: {'rmse': 49.369380288541834,
#      'max': 195.88625428540945,
#      'min': -165.84097409404603,
#      'abs': -1.1016307079992846},
#     3: {'rmse': 129.68074921309574,
#      'max': 349.82837749600003,
#      'min': -317.384649109008,
#      'abs': -8.392523662154746},
#     4: {'rmse': 117.69558722978073,
#      'max': 314.1063170529451,
#      'min': -318.43853542019497,
#      'abs': -6.101678988702208}},
#    'hh': {2: {'rmse': 75.95175537262213,
#      'max': 250.86388035139134,
#      'min': -321.7627939853937,
#      'abs': -2.6621441079306805},
#     3: {'rmse': 90.13230623160544,
#      'max': 217.78234061335388,
#      'min': -236.84218723382946,
#      'abs': 1.615103810829873},
#     4: {'rmse': 69.83810687252613,
#      'max': 242.73545665971324,
#      'min': -288.6671802314813,
#      'abs': -7.06472263459902}}},
#   512: {'flat': {2: {'rmse': 153.2969304454461,
#      'max': 471.6235572463338,
#      'min': -402.68885982080246,
#      'abs': 4.054438261682383},
#     3: {'rmse': 130.0888813131522,
#      'max': 397.0671154147567,
#      'min': -394.6930698352735,
#      'abs': -5.513191886402099},
#     4: {'rmse': 128.6654731674791,
#      'max': 404.64076897643827,
#      'min': -385.95535301652853,
#      'abs': -5.103071537145742}},
#    'hh': {2: {'rmse': 108.63660243485509,
#      'max': 365.26044083578745,
#      'min': -388.481501274975,
#      'abs': -13.391217822229867},
#     3: {'rmse': 97.10422629470699,
#      'max': 349.1690578893176,
#      'min': -295.20600131451647,
#      'abs': -0.4866068451435014},
#     4: {'rmse': 86.80997720921387,
#      'max': 260.37109492506715,
#      'min': -325.02287214636453,
#      'abs': 1.9530616644586087}}},
#   1024: {'flat': {2: {'rmse': 147.57055517129336,
#      'max': 442.10720442660386,
#      'min': -575.0137092974328,
#      'abs': 6.806873228296637},
#     3: {'rmse': 157.71802960000795,
#      'max': 485.94090067634534,
#      'min': -606.0934005436138,
#      'abs': 4.644772862326849},
#     4: {'rmse': 125.60361783357357,
#      'max': 345.4627082809893,
#      'min': -426.8359700005676,
#      'abs': 2.5608417499837697}},
#    'hh': {2: {'rmse': 120.89832057591975,
#      'max': 377.60658736506593,
#      'min': -449.8863526620553,
#      'abs': 0.7730057474592468},
#     3: {'rmse': 98.83578249040217,
#      'max': 453.2542030365148,
#      'min': -324.21033537894255,
#      'abs': -2.1313672548021714},
#     4: {'rmse': 84.34317803031017,
#      'max': 301.19091971209855,
#      'min': -298.58383399251034,
#      'abs': 14.816366389063097}}},
#   2048: {'flat': {2: {'rmse': 169.1522122723467,
#      'max': 463.8281525950297,
#      'min': -614.9265594076132,
#      'abs': -13.097825598208734},
#     3: {'rmse': 209.3070986381316,
#      'max': 491.1227540974505,
#      'min': -846.1857779771672,
#      'abs': -22.981295570642896},
#     4: {'rmse': 137.699831999334,
#      'max': 450.74825913243694,
#      'min': -498.11466529319296,
#      'abs': -6.578269392418061}},
#    'hh': {2: {'rmse': 127.1202577111324,
#      'max': 520.1351285831188,
#      'min': -575.5174514132959,
#      'abs': 2.9835845227231212},
#     3: {'rmse': 104.97457288433256,
#      'max': 418.65245410529315,
#      'min': -316.6934267406468,
#      'abs': 17.43515441323493},
#     4: {'rmse': 94.41464942740097,
#      'max': 492.5162969433004,
#      'min': -357.86004316213075,
#      'abs': 3.267138402197935}}}}}

# %%
loc_hh_error_dict = fill_up_hh_errors_dict(epsilons, n, degrees, loc_flat_est_hh_dict, loc_flat_cor_hh_dict, loc_hh_est_hh_dict, loc_hh_cor_hh_dict)
loc_hh_error_dict
# Out:
# {2.0: {32: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   128: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   256: {'flat': {2: {'rmse': 3180.6315414083992,
#      'max': 10086.509389504787,
#      'min': -7661.8298313752175,
#      'abs': -121.6680131927262},
#     3: {'rmse': 2580.478068804104,
#      'max': 6833.196682823422,
#      'min': -7245.750273902966,
#      'abs': -543.0562154346284},
#     4: {'rmse': 3684.674721177761,
#      'max': 9101.044196039453,
#      'min': -9801.288394431329,
#      'abs': -972.944533893945}},
#    'hh': {2: {'rmse': 2129.7819406878884,
#      'max': 9004.09269779532,
#      'min': -7645.816234173851,
#      'abs': -22.877068161443812},
#     3: {'rmse': 3861.3962062135693,
#      'max': 11323.877839474357,
#      'min': -12863.047955040667,
#      'abs': 114.76705769847075},
#     4: {'rmse': 2332.1548598032,
#      'max': 7703.992847567744,
#      'min': -7668.620147101614,
#      'abs': -257.55476613524945}}},
#   512: {'flat': {2: {'rmse': 8272.778629905,
#      'max': 24606.33472120005,
#      'min': -23803.249870785185,
#      'abs': -1061.1626996650325},
#     3: {'rmse': 11420.252207452035,
#      'max': 28235.534823874725,
#      'min': -39413.57400721881,
#      'abs': -1956.6691154515922},
#     4: {'rmse': 11130.911388756189,
#      'max': 27567.968975050535,
#      'min': -39413.57400721881,
#      'abs': -1682.1566803254268}},
#    'hh': {2: {'rmse': 4773.877086747785,
#      'max': 19372.738873533483,
#      'min': -18469.35748452622,
#      'abs': -149.13684993190188},
#     3: {'rmse': 5804.8296701386,
#      'max': 26106.425706925977,
#      'min': -23700.03059574288,
#      'abs': -285.4974635132217},
#     4: {'rmse': 7252.825643397354,
#      'max': 36061.677107081094,
#      'min': -22780.839115487615,
#      'abs': 64.11557932564065}}},
#   1024: {'flat': {2: {'rmse': 33343.392365271204,
#      'max': 97607.79017460122,
#      'min': -104366.02588374456,
#      'abs': 510.7115034394091},
#     3: {'rmse': 34032.14534314782,
#      'max': 99206.01375825479,
#      'min': -92601.87501394776,
#      'abs': 48.988674992588535},
#     4: {'rmse': 30866.33190309977,
#      'max': 100775.68838944734,
#      'min': -95383.792492983,
#      'abs': 225.9113211120007}},
#    'hh': {2: {'rmse': 9844.512118715773,
#      'max': 34878.77299200467,
#      'min': -34348.14088373666,
#      'abs': -11.23657659495477},
#     3: {'rmse': 14576.717709356491,
#      'max': 49981.29399022783,
#      'min': -48988.89494931821,
#      'abs': -165.23701887633632},
#     4: {'rmse': 9732.02766100665,
#      'max': 35911.88842343354,
#      'min': -35330.32707377088,
#      'abs': 49.542071216160465}}},
#   2048: {'flat': {2: {'rmse': 77475.13911560609,
#      'max': 242311.58478794352,
#      'min': -249742.16031231417,
#      'abs': 4547.206125907194},
#     3: {'rmse': 86364.53297728147,
#      'max': 263247.6418570571,
#      'min': -279498.17626306915,
#      'abs': 7086.692989355555},
#     4: {'rmse': 63331.43591616159,
#      'max': 194618.5276358027,
#      'min': -200619.33521027252,
#      'abs': -561.3182807599171}},
#    'hh': {2: {'rmse': 20021.128415272688,
#      'max': 72570.27953387785,
#      'min': -81019.95560502188,
#      'abs': 32.14795000470423},
#     3: {'rmse': 20111.57791126177,
#      'max': 76197.24390534626,
#      'min': -66353.82247480149,
#      'abs': 108.41939400658366},
#     4: {'rmse': 29976.400429544356,
#      'max': 125621.6345303613,
#      'min': -135012.66976159223,
#      'abs': 245.20703903990741}}}},
#  1.4: {32: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   128: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   256: {'flat': {2: {'rmse': 5232.793367302756,
#      'max': 18835.523073191933,
#      'min': -16027.114409957061,
#      'abs': -101.10713363346488},
#     3: {'rmse': 4513.877009767743,
#      'max': 10341.487968031535,
#      'min': -15239.63790240206,
#      'abs': -266.84261078948},
#     4: {'rmse': 5916.337855738503,
#      'max': 14996.305134769951,
#      'min': -15899.574380708189,
#      'abs': -255.58953795096483}},
#    'hh': {2: {'rmse': 3815.345801804058,
#      'max': 16671.490033459682,
#      'min': -15389.215949299181,
#      'abs': -86.06324826828207},
#     3: {'rmse': 6753.394448347917,
#      'max': 16579.420213121957,
#      'min': -18595.41669608734,
#      'abs': -1062.8835882692304},
#     4: {'rmse': 3897.6189498818026,
#      'max': 15275.858286059614,
#      'min': -15587.254013109818,
#      'abs': -240.03498765604292}}},
#   512: {'flat': {2: {'rmse': 18890.6703205826,
#      'max': 46554.317295377,
#      'min': -53674.01332954042,
#      'abs': 1284.1035163091713},
#     3: {'rmse': 22468.719890538698,
#      'max': 69300.75282519741,
#      'min': -62760.146489174076,
#      'abs': 2180.8709344436006},
#     4: {'rmse': 22481.523308373435,
#      'max': 65356.38822225013,
#      'min': -63928.290120638165,
#      'abs': 2692.821450276612}},
#    'hh': {2: {'rmse': 8613.751010416127,
#      'max': 29589.866620403292,
#      'min': -37670.79370033028,
#      'abs': 154.97182555518356},
#     3: {'rmse': 10109.875988355685,
#      'max': 36079.713785837346,
#      'min': -33212.46599198813,
#      'abs': -731.1475891153625},
#     4: {'rmse': 13525.947656650504,
#      'max': 52310.43982781259,
#      'min': -48835.30917025804,
#      'abs': 116.22357822198244}}},
#   1024: {'flat': {2: {'rmse': 57545.66886945675,
#      'max': 174116.7566614775,
#      'min': -168935.08557821106,
#      'abs': -8762.328934388499},
#     3: {'rmse': 58264.922540832886,
#      'max': 172329.78233550384,
#      'min': -175479.13468063372,
#      'abs': -9835.440426905994},
#     4: {'rmse': 56312.34724708503,
#      'max': 180399.33366331583,
#      'min': -193502.1232465682,
#      'abs': -2450.6085608555873}},
#    'hh': {2: {'rmse': 17323.678898995822,
#      'max': 87812.73938997998,
#      'min': -82931.40079151679,
#      'abs': -326.1330756938279},
#     3: {'rmse': 26309.064796603267,
#      'max': 91239.89975660786,
#      'min': -91570.60662823296,
#      'abs': 46.7249640944123},
#     4: {'rmse': 18669.377656653185,
#      'max': 69596.3886884684,
#      'min': -62145.23076212602,
#      'abs': -94.28558655579393}}},
#   2048: {'flat': {2: {'rmse': 132234.45169935666,
#      'max': 461078.04125242494,
#      'min': -358497.21853280056,
#      'abs': -128.902753567959},
#     3: {'rmse': 145265.08948769936,
#      'max': 420119.9816417515,
#      'min': -314139.8259364124,
#      'abs': -2426.7915616223527},
#     4: {'rmse': 112747.07222522923,
#      'max': 360444.4918880228,
#      'min': -335537.028110393,
#      'abs': -2203.0794824566096}},
#    'hh': {2: {'rmse': 35351.19556533451,
#      'max': 151795.84187539245,
#      'min': -149829.8987840755,
#      'abs': -595.2940106027802},
#     3: {'rmse': 37021.705374458594,
#      'max': 136930.83085916797,
#      'min': -126641.02516498027,
#      'abs': -1247.4089716068427},
#     4: {'rmse': 55040.08357776671,
#      'max': 292938.84228362056,
#      'min': -200521.49306505642,
#      'abs': -166.61314785328824}}}},
#  1.2: {32: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   128: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   256: {'flat': {2: {'rmse': 6633.14205954481,
#      'max': 17347.353016798024,
#      'min': -18567.728040503276,
#      'abs': -364.1385968162168},
#     3: {'rmse': 4894.922539414759,
#      'max': 13697.6220317712,
#      'min': -11552.088996791004,
#      'abs': -976.7168164557032},
#     4: {'rmse': 7047.7631811784495,
#      'max': 19152.10132040568,
#      'min': -22473.319039716465,
#      'abs': -1452.914392246047}},
#    'hh': {2: {'rmse': 4529.609108472227,
#      'max': 15212.848997530753,
#      'min': -16030.7722677768,
#      'abs': -12.693690948937409},
#     3: {'rmse': 8361.326764373069,
#      'max': 25289.189270958057,
#      'min': -26980.313515591206,
#      'abs': -1087.0029283466074},
#     4: {'rmse': 4564.6562064826585,
#      'max': 17574.24112460995,
#      'min': -15808.438893045775,
#      'abs': -2.508860730128852}}},
#   512: {'flat': {2: {'rmse': 22186.891258649393,
#      'max': 71675.94131852116,
#      'min': -64910.80262101939,
#      'abs': -2934.690699306437},
#     3: {'rmse': 26861.22585386413,
#      'max': 74359.34241474539,
#      'min': -78493.41308835008,
#      'abs': -4424.445411906749},
#     4: {'rmse': 26140.61363679988,
#      'max': 70924.59902272548,
#      'min': -77410.57993861733,
#      'abs': -5021.47183502336}},
#    'hh': {2: {'rmse': 10495.370705284447,
#      'max': 39631.61175685123,
#      'min': -40824.38944025401,
#      'abs': 286.9615330712769},
#     3: {'rmse': 12016.674114727946,
#      'max': 52560.34405487137,
#      'min': -39765.72149866402,
#      'abs': -415.1488046437233},
#     4: {'rmse': 16327.068409925072,
#      'max': 69579.77982084913,
#      'min': -59018.94190577559,
#      'abs': 288.2681161347351}}},
#   1024: {'flat': {2: {'rmse': 84434.04727287528,
#      'max': 218459.96842002822,
#      'min': -248916.10501375562,
#      'abs': 8252.535723378032},
#     3: {'rmse': 86597.97129833122,
#      'max': 223674.96192205,
#      'min': -262464.70873589814,
#      'abs': 11515.675168449834},
#     4: {'rmse': 75433.25979254548,
#      'max': 221713.98791396257,
#      'min': -228132.0127502787,
#      'abs': 4825.652631247499}},
#    'hh': {2: {'rmse': 22352.391836428364,
#      'max': 82639.97617959889,
#      'min': -80896.7973082648,
#      'abs': 1185.5070053321958},
#     3: {'rmse': 32049.627356454654,
#      'max': 112295.23601454153,
#      'min': -108231.10207104504,
#      'abs': -271.38131737691725},
#     4: {'rmse': 21838.13730721472,
#      'max': 78579.80245298278,
#      'min': -82203.83596730897,
#      'abs': -100.53148127728352}}},
#   2048: {'flat': {2: {'rmse': 186583.7053893637,
#      'max': 520077.9410419818,
#      'min': -509964.8535733119,
#      'abs': -3746.472509474727},
#     3: {'rmse': 213530.66046859854,
#      'max': 744416.6132937736,
#      'min': -685325.9344277419,
#      'abs': -9602.831925864262},
#     4: {'rmse': 161162.41478023244,
#      'max': 475617.13805620244,
#      'min': -555833.0164311903,
#      'abs': -321.7724701285057}},
#    'hh': {2: {'rmse': 42585.30087332409,
#      'max': 187574.34173672693,
#      'min': -173364.8506661644,
#      'abs': -291.84059699800315},
#     3: {'rmse': 43975.82549143236,
#      'max': 153619.9094927365,
#      'min': -155950.19560207726,
#      'abs': 514.7015408374438},
#     4: {'rmse': 66713.46758100862,
#      'max': 313275.9344725021,
#      'min': -216200.43546923297,
#      'abs': 102.60324741225065}}}},
#  1.0: {32: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   128: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   256: {'flat': {2: {'rmse': 7874.02317689302,
#      'max': 25277.732244905295,
#      'min': -22600.376156970284,
#      'abs': 10.351608286212722},
#     3: {'rmse': 6777.502402372462,
#      'max': 16086.868606469783,
#      'min': -19830.412213048134,
#      'abs': -1342.3011418714675},
#     4: {'rmse': 8122.79367732538,
#      'max': 22071.407804855604,
#      'min': -21147.469159551994,
#      'abs': -326.544711262031}},
#    'hh': {2: {'rmse': 5544.942567151954,
#      'max': 21780.970570312,
#      'min': -22456.217011141704,
#      'abs': 45.360840334806184},
#     3: {'rmse': 9648.43059390004,
#      'max': 28809.48209340914,
#      'min': -32652.558228700986,
#      'abs': -870.3698291942071},
#     4: {'rmse': 6439.014227891131,
#      'max': 21225.648813460328,
#      'min': -20166.584548146446,
#      'abs': -9.41899417810319}}},
#   512: {'flat': {2: {'rmse': 28524.17029368458,
#      'max': 65418.499108031596,
#      'min': -69735.80012669525,
#      'abs': 6787.770909165874},
#     3: {'rmse': 31745.90705904759,
#      'max': 84485.48995638968,
#      'min': -126708.20378704336,
#      'abs': 4326.829778168336},
#     4: {'rmse': 31648.88918574844,
#      'max': 85623.35390077566,
#      'min': -117564.84324842884,
#      'abs': 4377.5723331630825}},
#    'hh': {2: {'rmse': 12364.4038362129,
#      'max': 50964.817510839144,
#      'min': -50532.33952212684,
#      'abs': -612.7969627293045},
#     3: {'rmse': 15162.999755916715,
#      'max': 60144.464682577236,
#      'min': -48880.770651039966,
#      'abs': -177.979429885229},
#     4: {'rmse': 19580.20464548141,
#      'max': 73326.4935577705,
#      'min': -76308.7131091854,
#      'abs': -712.2416153971594}}},
#   1024: {'flat': {2: {'rmse': 94508.4765838653,
#      'max': 287424.23446501035,
#      'min': -278954.17469575396,
#      'abs': 4061.488326667039},
#     3: {'rmse': 95314.9926927537,
#      'max': 288165.269570461,
#      'min': -289201.2936249897,
#      'abs': 844.0054882031739},
#     4: {'rmse': 87489.00199119597,
#      'max': 227314.66622762918,
#      'min': -259938.1365714062,
#      'abs': 2063.9307311773355}},
#    'hh': {2: {'rmse': 26883.55788234147,
#      'max': 130579.87795279262,
#      'min': -96498.1605610534,
#      'abs': -422.4919285542952},
#     3: {'rmse': 39523.06668281599,
#      'max': 165718.15614976815,
#      'min': -131928.0579082625,
#      'abs': 809.4581205299867},
#     4: {'rmse': 27224.808180929722,
#      'max': 122192.39162691677,
#      'min': -92394.86447028308,
#      'abs': -150.1152114955209}}},
#   2048: {'flat': {2: {'rmse': 204112.7165521395,
#      'max': 518465.3377053151,
#      'min': -672543.5078522208,
#      'abs': 8494.745969346346},
#     3: {'rmse': 231106.61325819753,
#      'max': 671409.7009745204,
#      'min': -802189.8495207079,
#      'abs': 21740.874626876728},
#     4: {'rmse': 176190.5342149089,
#      'max': 471556.63954772253,
#      'min': -559256.5587023215,
#      'abs': 3772.125262693138}},
#    'hh': {2: {'rmse': 52508.49708788328,
#      'max': 208543.5497743751,
#      'min': -219285.35548757762,
#      'abs': 1168.4830628267177},
#     3: {'rmse': 55326.11715291779,
#      'max': 196608.00175660802,
#      'min': -169584.77486183523,
#      'abs': 1809.1814915986654},
#     4: {'rmse': 77570.06970730999,
#      'max': 317635.46565924556,
#      'min': -344129.2594552224,
#      'abs': -26.254741353811696}}}},
#  0.8: {32: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   128: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   256: {'flat': {2: {'rmse': 9495.18249533614,
#      'max': 32572.648176157396,
#      'min': -29326.054584682483,
#      'abs': 667.1107704246001},
#     3: {'rmse': 7170.054334101554,
#      'max': 17559.869471696118,
#      'min': -19144.847315368464,
#      'abs': 1190.6448160887044},
#     4: {'rmse': 9835.240440374238,
#      'max': 32508.795186378673,
#      'min': -19569.176761171795,
#      'abs': 2209.3888596934817}},
#    'hh': {2: {'rmse': 6567.102740670355,
#      'max': 30047.30906290846,
#      'min': -21239.37660052743,
#      'abs': 71.54844082633399},
#     3: {'rmse': 12449.78987858775,
#      'max': 47849.23266490182,
#      'min': -45893.82945200514,
#      'abs': -594.8301796298438},
#     4: {'rmse': 7179.769018873147,
#      'max': 23962.714092728624,
#      'min': -32104.566461834802,
#      'abs': 104.29565123520338}}},
#   512: {'flat': {2: {'rmse': 31790.497504925435,
#      'max': 80088.71526174844,
#      'min': -102867.03627601065,
#      'abs': -2214.839518348117},
#     3: {'rmse': 40105.015597217236,
#      'max': 101085.2352740498,
#      'min': -124456.90207458052,
#      'abs': -806.1581251687624},
#     4: {'rmse': 40267.37410288386,
#      'max': 101457.16308600013,
#      'min': -122412.83106794157,
#      'abs': -1075.6746691210926}},
#    'hh': {2: {'rmse': 15197.348636205552,
#      'max': 56321.22877004009,
#      'min': -49247.60488190181,
#      'abs': 359.8751208589253},
#     3: {'rmse': 17960.19838312049,
#      'max': 71028.015186226,
#      'min': -61822.41549607794,
#      'abs': 227.29185648174015},
#     4: {'rmse': 23578.837467713434,
#      'max': 92200.91113841243,
#      'min': -86214.59044784357,
#      'abs': 2296.8488876314177}}},
#   1024: {'flat': {2: {'rmse': 115609.75829257374,
#      'max': 321698.564085471,
#      'min': -366766.0866403619,
#      'abs': 1396.2929271500964},
#     3: {'rmse': 115239.93458980373,
#      'max': 330924.08187007246,
#      'min': -293749.32873605966,
#      'abs': 4488.384465502973},
#     4: {'rmse': 102096.72174909772,
#      'max': 331081.4484429764,
#      'min': -309827.5033748321,
#      'abs': 2647.3204312047587}},
#    'hh': {2: {'rmse': 31962.830828509876,
#      'max': 121021.2040218834,
#      'min': -121375.46208083662,
#      'abs': -930.6960316414021},
#     3: {'rmse': 48453.2664725108,
#      'max': 162922.84822638094,
#      'min': -178152.85554251313,
#      'abs': 543.7644035508413},
#     4: {'rmse': 33325.73820805607,
#      'max': 135323.11064504756,
#      'min': -115089.48743956228,
#      'abs': -1446.1880032598451}}},
#   2048: {'flat': {2: {'rmse': 273800.77381820563,
#      'max': 735547.5530728647,
#      'min': -1008849.6049347254,
#      'abs': 9396.728427915656},
#     3: {'rmse': 302341.2224287852,
#      'max': 913583.9928872157,
#      'min': -938063.5269989335,
#      'abs': 14055.841333362076},
#     4: {'rmse': 232423.89129045978,
#      'max': 636549.8049336977,
#      'min': -694764.150075791,
#      'abs': -1615.13417921388}},
#    'hh': {2: {'rmse': 63272.01802911678,
#      'max': 241412.04762363003,
#      'min': -226256.2726979651,
#      'abs': -958.1039572873455},
#     3: {'rmse': 65182.176759732814,
#      'max': 247144.2886412188,
#      'min': -230141.63350636698,
#      'abs': -914.6791782588026},
#     4: {'rmse': 99524.64852377702,
#      'max': 442583.58357164625,
#      'min': -423400.1066515633,
#      'abs': 3622.4657636910915}}}},
#  0.6: {32: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   128: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   256: {'flat': {2: {'rmse': 11897.269553969212,
#      'max': 35832.63503101784,
#      'min': -44575.93176718927,
#      'abs': 314.1421309556626},
#     3: {'rmse': 9659.102936361736,
#      'max': 27441.164881682882,
#      'min': -22610.955442932875,
#      'abs': 2130.366745590053},
#     4: {'rmse': 12961.20410247497,
#      'max': 35720.180730330074,
#      'min': -33466.99229800661,
#      'abs': 720.7663995115985}},
#    'hh': {2: {'rmse': 8199.002054911087,
#      'max': 36868.19794595146,
#      'min': -35575.10209149232,
#      'abs': -512.4976783041521},
#     3: {'rmse': 15530.874112134486,
#      'max': 51504.43189836685,
#      'min': -54806.903590600115,
#      'abs': -911.5728527107183},
#     4: {'rmse': 9201.449575768853,
#      'max': 29639.997522576872,
#      'min': -32780.204090356776,
#      'abs': -739.9013021136924}}},
#   512: {'flat': {2: {'rmse': 33279.742329287015,
#      'max': 96797.33040008036,
#      'min': -82009.25608393416,
#      'abs': -987.459224962987},
#     3: {'rmse': 44814.84970142904,
#      'max': 123297.48982197107,
#      'min': -130894.35571261458,
#      'abs': -409.24670611736764},
#     4: {'rmse': 45182.61664023762,
#      'max': 123297.48982197107,
#      'min': -124694.61529964552,
#      'abs': 211.9402472737301}},
#    'hh': {2: {'rmse': 18305.952393387135,
#      'max': 65104.04006581163,
#      'min': -78101.29181454753,
#      'abs': 853.9143697993198},
#     3: {'rmse': 22672.16229573691,
#      'max': 86423.12536200948,
#      'min': -91518.09399465902,
#      'abs': -91.67069091684436},
#     4: {'rmse': 28229.623436533362,
#      'max': 105051.05385116657,
#      'min': -101933.24197413109,
#      'abs': -1765.2622734195181}}},
#   1024: {'flat': {2: {'rmse': 120833.11612954747,
#      'max': 342560.87580454623,
#      'min': -287870.9786702696,
#      'abs': 22693.868565258123},
#     3: {'rmse': 129342.69800191076,
#      'max': 399638.0168270599,
#      'min': -314795.9430803144,
#      'abs': 27390.16336826276},
#     4: {'rmse': 109575.93217015664,
#      'max': 365547.90435853717,
#      'min': -267678.16176096885,
#      'abs': 11991.503961576662}},
#    'hh': {2: {'rmse': 40288.38329707168,
#      'max': 170936.10701106576,
#      'min': -176233.36834081006,
#      'abs': 608.5258625607213},
#     3: {'rmse': 58637.14976013063,
#      'max': 203338.3783578885,
#      'min': -190286.3027932556,
#      'abs': 1169.8711187944327},
#     4: {'rmse': 41769.193309915456,
#      'max': 170998.93469699286,
#      'min': -139390.9318026256,
#      'abs': -417.91584471852013}}},
#   2048: {'flat': {2: {'rmse': 302129.7573375316,
#      'max': 879675.7935293601,
#      'min': -871504.3231136437,
#      'abs': 7773.360879317565},
#     3: {'rmse': 325682.0902824298,
#      'max': 901151.452119281,
#      'min': -737166.7681387122,
#      'abs': -12384.451643382654},
#     4: {'rmse': 266978.05484261026,
#      'max': 706501.265842776,
#      'min': -909061.5464507943,
#      'abs': 15245.354170949458}},
#    'hh': {2: {'rmse': 79375.24042615572,
#      'max': 341225.48817491054,
#      'min': -270649.92322413257,
#      'abs': 103.06816695689182},
#     3: {'rmse': 82671.71624327234,
#      'max': 314701.4027366403,
#      'min': -237435.074014829,
#      'abs': 1374.116039375254},
#     4: {'rmse': 119609.1129017967,
#      'max': 458876.7353359407,
#      'min': -563136.9943026479,
#      'abs': 6366.271643170786}}}},
#  0.4: {32: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   128: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   256: {'flat': {2: {'rmse': 14623.327927725926,
#      'max': 42944.73486367112,
#      'min': -51368.651592827286,
#      'abs': 440.7507273138725},
#     3: {'rmse': 11152.220635213955,
#      'max': 29474.62867340939,
#      'min': -30013.708988315055,
#      'abs': 1440.2817998590576},
#     4: {'rmse': 16608.742952189627,
#      'max': 48393.70225534096,
#      'min': -58670.76024637179,
#      'abs': 2170.8818542864456}},
#    'hh': {2: {'rmse': 8692.11612639074,
#      'max': 34445.16947854444,
#      'min': -31217.259063004072,
#      'abs': 64.14076124588034},
#     3: {'rmse': 17224.15125175094,
#      'max': 48324.836951507925,
#      'min': -49359.00940440562,
#      'abs': 864.49816925905},
#     4: {'rmse': 9901.837664821027,
#      'max': 35893.167117596764,
#      'min': -29343.612052002354,
#      'abs': 1225.0393483742419}}},
#   512: {'flat': {2: {'rmse': 55804.272022497564,
#      'max': 178586.7347590485,
#      'min': -158797.20498172735,
#      'abs': 9941.997110011816},
#     3: {'rmse': 68460.47236871444,
#      'max': 173587.8063675666,
#      'min': -247207.78444959284,
#      'abs': 6692.817935293721},
#     4: {'rmse': 67037.30991930181,
#      'max': 177856.6753463329,
#      'min': -253664.3882330286,
#      'abs': 8695.96038060371}},
#    'hh': {2: {'rmse': 20664.924822377103,
#      'max': 81461.20194220188,
#      'min': -76494.40812259309,
#      'abs': -444.4057930070263},
#     3: {'rmse': 25602.2718897556,
#      'max': 96665.75590516112,
#      'min': -86865.2914270047,
#      'abs': 323.1298525358189},
#     4: {'rmse': 32766.215314632864,
#      'max': 115580.67057850224,
#      'min': -121924.75426325934,
#      'abs': 318.8448078677422}}},
#   1024: {'flat': {2: {'rmse': 141745.2104154786,
#      'max': 433058.7171262319,
#      'min': -408018.65693610243,
#      'abs': 1822.312850918077},
#     3: {'rmse': 139356.55383528498,
#      'max': 431442.7438668065,
#      'min': -391058.5079826941,
#      'abs': 1309.8011287188153},
#     4: {'rmse': 140457.70938455898,
#      'max': 407135.9283994457,
#      'min': -445922.66861896624,
#      'abs': 1079.818170144767}},
#    'hh': {2: {'rmse': 43371.111148985736,
#      'max': 216058.61700634065,
#      'min': -185964.45009868522,
#      'abs': 903.1383453598022},
#     3: {'rmse': 64442.251469042654,
#      'max': 269879.22500886983,
#      'min': -268048.5907073613,
#      'abs': 4220.457950128203},
#     4: {'rmse': 46115.35876909173,
#      'max': 232588.62062622153,
#      'min': -200020.5209756235,
#      'abs': -1527.9274922361246}}},
#   2048: {'flat': {2: {'rmse': 366179.25884147437,
#      'max': 1176338.859359518,
#      'min': -1040529.3249378041,
#      'abs': 40022.27945501303},
#     3: {'rmse': 402830.0713903363,
#      'max': 1228821.4691943708,
#      'min': -1031979.5406412816,
#      'abs': 49628.22324096706},
#     4: {'rmse': 325025.4196001417,
#      'max': 1012525.7563665248,
#      'min': -1045947.5910085941,
#      'abs': 19247.99840778441}},
#    'hh': {2: {'rmse': 87916.18101766381,
#      'max': 359793.29130472156,
#      'min': -343805.2417430187,
#      'abs': -259.0002010903785},
#     3: {'rmse': 89254.29969435354,
#      'max': 334209.70414168877,
#      'min': -300885.1378774878,
#      'abs': -475.3228789617106},
#     4: {'rmse': 130858.10578076495,
#      'max': 720787.0433700247,
#      'min': -467018.71340430056,
#      'abs': 5658.160522083539}}}},
#  0.2: {32: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   128: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   256: {'flat': {2: {'rmse': 20175.398767687646,
#      'max': 58432.72719201897,
#      'min': -51550.19432408657,
#      'abs': -1076.1301654343497},
#     3: {'rmse': 12392.30622407798,
#      'max': 35212.8923012493,
#      'min': -41151.47254148386,
#      'abs': -2900.7666145749645},
#     4: {'rmse': 18599.596832981737,
#      'max': 43235.71342475676,
#      'min': -59218.91783030213,
#      'abs': -2733.2789898590145}},
#    'hh': {2: {'rmse': 11157.54222343381,
#      'max': 47568.24513597106,
#      'min': -43960.56320644863,
#      'abs': -49.10399027469857},
#     3: {'rmse': 20264.26295016062,
#      'max': 66592.20504290613,
#      'min': -71750.39714563644,
#      'abs': 842.5893696875662},
#     4: {'rmse': 11750.954639327174,
#      'max': 47184.461715572805,
#      'min': -37786.86897444101,
#      'abs': 875.0734725120615}}},
#   512: {'flat': {2: {'rmse': 54367.50880410762,
#      'max': 128620.75484266286,
#      'min': -144383.03620701158,
#      'abs': -8694.920130677467},
#     3: {'rmse': 58600.942463155014,
#      'max': 155249.9142312559,
#      'min': -180890.50347879436,
#      'abs': -1002.1801148316558},
#     4: {'rmse': 57664.394863223315,
#      'max': 156868.28564607885,
#      'min': -169241.73244893178,
#      'abs': -1459.5386751788735}},
#    'hh': {2: {'rmse': 26007.05195259931,
#      'max': 95684.68519071845,
#      'min': -86116.2161705046,
#      'abs': -1817.8652703882817},
#     3: {'rmse': 31117.981809250083,
#      'max': 110777.52830032649,
#      'min': -105516.74520864224,
#      'abs': -1490.446839204679},
#     4: {'rmse': 39154.0838116438,
#      'max': 170811.88364933094,
#      'min': -142323.8910923968,
#      'abs': 1137.435314515369}}},
#   1024: {'flat': {2: {'rmse': 178766.25699870865,
#      'max': 467170.3646141002,
#      'min': -506938.9223276809,
#      'abs': -4521.234073812811},
#     3: {'rmse': 180849.9272400969,
#      'max': 464021.01047752856,
#      'min': -631421.5796012786,
#      'abs': -5837.134410053355},
#     4: {'rmse': 156637.44417309682,
#      'max': 400758.1478631432,
#      'min': -444802.78189802513,
#      'abs': -5640.510838891168}},
#    'hh': {2: {'rmse': 51779.194219771794,
#      'max': 230585.7148298432,
#      'min': -192901.66702900038,
#      'abs': 567.5807712201944},
#     3: {'rmse': 78551.33717398612,
#      'max': 310736.7446596145,
#      'min': -233530.39188039635,
#      'abs': 2244.6808685900683},
#     4: {'rmse': 55597.46419144061,
#      'max': 238382.77201838943,
#      'min': -243028.27099926685,
#      'abs': -1321.461823364144}}},
#   2048: {'flat': {2: {'rmse': 536584.7394052219,
#      'max': 1741939.295814512,
#      'min': -2343992.500790445,
#      'abs': 15210.23811383925},
#     3: {'rmse': 605864.3515880058,
#      'max': 2102097.219186674,
#      'min': -2187877.6378882173,
#      'abs': 23968.057870244298},
#     4: {'rmse': 453392.1566228133,
#      'max': 1279130.0673774567,
#      'min': -1725546.7685194854,
#      'abs': -20269.76450323425}},
#    'hh': {2: {'rmse': 106681.66654401635,
#      'max': 433721.0417805597,
#      'min': -395454.944897453,
#      'abs': -1764.9049664359104},
#     3: {'rmse': 108598.16574160504,
#      'max': 392698.0995847308,
#      'min': -389632.37873076566,
#      'abs': 1495.1526551676593},
#     4: {'rmse': 161314.93992186364,
#      'max': 725332.9841244749,
#      'min': -508499.87186932756,
#      'abs': 5730.212096853387}}}}}

# %%
def same_parameter(answers, correct_answer):
    error = np.abs(correct_answer-answers)
    max_error = np.amax(error)
    min_error = np.amin(error)
    true_values = np.full(len(answers), correct_answer)
    mse = mean_squared_error(true_values, answers, squared = False)
    error_dict = {'mse': mse, 'max': max_error, 'min': min_error, 'abs': np.mean(error)}
    
    return error_dict

# %%
cen_flat_error_dict
# Out:
# {2.0: {32: {'flat': {'rmse': 1.7145706652575146,
#     'max': 7.082161349269882,
#     'min': -6.76880795369857,
#     'abs': 0.005932139039750291},
#    'hh': {2: {'rmse': 3.8210874699316255,
#      'max': 14.265179244732963,
#      'min': -15.629003634433957,
#      'abs': -0.03253519769968161},
#     3: {'rmse': 4.09875950550944,
#      'max': 16.88936725886265,
#      'min': -25.110316107129847,
#      'abs': 0.5614300689908527},
#     4: {'rmse': 3.769548151869408,
#      'max': 14.138752394193489,
#      'min': -14.06792053556228,
#      'abs': -0.5426242302949693}}},
#   128: {'flat': {'rmse': 2.177891666779391,
#     'max': 8.837652855951319,
#     'min': -8.819077411297485,
#     'abs': -0.1395406136285371},
#    'hh': {2: {'rmse': 5.804371377312019,
#      'max': 23.54120977572893,
#      'min': -33.19051662092693,
#      'abs': -0.4536799654945073},
#     3: {'rmse': 4.765712525734771,
#      'max': 18.857693463549367,
#      'min': -18.22361724234929,
#      'abs': -0.05987173003324547},
#     4: {'rmse': 4.655651113503488,
#      'max': 24.035466635653847,
#      'min': -18.295420932026445,
#      'abs': -0.10720679972750245}}},
#   256: {'flat': {'rmse': 3.3790432442937437,
#     'max': 15.430611656320252,
#     'min': -10.634887724548207,
#     'abs': 0.09039333730890721},
#    'hh': {2: {'rmse': 8.079939247556833,
#      'max': 37.45019176832648,
#      'min': -29.595034097750613,
#      'abs': 0.2699304232992306},
#     3: {'rmse': 7.056137607155167,
#      'max': 28.041873078310346,
#      'min': -35.468987831348386,
#      'abs': -0.2909662013022837},
#     4: {'rmse': 5.783016756681464,
#      'max': 22.296053622584623,
#      'min': -25.01303417643885,
#      'abs': 0.05971921145823853}}},
#   512: {'flat': {'rmse': 4.17130207361657,
#     'max': 17.022581412884392,
#     'min': -14.441988048653911,
#     'abs': 0.00951120807616935},
#    'hh': {2: {'rmse': 8.06961957506178,
#      'max': 35.02532410856293,
#      'min': -34.27194227641303,
#      'abs': -0.8109089068023583},
#     3: {'rmse': 7.181730821957709,
#      'max': 31.210328957447928,
#      'min': -19.592500289102645,
#      'abs': 0.548406185614078},
#     4: {'rmse': 6.969184864088994,
#      'max': 34.25625338529608,
#      'min': -25.05841349379807,
#      'abs': 0.4515086470519196}}},
#   1024: {'flat': {'rmse': 4.499569422862048,
#     'max': 14.09385356248822,
#     'min': -14.574277619278291,
#     'abs': 0.10924775356750178},
#    'hh': {2: {'rmse': 9.408586316378877,
#      'max': 44.014441267225266,
#      'min': -45.183301580082116,
#      'abs': 0.3531489252745876},
#     3: {'rmse': 7.72169755732299,
#      'max': 28.572187663432487,
#      'min': -30.895285805509047,
#      'abs': 0.09816298578092064},
#     4: {'rmse': 6.534520416999637,
#      'max': 21.572590269943248,
#      'min': -28.73873316544268,
#      'abs': -0.04574071050814491}}},
#   2048: {'flat': {'rmse': 5.53539530897585,
#     'max': 18.719107699413144,
#     'min': -22.89939654189584,
#     'abs': -0.03957631972413903},
#    'hh': {2: {'rmse': 10.483631144613662,
#      'max': 48.171325738554515,
#      'min': -50.91822113797207,
#      'abs': 0.868041866472045},
#     3: {'rmse': 8.194838114259754,
#      'max': 42.84104391959772,
#      'min': -42.914175583824544,
#      'abs': -0.7165025717762752},
#     4: {'rmse': 7.70614631326624,
#      'max': 27.483923081234025,
#      'min': -43.408519565766255,
#      'abs': 0.06873329906731862}}}},
#  1.4: {32: {'flat': {'rmse': 2.43647965906805,
#     'max': 8.817896693782586,
#     'min': -8.479384446994572,
#     'abs': 0.18011491545785976},
#    'hh': {2: {'rmse': 6.546297165880189,
#      'max': 23.246860946363995,
#      'min': -26.64897184505162,
#      'abs': 0.18302962722352253},
#     3: {'rmse': 5.701651784369545,
#      'max': 21.374605073713383,
#      'min': -26.87267949901218,
#      'abs': 0.4229507122236375},
#     4: {'rmse': 5.494888954515293,
#      'max': 22.825324210355575,
#      'min': -21.787382686564342,
#      'abs': -0.5240369945584911}}},
#   128: {'flat': {'rmse': 3.0890676245748696,
#     'max': 10.014505222812204,
#     'min': -11.063635822421475,
#     'abs': -0.07299982499072598},
#    'hh': {2: {'rmse': 9.337233999832796,
#      'max': 40.15145995642547,
#      'min': -41.021922300035385,
#      'abs': -0.00906961830392397},
#     3: {'rmse': 7.190426335754818,
#      'max': 33.60552146804616,
#      'min': -29.10589495425029,
#      'abs': 0.4483882559262004},
#     4: {'rmse': 7.172992776141757,
#      'max': 36.49487035124116,
#      'min': -36.70253688550201,
#      'abs': 0.5003415625361167}}},
#   256: {'flat': {'rmse': 4.84848736309934,
#     'max': 14.797906528257045,
#     'min': -16.197464477374524,
#     'abs': -0.3667661184241164},
#    'hh': {2: {'rmse': 10.497377489134674,
#      'max': 37.58875376744163,
#      'min': -38.562863812657724,
#      'abs': 0.20999241884517034},
#     3: {'rmse': 9.930272377176104,
#      'max': 40.40292575451713,
#      'min': -36.07461568038161,
#      'abs': 0.3164906949873141},
#     4: {'rmse': 7.580796403180013,
#      'max': 39.466785307969076,
#      'min': -35.96410611576721,
#      'abs': -0.5701716829862132}}},
#   512: {'flat': {'rmse': 5.895581514606601,
#     'max': 20.7138501772406,
#     'min': -24.59970733890259,
#     'abs': -0.2604208618959343},
#    'hh': {2: {'rmse': 12.059448678904909,
#      'max': 61.83635234582107,
#      'min': -40.05341483996472,
#      'abs': -0.2904640432300457},
#     3: {'rmse': 10.367808603290138,
#      'max': 46.3721144005367,
#      'min': -36.977515385633524,
#      'abs': 0.9307598074120534},
#     4: {'rmse': 9.136409910453004,
#      'max': 39.309045807522125,
#      'min': -45.405069894704866,
#      'abs': 0.16577203651602648}}},
#   1024: {'flat': {'rmse': 6.693582507829371,
#     'max': 22.00868444822936,
#     'min': -25.930331274605123,
#     'abs': 0.19785449426080196},
#    'hh': {2: {'rmse': 12.576587047056154,
#      'max': 56.5500777467405,
#      'min': -69.18364401870349,
#      'abs': -0.9146185860358459},
#     3: {'rmse': 10.84048257265864,
#      'max': 38.32905783771275,
#      'min': -48.55919446443477,
#      'abs': -0.19743425997675296},
#     4: {'rmse': 9.800505205490976,
#      'max': 41.38201234014923,
#      'min': -36.26179741112355,
#      'abs': 0.1838440094359652}}},
#   2048: {'flat': {'rmse': 8.07792504334979,
#     'max': 26.528758801061485,
#     'min': -26.43302654587933,
#     'abs': -0.3643846827169983},
#    'hh': {2: {'rmse': 14.3080323531303,
#      'max': 59.24941041006423,
#      'min': -57.35941254701356,
#      'abs': -0.16997148236523088},
#     3: {'rmse': 11.706312263905552,
#      'max': 45.32405905397536,
#      'min': -56.9848203143265,
#      'abs': 0.1528817305270354},
#     4: {'rmse': 11.18581465438397,
#      'max': 43.637220617172716,
#      'min': -50.91345087858281,
#      'abs': -0.5876333393173964}}}},
#  1.2: {32: {'flat': {'rmse': 3.1143373744794514,
#     'max': 10.168758703526919,
#     'min': -9.861350277505721,
#     'abs': 0.13855026275003074},
#    'hh': {2: {'rmse': 7.313871962053904,
#      'max': 28.343621521452633,
#      'min': -32.909408508783486,
#      'abs': 0.7806951603549036},
#     3: {'rmse': 7.303053812425409,
#      'max': 18.554824741567018,
#      'min': -33.785162356621186,
#      'abs': -1.1387857846457006},
#     4: {'rmse': 6.151055828006287,
#      'max': 22.433439529065254,
#      'min': -34.28762452677188,
#      'abs': 0.3224535520392664}}},
#   128: {'flat': {'rmse': 3.5831415771343353,
#     'max': 12.374140020679306,
#     'min': -13.10479693197567,
#     'abs': 0.08936759093523078},
#    'hh': {2: {'rmse': 10.19050326473419,
#      'max': 33.93085193946354,
#      'min': -55.615730779177284,
#      'abs': 0.03428585223550581},
#     3: {'rmse': 8.733345184642046,
#      'max': 47.046877273216296,
#      'min': -33.10558694724182,
#      'abs': -0.654885670182242},
#     4: {'rmse': 7.278335910580392,
#      'max': 44.94535381554033,
#      'min': -33.57874336408668,
#      'abs': 0.2792616000419452}}},
#   256: {'flat': {'rmse': 5.70699013734031,
#     'max': 19.416194056222594,
#     'min': -19.595261752254373,
#     'abs': 0.21478182596044754},
#    'hh': {2: {'rmse': 12.596449323640899,
#      'max': 47.57155463577692,
#      'min': -46.63047698641549,
#      'abs': -0.14718082015697984},
#     3: {'rmse': 11.030918030184356,
#      'max': 47.12038711391688,
#      'min': -40.66777618167998,
#      'abs': -0.4200478208063341},
#     4: {'rmse': 9.428097995366436,
#      'max': 35.73106576759619,
#      'min': -28.8613937700311,
#      'abs': 0.8704889101920235}}},
#   512: {'flat': {'rmse': 6.776587845017445,
#     'max': 23.34714643521329,
#     'min': -23.325001367054938,
#     'abs': -0.5725049732848987},
#    'hh': {2: {'rmse': 14.163268556751198,
#      'max': 61.640305409453504,
#      'min': -63.37623474020802,
#      'abs': 0.3520830162402341},
#     3: {'rmse': 12.005192707794105,
#      'max': 47.263697733959816,
#      'min': -48.14964879172385,
#      'abs': -1.0366339551884547},
#     4: {'rmse': 10.607690887252183,
#      'max': 38.45008163778766,
#      'min': -53.0108793744439,
#      'abs': -0.09793624962998947}}},
#   1024: {'flat': {'rmse': 8.143963144787271,
#     'max': 28.64809253819476,
#     'min': -28.205454421037757,
#     'abs': 0.10895570367613036},
#    'hh': {2: {'rmse': 15.281004761958073,
#      'max': 58.17019591041026,
#      'min': -63.916471234783785,
#      'abs': 0.30181331906206943},
#     3: {'rmse': 13.429051968131382,
#      'max': 51.80116798036033,
#      'min': -44.693006330498974,
#      'abs': 0.6143580100701547},
#     4: {'rmse': 11.589362109777746,
#      'max': 43.796818591737974,
#      'min': -46.179642050692564,
#      'abs': -0.13456290495308312}}},
#   2048: {'flat': {'rmse': 9.60715893944258,
#     'max': 31.915023163994192,
#     'min': -37.56116146480781,
#     'abs': 0.028037582393350625},
#    'hh': {2: {'rmse': 16.338251371753127,
#      'max': 56.97054163034409,
#      'min': -49.63153428530313,
#      'abs': 0.21988295532454094},
#     3: {'rmse': 13.396983386829485,
#      'max': 54.760475807419425,
#      'min': -60.067801016035446,
#      'abs': 0.004386225771410386},
#     4: {'rmse': 13.938781961684844,
#      'max': 48.42575157860665,
#      'min': -63.994082318416986,
#      'abs': -0.14534270831077115}}}},
#  1.0: {32: {'flat': {'rmse': 3.5165921601370647,
#     'max': 9.96078903225657,
#     'min': -17.078960382664263,
#     'abs': -0.17172619509746642},
#    'hh': {2: {'rmse': 8.911366039925252,
#      'max': 42.12507186141784,
#      'min': -39.09659463635512,
#      'abs': 1.248032975550833},
#     3: {'rmse': 7.930735530374019,
#      'max': 23.556162980062027,
#      'min': -37.00206601348236,
#      'abs': 0.6239489745980197},
#     4: {'rmse': 7.312465524853718,
#      'max': 28.26715565046743,
#      'min': -39.68149735128554,
#      'abs': -0.23188728440872397}}},
#   128: {'flat': {'rmse': 4.096766286797886,
#     'max': 13.035493416199188,
#     'min': -16.119533440966734,
#     'abs': 0.16639610706303284},
#    'hh': {2: {'rmse': 12.888426962908134,
#      'max': 49.00472143395791,
#      'min': -56.68961943893191,
#      'abs': 0.1498108936511217},
#     3: {'rmse': 10.096867240890447,
#      'max': 39.91519080712237,
#      'min': -42.540411149021566,
#      'abs': -0.03368620561811363},
#     4: {'rmse': 8.620207866783614,
#      'max': 31.862332882298006,
#      'min': -30.71378904994981,
#      'abs': 0.5997922858519554}}},
#   256: {'flat': {'rmse': 6.647015260918514,
#     'max': 25.59075011034747,
#     'min': -21.704896764455043,
#     'abs': 0.17372856660192065},
#    'hh': {2: {'rmse': 14.498774395173493,
#      'max': 61.11922496729767,
#      'min': -64.09426372800863,
#      'abs': 1.476999206150798},
#     3: {'rmse': 13.44326749218975,
#      'max': 49.641192493989365,
#      'min': -70.26512112960063,
#      'abs': 0.5870034303740082},
#     4: {'rmse': 10.715840517244509,
#      'max': 45.491724458880526,
#      'min': -42.07795281761992,
#      'abs': -0.018569710850143382}}},
#   512: {'flat': {'rmse': 8.303600796300548,
#     'max': 25.833235922980748,
#     'min': -29.374580867168333,
#     'abs': 0.5343515236538046},
#    'hh': {2: {'rmse': 17.0265823423929,
#      'max': 73.83397447620064,
#      'min': -70.30749194287546,
#      'abs': -0.9302581733950043},
#     3: {'rmse': 13.976754398796349,
#      'max': 63.048641052615494,
#      'min': -53.375161919775564,
#      'abs': 0.868564031816967},
#     4: {'rmse': 12.709557551107036,
#      'max': 55.04965873706897,
#      'min': -40.297862977938166,
#      'abs': 0.0712067728776492}}},
#   1024: {'flat': {'rmse': 9.494380083417516,
#     'max': 29.384854136582362,
#     'min': -29.37255340516458,
#     'abs': 0.27992431787816274},
#    'hh': {2: {'rmse': 18.820081455317723,
#      'max': 67.7443991810942,
#      'min': -84.44241944637724,
#      'abs': 0.030698182240562893},
#     3: {'rmse': 15.748695749051999,
#      'max': 52.28692388165655,
#      'min': -56.69690781288955,
#      'abs': 0.1689162367158482},
#     4: {'rmse': 13.562991412152288,
#      'max': 48.141540744312806,
#      'min': -59.02970069241928,
#      'abs': -0.11553593495940258}}},
#   2048: {'flat': {'rmse': 11.319077029979113,
#     'max': 34.85832964180372,
#     'min': -37.3314715696979,
#     'abs': -0.1478345197117933},
#    'hh': {2: {'rmse': 20.879810524308294,
#      'max': 76.52299544587186,
#      'min': -83.12600560266037,
#      'abs': 1.2517548582552782},
#     3: {'rmse': 16.523614678787535,
#      'max': 63.243739983878186,
#      'min': -61.4290592252933,
#      'abs': -1.009377330444757},
#     4: {'rmse': 16.1516160152596,
#      'max': 74.55242304238709,
#      'min': -66.20548801208315,
#      'abs': -1.2165894791999907}}}},
#  0.8: {32: {'flat': {'rmse': 4.34077752925147,
#     'max': 12.987179617938182,
#     'min': -17.629222837352245,
#     'abs': -0.13477913119040758},
#    'hh': {2: {'rmse': 10.981930814018453,
#      'max': 37.85020150446803,
#      'min': -45.05987617607764,
#      'abs': -0.17575203901986783},
#     3: {'rmse': 9.82588241734027,
#      'max': 42.315747317190244,
#      'min': -38.831786377700155,
#      'abs': 0.09490235362753774},
#     4: {'rmse': 8.982848049694155,
#      'max': 40.77333613300493,
#      'min': -34.908598989570464,
#      'abs': 1.214000475585326}}},
#   128: {'flat': {'rmse': 5.155408256690526,
#     'max': 20.038623406844636,
#     'min': -22.940143975325782,
#     'abs': 0.08774856950747931},
#    'hh': {2: {'rmse': 14.447451968442527,
#      'max': 48.96846842620744,
#      'min': -63.679778385020654,
#      'abs': -0.34804621292587234},
#     3: {'rmse': 13.2549050727564,
#      'max': 70.25735258890177,
#      'min': -46.65260497726513,
#      'abs': 0.6222779238951835},
#     4: {'rmse': 11.469143680088733,
#      'max': 40.65158473198335,
#      'min': -52.891720665559205,
#      'abs': 0.9945165864549613}}},
#   256: {'flat': {'rmse': 8.642897876791146,
#     'max': 28.575705738121997,
#     'min': -30.544882279419653,
#     'abs': 0.17744519122774619},
#    'hh': {2: {'rmse': 18.84025709159397,
#      'max': 67.98256554150794,
#      'min': -74.65918152935683,
#      'abs': -0.20044394298536228},
#     3: {'rmse': 16.897786340926206,
#      'max': 57.66668439823616,
#      'min': -64.88344245240023,
#      'abs': 0.18368824459028038},
#     4: {'rmse': 14.319233538357508,
#      'max': 56.73885714154676,
#      'min': -56.60188411555464,
#      'abs': 0.4172532084793769}}},
#   512: {'flat': {'rmse': 10.881419032962096,
#     'max': 29.52365968525919,
#     'min': -42.308917506170474,
#     'abs': -0.9532552626569369},
#    'hh': {2: {'rmse': 20.826741722921074,
#      'max': 73.45644024043759,
#      'min': -67.5758992926776,
#      'abs': -0.030957483326806687},
#     3: {'rmse': 17.593766737663547,
#      'max': 71.54990930238819,
#      'min': -70.32124592749005,
#      'abs': 0.21189451588363772},
#     4: {'rmse': 16.756252364052166,
#      'max': 71.30555935803113,
#      'min': -60.404234473913675,
#      'abs': 1.0613903526133952}}},
#   1024: {'flat': {'rmse': 11.546705729036368,
#     'max': 41.2404636195015,
#     'min': -48.090671698015285,
#     'abs': -0.07369349111740739},
#    'hh': {2: {'rmse': 23.94377786905103,
#      'max': 91.47783086661912,
#      'min': -98.51517102595062,
#      'abs': -0.4135947268289954},
#     3: {'rmse': 19.4384963758155,
#      'max': 78.84083990419367,
#      'min': -82.89076414633018,
#      'abs': -0.5302492827394839},
#     4: {'rmse': 17.05234914380562,
#      'max': 79.08117673318884,
#      'min': -63.94195179055896,
#      'abs': 0.28251539435020384}}},
#   2048: {'flat': {'rmse': 13.745708975816541,
#     'max': 51.05616217538409,
#     'min': -48.20239906112329,
#     'abs': 0.6679384509433952},
#    'hh': {2: {'rmse': 25.54845698654614,
#      'max': 114.71586033349377,
#      'min': -110.4672030191141,
#      'abs': -1.2506671638333748},
#     3: {'rmse': 20.486304753026552,
#      'max': 84.32168609412656,
#      'min': -82.53287128123603,
#      'abs': 0.3760363659915063},
#     4: {'rmse': 19.12817707280194,
#      'max': 87.6605584150384,
#      'min': -74.12607713020589,
#      'abs': 0.7126533802335586}}}},
#  0.6: {32: {'flat': {'rmse': 5.628084803174077,
#     'max': 17.885883538315966,
#     'min': -21.689552761620007,
#     'abs': 0.2319839243484169},
#    'hh': {2: {'rmse': 13.041993028091351,
#      'max': 42.358531326427965,
#      'min': -51.90481223631616,
#      'abs': 0.4150108608712284},
#     3: {'rmse': 11.781305166757239,
#      'max': 37.39366814673167,
#      'min': -44.70121997370461,
#      'abs': -0.1903382644401247},
#     4: {'rmse': 10.818849253997572,
#      'max': 43.48411927927282,
#      'min': -31.415723909882445,
#      'abs': -0.7697003147855674}}},
#   128: {'flat': {'rmse': 7.337234345936353,
#     'max': 25.746247379878696,
#     'min': -22.335204329704993,
#     'abs': -0.20233155296918134},
#    'hh': {2: {'rmse': 21.12143305684566,
#      'max': 107.6336195089873,
#      'min': -76.43232511320957,
#      'abs': 0.8370573619471746},
#     3: {'rmse': 17.402118329804974,
#      'max': 62.82836454112203,
#      'min': -87.0853393006413,
#      'abs': 0.23182168913766119},
#     4: {'rmse': 14.872778582112526,
#      'max': 68.43477497802587,
#      'min': -62.71046290602317,
#      'abs': 0.5389252986018932}}},
#   256: {'flat': {'rmse': 11.353082118133091,
#     'max': 56.75886643564081,
#     'min': -42.7075543894025,
#     'abs': -0.5324787992456556},
#    'hh': {2: {'rmse': 23.593040509360822,
#      'max': 111.27391815339888,
#      'min': -87.52286585522597,
#      'abs': -0.29746399728331396},
#     3: {'rmse': 21.400984521483988,
#      'max': 87.31665921369495,
#      'min': -73.76453090035284,
#      'abs': -0.23684893551697023},
#     4: {'rmse': 17.43235125448744,
#      'max': 68.35302744378987,
#      'min': -74.21700670317932,
#      'abs': 0.3918384470770887}}},
#   512: {'flat': {'rmse': 13.59601354739762,
#     'max': 43.434520656262976,
#     'min': -52.53626066076322,
#     'abs': -0.26228099678441325},
#    'hh': {2: {'rmse': 27.749067680786613,
#      'max': 141.07503256923974,
#      'min': -131.08716991126857,
#      'abs': 0.3581289987097778},
#     3: {'rmse': 22.938273911674326,
#      'max': 70.76742902167189,
#      'min': -103.74118416295096,
#      'abs': 0.6393289957514505},
#     4: {'rmse': 21.65172432193413,
#      'max': 82.8511814424246,
#      'min': -85.29357026305661,
#      'abs': 0.09145787715232327}}},
#   1024: {'flat': {'rmse': 15.861116127627678,
#     'max': 48.70867399652889,
#     'min': -59.311219448014526,
#     'abs': -0.5941316277335267},
#    'hh': {2: {'rmse': 30.602252890490828,
#      'max': 136.40773022106805,
#      'min': -119.57817422149128,
#      'abs': 0.3222106036741574},
#     3: {'rmse': 24.958961417258706,
#      'max': 124.91404062838228,
#      'min': -98.06355551981869,
#      'abs': -0.8158653934795155},
#     4: {'rmse': 22.60340632960384,
#      'max': 93.48408012139498,
#      'min': -88.84970286808675,
#      'abs': 0.13892716083893028}}},
#   2048: {'flat': {'rmse': 18.62148620006505,
#     'max': 62.88696552542751,
#     'min': -72.73959888812897,
#     'abs': -0.30520994322926437},
#    'hh': {2: {'rmse': 33.42227818798359,
#      'max': 117.88366348003728,
#      'min': -127.35709289930128,
#      'abs': -0.9971161268334529},
#     3: {'rmse': 27.63720542654646,
#      'max': 130.44366784820522,
#      'min': -130.8066062314665,
#      'abs': 0.17938909462650054},
#     4: {'rmse': 26.81709735635632,
#      'max': 96.59200951829916,
#      'min': -109.20193802953509,
#      'abs': -0.10739301974384298}}}},
#  0.4: {32: {'flat': {'rmse': 8.477663664933099,
#     'max': 29.934985003460497,
#     'min': -29.94824859273365,
#     'abs': -1.1550042134104646},
#    'hh': {2: {'rmse': 22.450387218343636,
#      'max': 86.28764659795343,
#      'min': -127.9070140026331,
#      'abs': -0.33141682856444116},
#     3: {'rmse': 19.922739460497294,
#      'max': 72.97082167193298,
#      'min': -68.7222112018103,
#      'abs': -2.38003949744952},
#     4: {'rmse': 18.37077176402858,
#      'max': 61.70938837740505,
#      'min': -70.98438868625271,
#      'abs': 0.4871574891408023}}},
#   128: {'flat': {'rmse': 10.682881586689033,
#     'max': 39.823775069885414,
#     'min': -44.738178942958484,
#     'abs': 0.022055908021547884},
#    'hh': {2: {'rmse': 28.190988318608163,
#      'max': 109.63848271146435,
#      'min': -96.7396205213181,
#      'abs': -1.645191775545536},
#     3: {'rmse': 25.15215757100364,
#      'max': 111.690830818118,
#      'min': -137.12748785552594,
#      'abs': 1.343388017536083},
#     4: {'rmse': 22.484965660339277,
#      'max': 124.23857157412749,
#      'min': -86.7085985105507,
#      'abs': 0.9217995992303384}}},
#   256: {'flat': {'rmse': 17.024460427780642,
#     'max': 53.69273005823925,
#     'min': -55.1643578425992,
#     'abs': 0.7231506386584852},
#    'hh': {2: {'rmse': 37.16270047148677,
#      'max': 144.19026831478732,
#      'min': -126.13209627482456,
#      'abs': -2.4936280198349223},
#     3: {'rmse': 33.609051787173605,
#      'max': 208.15520209326223,
#      'min': -140.6486867448284,
#      'abs': -2.4924943653619143},
#     4: {'rmse': 27.0894501515129,
#      'max': 97.21723769046002,
#      'min': -128.72937708501559,
#      'abs': -0.7802471019491717}}},
#   512: {'flat': {'rmse': 21.066991607637664,
#     'max': 63.20127628810769,
#     'min': -85.21244236077655,
#     'abs': -0.6451163246166827},
#    'hh': {2: {'rmse': 41.36873254763475,
#      'max': 164.7356886588932,
#      'min': -170.3955924736556,
#      'abs': -1.6454803248037424},
#     3: {'rmse': 33.949116548824264,
#      'max': 121.00246018063353,
#      'min': -117.06450932213738,
#      'abs': -1.6579216206408138},
#     4: {'rmse': 31.16232228469305,
#      'max': 105.1766369742827,
#      'min': -131.16216458383315,
#      'abs': -2.1417308360701974}}},
#   1024: {'flat': {'rmse': 23.968952477185855,
#     'max': 86.91892310633011,
#     'min': -84.33038589484386,
#     'abs': -0.2511512407272297},
#    'hh': {2: {'rmse': 45.47110299309424,
#      'max': 184.37472075222468,
#      'min': -226.28613494715682,
#      'abs': -0.4995361254082618},
#     3: {'rmse': 39.484262162246154,
#      'max': 156.5695612165273,
#      'min': -145.88852699980453,
#      'abs': -2.273344313098342},
#     4: {'rmse': 33.921207731670115,
#      'max': 135.1139158104197,
#      'min': -135.61315551468215,
#      'abs': -0.6850997334994535}}},
#   2048: {'flat': {'rmse': 28.564535631390562,
#     'max': 113.4076687373672,
#     'min': -101.95638121959928,
#     'abs': 0.9784208301095078},
#    'hh': {2: {'rmse': 49.589333457904864,
#      'max': 159.05083034185554,
#      'min': -195.42970008303564,
#      'abs': -0.9776371146469304},
#     3: {'rmse': 40.70042184085182,
#      'max': 218.4342540780599,
#      'min': -165.44133718438025,
#      'abs': -0.08391056531443364},
#     4: {'rmse': 39.31716747002935,
#      'max': 159.81214934006857,
#      'min': -215.34325285314844,
#      'abs': 0.04104434800690897}}}},
#  0.2: {32: {'flat': {'rmse': 18.922287497682408,
#     'max': 111.30110147462824,
#     'min': -61.803472366194455,
#     'abs': -0.8187154156942432},
#    'hh': {2: {'rmse': 46.824347082058026,
#      'max': 274.04932903765416,
#      'min': -139.16239887114148,
#      'abs': 1.018490206291764},
#     3: {'rmse': 44.10143309962004,
#      'max': 118.11744111320036,
#      'min': -165.66467596953316,
#      'abs': -0.6981824456257946},
#     4: {'rmse': 34.49228353658308,
#      'max': 186.94976738122932,
#      'min': -160.86957744626068,
#      'abs': 2.4945968835351398}}},
#   128: {'flat': {'rmse': 21.593340676720576,
#     'max': 84.45574803985619,
#     'min': -76.49167572190368,
#     'abs': 0.29500876142776017},
#    'hh': {2: {'rmse': 60.69939434243358,
#      'max': 307.4062248226546,
#      'min': -269.23121270654246,
#      'abs': -1.8461153121600313},
#     3: {'rmse': 51.31178796172929,
#      'max': 228.12753189977457,
#      'min': -232.5810998057284,
#      'abs': -2.9296025344243843},
#     4: {'rmse': 47.51628164179754,
#      'max': 167.48389962761667,
#      'min': -200.38735788661643,
#      'abs': -1.9592403476944922}}},
#   256: {'flat': {'rmse': 36.845762475576336,
#     'max': 162.52533869767285,
#     'min': -117.73515275905902,
#     'abs': -0.6111870359264402},
#    'hh': {2: {'rmse': 70.70562912990742,
#      'max': 250.89804495840872,
#      'min': -291.17503941698897,
#      'abs': -1.382265129880888},
#     3: {'rmse': 71.35813398374441,
#      'max': 267.2188043877868,
#      'min': -338.1575907998408,
#      'abs': 1.5133179424266372},
#     4: {'rmse': 55.32909533700434,
#      'max': 262.6502190467345,
#      'min': -220.5020290716093,
#      'abs': -1.084871294853854}}},
#   512: {'flat': {'rmse': 41.63524703953396,
#     'max': 131.75309768559418,
#     'min': -170.52575024077942,
#     'abs': 0.11620099804054516},
#    'hh': {2: {'rmse': 86.30912205079241,
#      'max': 448.433256520796,
#      'min': -292.86117829488103,
#      'abs': -3.6792619161597635},
#     3: {'rmse': 71.22885087188412,
#      'max': 313.4731313944012,
#      'min': -257.4068864191577,
#      'abs': 1.7201827839562058},
#     4: {'rmse': 65.57389170650784,
#      'max': 228.23762714679106,
#      'min': -287.85545531268235,
#      'abs': 0.971730787377273}}},
#   1024: {'flat': {'rmse': 47.088716783061564,
#     'max': 194.14720267449047,
#     'min': -179.89389017462236,
#     'abs': -0.5783732305189231},
#    'hh': {2: {'rmse': 94.56127855457613,
#      'max': 392.4947393305847,
#      'min': -391.8555286300725,
#      'abs': 1.4757915166055073},
#     3: {'rmse': 81.13225499664838,
#      'max': 424.4952658266411,
#      'min': -310.7568917119006,
#      'abs': -1.1573655432795293},
#     4: {'rmse': 68.13641350477008,
#      'max': 299.5330825760975,
#      'min': -261.17988283662817,
#      'abs': 6.2078690197447886}}},
#   2048: {'flat': {'rmse': 57.83204617269362,
#     'max': 172.92456370731088,
#     'min': -201.4591017132916,
#     'abs': -1.7254974559672518},
#    'hh': {2: {'rmse': 98.29742487666313,
#      'max': 502.63012888832964,
#      'min': -313.92205400888287,
#      'abs': -1.4820107982808277},
#     3: {'rmse': 81.23860677356363,
#      'max': 325.3384851818482,
#      'min': -290.65414504122054,
#      'abs': 0.9474442211427413},
#     4: {'rmse': 80.66034650171262,
#      'max': 338.6578845483673,
#      'min': -401.241885291427,
#      'abs': -0.42334659030125843}}}}}

# %%
def flat_plots(epsilons, n, degrees, cen_error_dict, loc_error_dict, path):
    for N in n:
        cen_flat = []
        loc_flat = []
        
        for e in epsilons:


            #plt.hlines(np.mean(answears128),line_range[0],line_range[1])
            #plt.hlines(np.mean(correct_answear),line_range[0],line_range[1])

            #plt.savefig(plot_name,dpi=300,bbox_inches='tight')
            rmse = cen_error_dict[e][N]['flat']['rmse']
            cen_flat.append(rmse)
            
            rmse = loc_error_dict[e][N]['flat']['rmse']
            loc_flat.append(rmse)
            #plt.scatter(e, rmse, marker = '+', label=f"RMSE of flat esitmates with \u03B5 = {e}")

        plt.scatter(epsilons, cen_flat, marker = '+', label=f"RMSE of central")
        plt.scatter(epsilons, loc_flat, marker = '1', label=f"RMSE of local")

        #plt.yscale('log')

        plt.legend()
        plt.xlabel('Epsilons')
        plt.ylabel('RMSE of esitmates')
        plt.title(f'Local vs Central: Flat = {N}')
        plt_name = f'flat_N={N}'
        plt.savefig(owd + path + plt_name, bbox_inches='tight')
        plt.show()

path = '/plots/loc_vs_cen/flat/'
flat_plots(epsilons, n, degrees, cen_flat_error_dict, loc_flat_error_dict, path)

# %%
cen_hh_error_dict
# Out:
# {2.0: {32: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   128: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   256: {'flat': {2: {'rmse': 4.82065288956576,
#      'max': 16.665395765527137,
#      'min': -17.197702962475887,
#      'abs': -0.03307960028196139},
#     3: {'rmse': 9.605424228449289,
#      'max': 19.052149655857647,
#      'min': -28.632124668598408,
#      'abs': -0.22192147126585768},
#     4: {'rmse': 9.541878470981406,
#      'max': 21.81540628977382,
#      'min': -29.206055937444034,
#      'abs': -0.1355722060546017}},
#    'hh': {2: {'rmse': 8.951119036657905,
#      'max': 37.82017063243984,
#      'min': -35.97690266894824,
#      'abs': -0.04697081298857738},
#     3: {'rmse': 9.15678800707594,
#      'max': 27.272816347613116,
#      'min': -28.342473856340803,
#      'abs': 0.8047636002785846},
#     4: {'rmse': 7.082766941735129,
#      'max': 31.319013421867567,
#      'min': -20.582127696943644,
#      'abs': -0.5850140294202574}}},
#   512: {'flat': {2: {'rmse': 13.804155795355697,
#      'max': 54.62443262929446,
#      'min': -28.813779921998503,
#      'abs': 2.447890834805847},
#     3: {'rmse': 12.20314212433648,
#      'max': 46.33111285988707,
#      'min': -27.550380946922814,
#      'abs': 1.5701311697746219},
#     4: {'rmse': 12.322748425619842,
#      'max': 50.65729075710988,
#      'min': -27.840469556031167,
#      'abs': 1.3391922209058509}},
#    'hh': {2: {'rmse': 12.915015355533155,
#      'max': 33.789502984582214,
#      'min': -43.37827197667502,
#      'abs': -3.314251431552932},
#     3: {'rmse': 8.989131146995545,
#      'max': 42.03659457604226,
#      'min': -24.76391682602116,
#      'abs': 1.8903646151368185},
#     4: {'rmse': 9.44334578715405,
#      'max': 37.13009402645548,
#      'min': -32.32077401650895,
#      'abs': 1.7007300433930825}}},
#   1024: {'flat': {2: {'rmse': 14.01423475798044,
#      'max': 42.70538083855354,
#      'min': -34.381116494128946,
#      'abs': 2.295785708850849},
#     3: {'rmse': 14.57447166486251,
#      'max': 43.909854121739045,
#      'min': -30.88013133118511,
#      'abs': 2.1938879485694227},
#     4: {'rmse': 11.377837360606762,
#      'max': 37.90012195367308,
#      'min': -32.40332335390849,
#      'abs': 1.3451861106071854}},
#    'hh': {2: {'rmse': 12.494200266473513,
#      'max': 37.92468125920277,
#      'min': -49.484894031484146,
#      'abs': -0.13436961604356765},
#     3: {'rmse': 9.855397035809482,
#      'max': 37.28157951806497,
#      'min': -39.51457562424184,
#      'abs': 0.8657441715589317},
#     4: {'rmse': 8.649156551616946,
#      'max': 27.513962054552394,
#      'min': -36.668934138120676,
#      'abs': -0.8755092602428107}}},
#   2048: {'flat': {2: {'rmse': 15.938833164688383,
#      'max': 45.46667815328692,
#      'min': -51.75982858588395,
#      'abs': -0.5688942557456321},
#     3: {'rmse': 19.424142361971217,
#      'max': 57.58632681230665,
#      'min': -64.84214216368855,
#      'abs': -0.40144262083488286},
#     4: {'rmse': 13.168842625240094,
#      'max': 41.6541300205281,
#      'min': -47.03233754687244,
#      'abs': -0.5208903956135124}},
#    'hh': {2: {'rmse': 13.35848039383354,
#      'max': 52.89765342413739,
#      'min': -43.89263125535217,
#      'abs': -0.3591736057367059},
#     3: {'rmse': 9.985308862427337,
#      'max': 35.98072133192909,
#      'min': -36.14801865874324,
#      'abs': 0.5540854818782187},
#     4: {'rmse': 9.07753658733469,
#      'max': 29.94503823519335,
#      'min': -30.582022270638845,
#      'abs': 0.05259018359212205}}}},
#  1.4: {32: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   128: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   256: {'flat': {2: {'rmse': 6.634059671472293,
#      'max': 18.681996135690497,
#      'min': -22.094710100145676,
#      'abs': -0.694200154711627},
#     3: {'rmse': 15.293532984931348,
#      'max': 28.722109385562362,
#      'min': -39.27139532403817,
#      'abs': -2.9013283197593904},
#     4: {'rmse': 13.879800984404605,
#      'max': 34.54909433754801,
#      'min': -39.73992971770349,
#      'abs': -2.742666674531993}},
#    'hh': {2: {'rmse': 12.324260125482292,
#      'max': 52.45149144680727,
#      'min': -40.29156826984763,
#      'abs': 0.4762299574640765},
#     3: {'rmse': 12.431515089068595,
#      'max': 43.3940303207346,
#      'min': -42.45028732856008,
#      'abs': 0.8419267951457121},
#     4: {'rmse': 9.239786611029848,
#      'max': 32.96073254161456,
#      'min': -31.784394745140162,
#      'abs': 0.5503664397850166}}},
#   512: {'flat': {2: {'rmse': 21.50544009957563,
#      'max': 58.20135004472104,
#      'min': -54.982430390839,
#      'abs': -4.459818773574755},
#     3: {'rmse': 18.602416087144185,
#      'max': 54.84460663511709,
#      'min': -47.46679976697487,
#      'abs': -3.938652028722479},
#     4: {'rmse': 18.277328852614183,
#      'max': 53.90315107500646,
#      'min': -48.56636464083567,
#      'abs': -4.084754073672736}},
#    'hh': {2: {'rmse': 17.113947773861454,
#      'max': 53.08557789874612,
#      'min': -46.29816013909294,
#      'abs': -0.5109437262558088},
#     3: {'rmse': 13.984342827735876,
#      'max': 57.08861634132336,
#      'min': -45.365374314496876,
#      'abs': 2.809118285190771},
#     4: {'rmse': 12.006819348982765,
#      'max': 41.08129146405554,
#      'min': -33.240396904802765,
#      'abs': 2.730421869482292}}},
#   1024: {'flat': {2: {'rmse': 21.250772447656846,
#      'max': 83.05642309389077,
#      'min': -70.88581218633044,
#      'abs': 4.612306074523111},
#     3: {'rmse': 22.672800276908006,
#      'max': 83.07791331478802,
#      'min': -66.92536155937705,
#      'abs': 5.86407391264491},
#     4: {'rmse': 16.626315649942526,
#      'max': 64.10728477753582,
#      'min': -57.894469474565994,
#      'abs': 2.4642332605801696}},
#    'hh': {2: {'rmse': 17.650278025122944,
#      'max': 57.02607635948516,
#      'min': -73.37409608070448,
#      'abs': -1.1926448420202242},
#     3: {'rmse': 14.338107627036335,
#      'max': 51.14348875802534,
#      'min': -57.832629244730924,
#      'abs': -0.12020267907484085},
#     4: {'rmse': 11.778372916900606,
#      'max': 41.97386465486488,
#      'min': -48.562730354693485,
#      'abs': 1.1424731953187408}}},
#   2048: {'flat': {2: {'rmse': 23.74352074843637,
#      'max': 59.727530982519966,
#      'min': -72.57952067523729,
#      'abs': -2.9842809022433996},
#     3: {'rmse': 30.553288324693625,
#      'max': 70.97734885377577,
#      'min': -89.23857375010266,
#      'abs': -4.761175116133725},
#     4: {'rmse': 20.113777305020434,
#      'max': 51.044442138052545,
#      'min': -67.09833159238042,
#      'abs': -1.6742414165900992}},
#    'hh': {2: {'rmse': 18.227307198290642,
#      'max': 69.57131754804868,
#      'min': -62.82586032814288,
#      'abs': 1.1404651553630247},
#     3: {'rmse': 16.043990453193075,
#      'max': 64.36028901446844,
#      'min': -55.155686089914525,
#      'abs': 0.6559984131784178},
#     4: {'rmse': 13.420553561785686,
#      'max': 51.78499979697517,
#      'min': -62.44297413859749,
#      'abs': -0.9028982001687371}}}},
#  1.2: {32: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   128: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   256: {'flat': {2: {'rmse': 7.61801168912166,
#      'max': 26.55631974069729,
#      'min': -27.10671819406525,
#      'abs': 0.2481333356590985},
#     3: {'rmse': 14.971929855427556,
#      'max': 40.46986735106475,
#      'min': -35.520357683744805,
#      'abs': 2.122922406130194},
#     4: {'rmse': 13.373513654258117,
#      'max': 36.744520838867174,
#      'min': -33.68694618832524,
#      'abs': 1.656849044438466}},
#    'hh': {2: {'rmse': 13.82215757031543,
#      'max': 53.99806826081385,
#      'min': -58.89557462564153,
#      'abs': -0.0871848836698111},
#     3: {'rmse': 13.072691898355986,
#      'max': 54.13636985393532,
#      'min': -32.91158087669464,
#      'abs': 0.6608777884719195},
#     4: {'rmse': 12.594723392976443,
#      'max': 34.1377906364869,
#      'min': -45.15123356249387,
#      'abs': 0.9298459658035164}}},
#   512: {'flat': {2: {'rmse': 23.35284262247031,
#      'max': 69.63008646704839,
#      'min': -68.49607878045936,
#      'abs': -2.493916417161911},
#     3: {'rmse': 20.35080701085209,
#      'max': 63.17709767575434,
#      'min': -56.65923641162226,
#      'abs': -1.4889920150700084},
#     4: {'rmse': 20.4705006393349,
#      'max': 64.859581752753,
#      'min': -58.5520849727327,
#      'abs': -1.6809376437846921}},
#    'hh': {2: {'rmse': 19.064610602127104,
#      'max': 68.76734070376551,
#      'min': -62.668367830861825,
#      'abs': -0.24873396656184923},
#     3: {'rmse': 15.787402999575987,
#      'max': 41.3172177606757,
#      'min': -78.33741251337051,
#      'abs': -2.617251753429664},
#     4: {'rmse': 14.16130878106736,
#      'max': 42.16262117972656,
#      'min': -51.081686503275705,
#      'abs': -0.2554754431019683}}},
#   1024: {'flat': {2: {'rmse': 24.82458798328787,
#      'max': 68.0470422472572,
#      'min': -81.99724006603356,
#      'abs': -2.4346189217401495},
#     3: {'rmse': 25.263810529714,
#      'max': 65.0921722043422,
#      'min': -72.83659296021506,
#      'abs': -2.7681168627760315},
#     4: {'rmse': 20.78548675331994,
#      'max': 52.39247251948109,
#      'min': -62.648177168215625,
#      'abs': -1.2589001127252908}},
#    'hh': {2: {'rmse': 19.460209113609544,
#      'max': 75.64938511322543,
#      'min': -63.754105397863896,
#      'abs': 0.4418786407434498},
#     3: {'rmse': 15.113551564786713,
#      'max': 62.585481767586316,
#      'min': -59.87192438452621,
#      'abs': 1.5111045768301004},
#     4: {'rmse': 14.980101535862113,
#      'max': 48.55161482456606,
#      'min': -52.546850519182044,
#      'abs': -1.3824717042364443}}},
#   2048: {'flat': {2: {'rmse': 24.580380998839864,
#      'max': 77.22251490823692,
#      'min': -64.86738092760788,
#      'abs': 1.7285412046584476},
#     3: {'rmse': 29.29302947400159,
#      'max': 86.64804437954444,
#      'min': -94.65315125862253,
#      'abs': 1.667295838887256},
#     4: {'rmse': 20.905784498459926,
#      'max': 67.04539903381374,
#      'min': -69.9880599604221,
#      'abs': 1.432178337656494}},
#    'hh': {2: {'rmse': 20.477667577965697,
#      'max': 56.22983094396477,
#      'min': -84.76197920639243,
#      'abs': 1.023544639948639},
#     3: {'rmse': 17.056373062885132,
#      'max': 52.85212196482462,
#      'min': -66.61847786096041,
#      'abs': -0.14654157178975874},
#     4: {'rmse': 15.748290851077305,
#      'max': 79.11497522395803,
#      'min': -60.31685954137356,
#      'abs': -0.3912826020315726}}}},
#  1.0: {32: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   128: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   256: {'flat': {2: {'rmse': 9.241538872060337,
#      'max': 34.326079301965365,
#      'min': -30.67207863787553,
#      'abs': -0.010781709787421278},
#     3: {'rmse': 22.25671698096483,
#      'max': 53.96817797108088,
#      'min': -63.45817783743405,
#      'abs': -0.11406825990230428},
#     4: {'rmse': 21.225621957953,
#      'max': 57.249016227113316,
#      'min': -62.11515341127233,
#      'abs': -0.5360012437016878}},
#    'hh': {2: {'rmse': 15.795484373100468,
#      'max': 86.84072397031923,
#      'min': -69.42275179639819,
#      'abs': 1.800496310489704},
#     3: {'rmse': 17.97141359904794,
#      'max': 68.91224288405647,
#      'min': -38.906463860817894,
#      'abs': 5.043036156919052},
#     4: {'rmse': 14.596739849326582,
#      'max': 51.9179821815851,
#      'min': -48.99674534986116,
#      'abs': -1.2611330716833327}}},
#   512: {'flat': {2: {'rmse': 24.879875366039347,
#      'max': 66.58498969905486,
#      'min': -62.80752573507198,
#      'abs': 2.5394381738573606},
#     3: {'rmse': 21.609060147768894,
#      'max': 52.41009924739774,
#      'min': -71.10485522189992,
#      'abs': 2.2553501668705196},
#     4: {'rmse': 21.36626726514172,
#      'max': 55.214328114561795,
#      'min': -71.10485522189992,
#      'abs': 1.8464795010422268}},
#    'hh': {2: {'rmse': 21.84504938110855,
#      'max': 75.58850292694115,
#      'min': -79.09487243970216,
#      'abs': -2.2914531032750673},
#     3: {'rmse': 17.819752337719244,
#      'max': 63.04553294138168,
#      'min': -54.151455461345904,
#      'abs': 1.7782508659615879},
#     4: {'rmse': 18.671255249291764,
#      'max': 71.24434717063559,
#      'min': -66.56483110482804,
#      'abs': -0.07566599693913886}}},
#   1024: {'flat': {2: {'rmse': 34.949566524154726,
#      'max': 122.89573841051606,
#      'min': -75.84713632777857,
#      'abs': 5.902121147548995},
#     3: {'rmse': 37.22530524746665,
#      'max': 125.2475122193282,
#      'min': -74.89315380470362,
#      'abs': 6.92124920548285},
#     4: {'rmse': 27.41570416123196,
#      'max': 96.59948145609815,
#      'min': -70.90318762880634,
#      'abs': 4.461998164694844}},
#    'hh': {2: {'rmse': 23.84417959132859,
#      'max': 103.04829387336213,
#      'min': -121.95066069881432,
#      'abs': -1.8237784437840514},
#     3: {'rmse': 18.9339412535114,
#      'max': 76.24608762646676,
#      'min': -62.48595211155771,
#      'abs': -0.8318621638137381},
#     4: {'rmse': 17.722117662922,
#      'max': 60.21607381806825,
#      'min': -65.65055319456587,
#      'abs': -0.2707382002341561}}},
#   2048: {'flat': {2: {'rmse': 32.26419105178323,
#      'max': 118.25899248567293,
#      'min': -93.26119377446594,
#      'abs': 0.061640560102817835},
#     3: {'rmse': 42.610271110344264,
#      'max': 154.80245482583996,
#      'min': -116.4046984789311,
#      'abs': -0.9669483899950865},
#     4: {'rmse': 26.619089986267852,
#      'max': 90.45477216586005,
#      'min': -83.15031452098629,
#      'abs': -0.5927050469575246}},
#    'hh': {2: {'rmse': 25.050035079340667,
#      'max': 88.8675874727196,
#      'min': -91.43008687043039,
#      'abs': 1.5127326070923242},
#     3: {'rmse': 22.52538320897494,
#      'max': 70.98366735453601,
#      'min': -87.21191002236446,
#      'abs': -1.9533232143523753},
#     4: {'rmse': 19.703855314716574,
#      'max': 59.568198421635316,
#      'min': -81.25083168323908,
#      'abs': -2.226610738036045}}}},
#  0.8: {32: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   128: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   256: {'flat': {2: {'rmse': 11.525469317719814,
#      'max': 35.357715194200864,
#      'min': -40.22815648555934,
#      'abs': -0.2579027122856951},
#     3: {'rmse': 28.46014875766976,
#      'max': 68.46781892211584,
#      'min': -72.19834598868329,
#      'abs': 1.1526074483254256},
#     4: {'rmse': 25.12711929751974,
#      'max': 56.031821476375626,
#      'min': -65.82798389767413,
#      'abs': 0.24082518651894935}},
#    'hh': {2: {'rmse': 20.81026092528639,
#      'max': 65.63965242465565,
#      'min': -67.30452740780493,
#      'abs': -0.46003373776875994},
#     3: {'rmse': 18.87150708977978,
#      'max': 65.37889012032974,
#      'min': -60.95890412419976,
#      'abs': -1.7239116493984912},
#     4: {'rmse': 17.176883886298953,
#      'max': 82.03966735584254,
#      'min': -51.82501227942703,
#      'abs': -0.3232144236048276}}},
#   512: {'flat': {2: {'rmse': 31.29156324027412,
#      'max': 95.42736035003327,
#      'min': -86.81083358221804,
#      'abs': -5.417258486329246},
#     3: {'rmse': 28.018602172719596,
#      'max': 84.77634054415103,
#      'min': -84.45378595829243,
#      'abs': -4.29233173640366},
#     4: {'rmse': 28.088594414798777,
#      'max': 87.11268190483679,
#      'min': -83.49006341323548,
#      'abs': -3.881337013793414}},
#    'hh': {2: {'rmse': 28.750372657244448,
#      'max': 88.05175285151927,
#      'min': -92.73832706114626,
#      'abs': -0.9770507681428978},
#     3: {'rmse': 21.84176250111637,
#      'max': 77.40818075145944,
#      'min': -69.26695503707742,
#      'abs': 2.9708427439761262},
#     4: {'rmse': 22.64452720659567,
#      'max': 87.37236566105275,
#      'min': -66.31451679234306,
#      'abs': 1.8317029123126645}}},
#   1024: {'flat': {2: {'rmse': 35.27527800403646,
#      'max': 139.76338884001598,
#      'min': -122.56213774104253,
#      'abs': -0.20385210975070367},
#     3: {'rmse': 37.70672762259517,
#      'max': 144.2803319732775,
#      'min': -124.40186277567409,
#      'abs': -0.0007995767568820156},
#     4: {'rmse': 29.369859584463256,
#      'max': 108.88420709883212,
#      'min': -88.46185160438472,
#      'abs': -0.2590291145461466}},
#    'hh': {2: {'rmse': 30.442265620844758,
#      'max': 106.7392378851655,
#      'min': -122.99554004291713,
#      'abs': 1.9432222035893938},
#     3: {'rmse': 23.42295165511663,
#      'max': 74.54005280038109,
#      'min': -84.82901709871658,
#      'abs': -0.7479514081280446},
#     4: {'rmse': 20.473536124013492,
#      'max': 96.53723433397681,
#      'min': -93.52913883305155,
#      'abs': 0.6230858300459746}}},
#   2048: {'flat': {2: {'rmse': 38.498100271846525,
#      'max': 145.81132005630934,
#      'min': -121.38147422700422,
#      'abs': 4.733920982677245},
#     3: {'rmse': 46.192973841861026,
#      'max': 164.8831114124041,
#      'min': -167.25863730206038,
#      'abs': 6.82850793483227},
#     4: {'rmse': 31.602989336272124,
#      'max': 123.82576075127872,
#      'min': -98.40393124258844,
#      'abs': 3.244248117167334}},
#    'hh': {2: {'rmse': 32.57593099974789,
#      'max': 141.95953985693632,
#      'min': -166.2207522103272,
#      'abs': -1.0135909621378407},
#     3: {'rmse': 27.42993119430731,
#      'max': 127.65367364152917,
#      'min': -78.152200602839,
#      'abs': 2.685825740453601},
#     4: {'rmse': 23.213942540647594,
#      'max': 102.21769212307117,
#      'min': -86.64690889917256,
#      'abs': 1.4633332698042125}}}},
#  0.6: {32: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   128: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   256: {'flat': {2: {'rmse': 15.33781704916544,
#      'max': 64.11175633631683,
#      'min': -44.52322927358,
#      'abs': -1.2318032312333658},
#     3: {'rmse': 34.66688283801703,
#      'max': 92.02374988320662,
#      'min': -110.01021529349964,
#      'abs': -6.742096989559723},
#     4: {'rmse': 32.934300157085964,
#      'max': 94.55047156175715,
#      'min': -97.5550437822094,
#      'abs': -5.009044998623323}},
#    'hh': {2: {'rmse': 25.771644734059755,
#      'max': 90.49519852120102,
#      'min': -117.04468526250821,
#      'abs': -0.3858921397894643},
#     3: {'rmse': 25.782255100752902,
#      'max': 63.56293755507795,
#      'min': -97.15534664203005,
#      'abs': 2.954340738314687},
#     4: {'rmse': 20.248261641441708,
#      'max': 77.42571128422423,
#      'min': -61.85122851782944,
#      'abs': 0.2361659486095159}}},
#   512: {'flat': {2: {'rmse': 45.30506440097401,
#      'max': 104.92914089467376,
#      'min': -156.4654287444573,
#      'abs': 4.105170885165955},
#     3: {'rmse': 38.439060564046606,
#      'max': 103.21600477297034,
#      'min': -146.95959735606448,
#      'abs': 1.610597532731673},
#     4: {'rmse': 37.96553093055496,
#      'max': 109.15382947507896,
#      'min': -142.31243790732697,
#      'abs': 2.0701031183593295}},
#    'hh': {2: {'rmse': 38.32678707464223,
#      'max': 124.94081745922449,
#      'min': -134.17600708919053,
#      'abs': -3.7898385934453747},
#     3: {'rmse': 28.480533682356132,
#      'max': 113.71642676733609,
#      'min': -123.81709097281419,
#      'abs': -0.24243872705309186},
#     4: {'rmse': 30.724039880358344,
#      'max': 114.67017773055704,
#      'min': -92.52119840623345,
#      'abs': 1.6782512123116118}}},
#   1024: {'flat': {2: {'rmse': 52.23127377665363,
#      'max': 134.30573691886093,
#      'min': -178.34042978478828,
#      'abs': -9.266397555782524},
#     3: {'rmse': 56.105104426669755,
#      'max': 164.214860185195,
#      'min': -191.1262455971737,
#      'abs': -11.177677053438767},
#     4: {'rmse': 42.24710235196345,
#      'max': 142.02765832272416,
#      'min': -154.02046468641493,
#      'abs': -7.084911918971539}},
#    'hh': {2: {'rmse': 38.85813429743642,
#      'max': 142.31250588526018,
#      'min': -151.97467886688537,
#      'abs': 0.751986619106715},
#     3: {'rmse': 32.06437202284849,
#      'max': 126.09253089994309,
#      'min': -121.32780624058796,
#      'abs': -1.7521556648088967},
#     4: {'rmse': 26.588083456182538,
#      'max': 104.08705000503687,
#      'min': -112.81939537730796,
#      'abs': 2.0821205550489976}}},
#   2048: {'flat': {2: {'rmse': 56.18468294624003,
#      'max': 170.21397409160272,
#      'min': -180.07710551032505,
#      'abs': 0.026238141915854066},
#     3: {'rmse': 67.01582059550671,
#      'max': 176.4169926570612,
#      'min': -216.44914522994077,
#      'abs': 0.5722458495924365},
#     4: {'rmse': 45.059573883164674,
#      'max': 152.4834024992888,
#      'min': -136.36070090220164,
#      'abs': -0.23529479789907637}},
#    'hh': {2: {'rmse': 43.32142339190836,
#      'max': 141.97977004095446,
#      'min': -169.8876828129287,
#      'abs': -6.1241931618759935},
#     3: {'rmse': 36.52404606561899,
#      'max': 164.7830084307352,
#      'min': -107.97465293481946,
#      'abs': 4.203916971404618},
#     4: {'rmse': 30.902676726186204,
#      'max': 125.24949651265342,
#      'min': -132.29793379102193,
#      'abs': -0.3930854616251367}}}},
#  0.4: {32: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   128: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   256: {'flat': {2: {'rmse': 23.327137553265676,
#      'max': 70.09376582496952,
#      'min': -64.29211032366038,
#      'abs': 0.039088392807416314},
#     3: {'rmse': 48.22309428909309,
#      'max': 173.85157830156095,
#      'min': -110.09695045841363,
#      'abs': 2.930140467701963},
#     4: {'rmse': 47.35655706142684,
#      'max': 175.24624920957285,
#      'min': -111.95012781764672,
#      'abs': 3.1268968569581834}},
#    'hh': {2: {'rmse': 40.35102677946489,
#      'max': 141.39603128875024,
#      'min': -144.73937006026154,
#      'abs': -5.624519638906446},
#     3: {'rmse': 40.048393594474504,
#      'max': 150.20562605027953,
#      'min': -103.68728243237274,
#      'abs': 1.479648784559383},
#     4: {'rmse': 38.749303439672055,
#      'max': 121.61461206387321,
#      'min': -140.46107259385462,
#      'abs': -3.497131610060789}}},
#   512: {'flat': {2: {'rmse': 70.40938210273663,
#      'max': 203.12479433507542,
#      'min': -186.70757263999258,
#      'abs': -10.992061275886412},
#     3: {'rmse': 61.721712909433286,
#      'max': 196.47843073675904,
#      'min': -181.574589642536,
#      'abs': -9.399838101028354},
#     4: {'rmse': 62.556293824161244,
#      'max': 204.1606534873281,
#      'min': -181.574589642536,
#      'abs': -9.627144255958457}},
#    'hh': {2: {'rmse': 62.49672755141521,
#      'max': 195.70259531935153,
#      'min': -221.74716392542177,
#      'abs': -7.9850790698520315},
#     3: {'rmse': 45.054798394793785,
#      'max': 165.52241163620783,
#      'min': -179.9590771876974,
#      'abs': 5.450077149516245},
#     4: {'rmse': 41.47172417504322,
#      'max': 160.21774003229802,
#      'min': -127.68846277562989,
#      'abs': -0.4499450961221999}}},
#   1024: {'flat': {2: {'rmse': 76.12067940279866,
#      'max': 218.84151290432783,
#      'min': -254.2211344607349,
#      'abs': -4.3217005836079885},
#     3: {'rmse': 78.79437022699128,
#      'max': 216.2585071384965,
#      'min': -270.4253443216585,
#      'abs': -2.6172784835000815},
#     4: {'rmse': 62.28873816925384,
#      'max': 249.33037384433555,
#      'min': -198.6315482538921,
#      'abs': -2.702606910516412}},
#    'hh': {2: {'rmse': 58.55593246916818,
#      'max': 238.34419756478746,
#      'min': -220.21729829300602,
#      'abs': -2.16123520299925},
#     3: {'rmse': 48.920113663047424,
#      'max': 197.8341001394001,
#      'min': -187.69647102463932,
#      'abs': -3.5249317878369415},
#     4: {'rmse': 39.669224761801956,
#      'max': 138.70621613130788,
#      'min': -143.41283343944087,
#      'abs': -1.4608576908887567}}},
#   2048: {'flat': {2: {'rmse': 75.46171575462057,
#      'max': 274.4241759731667,
#      'min': -237.3797104905534,
#      'abs': 0.6982012752809096},
#     3: {'rmse': 91.866200115792,
#      'max': 287.91016419333755,
#      'min': -271.77440880739596,
#      'abs': -1.5763551246158196},
#     4: {'rmse': 64.90607747555264,
#      'max': 200.00462006713497,
#      'min': -194.42248520444264,
#      'abs': 0.6798007946512982}},
#    'hh': {2: {'rmse': 59.96236132724164,
#      'max': 236.83854243486712,
#      'min': -240.59450088135782,
#      'abs': -4.713309593971143},
#     3: {'rmse': 52.80494603286135,
#      'max': 179.4021591822675,
#      'min': -185.94767249102006,
#      'abs': -2.0371889550118008},
#     4: {'rmse': 46.77627683949235,
#      'max': 191.62894279049942,
#      'min': -231.63720769790234,
#      'abs': -0.6581530288015638}}}},
#  0.2: {32: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   128: {'flat': {2: None, 3: None, 4: None},
#    'hh': {2: None, 3: None, 4: None}},
#   256: {'flat': {2: {'rmse': 49.369380288541834,
#      'max': 195.88625428540945,
#      'min': -165.84097409404603,
#      'abs': -1.1016307079992846},
#     3: {'rmse': 129.68074921309574,
#      'max': 349.82837749600003,
#      'min': -317.384649109008,
#      'abs': -8.392523662154746},
#     4: {'rmse': 117.69558722978073,
#      'max': 314.1063170529451,
#      'min': -318.43853542019497,
#      'abs': -6.101678988702208}},
#    'hh': {2: {'rmse': 75.95175537262213,
#      'max': 250.86388035139134,
#      'min': -321.7627939853937,
#      'abs': -2.6621441079306805},
#     3: {'rmse': 90.13230623160544,
#      'max': 217.78234061335388,
#      'min': -236.84218723382946,
#      'abs': 1.615103810829873},
#     4: {'rmse': 69.83810687252613,
#      'max': 242.73545665971324,
#      'min': -288.6671802314813,
#      'abs': -7.06472263459902}}},
#   512: {'flat': {2: {'rmse': 153.2969304454461,
#      'max': 471.6235572463338,
#      'min': -402.68885982080246,
#      'abs': 4.054438261682383},
#     3: {'rmse': 130.0888813131522,
#      'max': 397.0671154147567,
#      'min': -394.6930698352735,
#      'abs': -5.513191886402099},
#     4: {'rmse': 128.6654731674791,
#      'max': 404.64076897643827,
#      'min': -385.95535301652853,
#      'abs': -5.103071537145742}},
#    'hh': {2: {'rmse': 108.63660243485509,
#      'max': 365.26044083578745,
#      'min': -388.481501274975,
#      'abs': -13.391217822229867},
#     3: {'rmse': 97.10422629470699,
#      'max': 349.1690578893176,
#      'min': -295.20600131451647,
#      'abs': -0.4866068451435014},
#     4: {'rmse': 86.80997720921387,
#      'max': 260.37109492506715,
#      'min': -325.02287214636453,
#      'abs': 1.9530616644586087}}},
#   1024: {'flat': {2: {'rmse': 147.57055517129336,
#      'max': 442.10720442660386,
#      'min': -575.0137092974328,
#      'abs': 6.806873228296637},
#     3: {'rmse': 157.71802960000795,
#      'max': 485.94090067634534,
#      'min': -606.0934005436138,
#      'abs': 4.644772862326849},
#     4: {'rmse': 125.60361783357357,
#      'max': 345.4627082809893,
#      'min': -426.8359700005676,
#      'abs': 2.5608417499837697}},
#    'hh': {2: {'rmse': 120.89832057591975,
#      'max': 377.60658736506593,
#      'min': -449.8863526620553,
#      'abs': 0.7730057474592468},
#     3: {'rmse': 98.83578249040217,
#      'max': 453.2542030365148,
#      'min': -324.21033537894255,
#      'abs': -2.1313672548021714},
#     4: {'rmse': 84.34317803031017,
#      'max': 301.19091971209855,
#      'min': -298.58383399251034,
#      'abs': 14.816366389063097}}},
#   2048: {'flat': {2: {'rmse': 169.1522122723467,
#      'max': 463.8281525950297,
#      'min': -614.9265594076132,
#      'abs': -13.097825598208734},
#     3: {'rmse': 209.3070986381316,
#      'max': 491.1227540974505,
#      'min': -846.1857779771672,
#      'abs': -22.981295570642896},
#     4: {'rmse': 137.699831999334,
#      'max': 450.74825913243694,
#      'min': -498.11466529319296,
#      'abs': -6.578269392418061}},
#    'hh': {2: {'rmse': 127.1202577111324,
#      'max': 520.1351285831188,
#      'min': -575.5174514132959,
#      'abs': 2.9835845227231212},
#     3: {'rmse': 104.97457288433256,
#      'max': 418.65245410529315,
#      'min': -316.6934267406468,
#      'abs': 17.43515441323493},
#     4: {'rmse': 94.41464942740097,
#      'max': 492.5162969433004,
#      'min': -357.86004316213075,
#      'abs': 3.267138402197935}}}}}

# %%
def hh_plots(epsilons, n, degrees, cen_error_dict, loc_error_dict, path):
    for N in n:
        cen_hh_2 = []
        cen_hh_3 = []
        cen_hh_4 = []
        loc_hh_2 = []
        loc_hh_3 = []
        loc_hh_4 = []

        for e in epsilons:


            #plt.hlines(np.mean(answears128),line_range[0],line_range[1])
            #plt.hlines(np.mean(correct_answear),line_range[0],line_range[1])

            #plt.savefig(plot_name,dpi=300,bbox_inches='tight')
            #rmse = flat_error_dict[e][N]['flat']['rmse']
            #rmse_flat.append(rmse)
            #plt.scatter(e, rmse, marker = '+', label=f"RMSE of flat esitmates with \u03B5 = {e}")
            for idx, degree in enumerate(cen_error_dict[e][N]['hh']):
                #print(flat_error_dict[e][N]['hh'][degree]['rmse'])
                rmse = cen_error_dict[e][N]['hh'][degree]['rmse']
                if degree == 2:
                    cen_hh_2.append(rmse)
                if degree == 3:
                    cen_hh_3.append(rmse)
                if degree == 4:
                    cen_hh_4.append(rmse)
            for idx, degree in enumerate(loc_error_dict[e][N]['hh']):
                #print(flat_error_dict[e][N]['hh'][degree]['rmse'])
                rmse = loc_error_dict[e][N]['hh'][degree]['rmse']
                if degree == 2:
                    loc_hh_2.append(rmse)
                if degree == 3:
                    loc_hh_3.append(rmse)
                if degree == 4:
                    loc_hh_4.append(rmse)

                #plt.scatter(e, rmse, marker = 'o', label=f"RMSE of HH esitmates with degree = {degree} and \u03B5 = {e}")
        
        plt.scatter(epsilons, cen_hh_2, marker = '+', label=f"RMSE of central esitmates")
        plt.scatter(epsilons, loc_hh_2, marker = '+', label=f"RMSE of local esitmates")
        
        #plt.yscale('log')
        plt.legend()
        plt.xlabel('Epsilons')
        plt.ylabel('RMSE of esitmates')
        plt.title(f'Central: HH with N = {N} and B=2')
        plt_name = f'hh_beat_flat={N}_B=2'
        plt.savefig(owd + path + plt_name, bbox_inches='tight')
        plt.show()
        
        plt.scatter(epsilons, cen_hh_3, marker = '+', label=f"RMSE of central esitmates")
        plt.scatter(epsilons, loc_hh_3, marker = '+', label=f"RMSE of local esitmates")
        
        #plt.yscale('log')
        plt.legend()
        plt.xlabel('Epsilons')
        plt.ylabel('RMSE of esitmates')
        plt.title(f'Central: HH with N = {N} and B=3')
        plt_name = f'hh_beat_flat={N}_B=3'
        plt.savefig(owd + path + plt_name, bbox_inches='tight')
        plt.show()
        
        plt.scatter(epsilons, cen_hh_4, marker = '+', label=f"RMSE of central esitmates")
        plt.scatter(epsilons, loc_hh_4, marker = '+', label=f"RMSE of local esitmates")
        #plt.yscale('log')
        plt.legend()
        plt.xlabel('Epsilons')
        plt.ylabel('RMSE of esitmates')
        plt.title(f'Central: HH with N = {N} and B=4')
        plt_name = f'hh_beat_flat={N}_B=4'
        plt.savefig(owd + path + plt_name, bbox_inches='tight')
        plt.show()


path = '/plots/loc_vs_cen/hh/'
hh_plots(epsilons, n[2:], degrees, cen_hh_error_dict, loc_hh_error_dict, path)

# %%
def hh_better_plots(epsilons, n, degrees, hh_error_dict, path):
    for N in n:
        rmse_flat_2 = []
        rmse_flat_3 = []
        rmse_flat_4 = []
        rmse_degree2 = []
        rmse_degree3 = []
        rmse_degree4 = []

        for e in epsilons:


            #plt.hlines(np.mean(answears128),line_range[0],line_range[1])
            #plt.hlines(np.mean(correct_answear),line_range[0],line_range[1])

            #plt.savefig(plot_name,dpi=300,bbox_inches='tight')
            #rmse = flat_error_dict[e][N]['flat']['rmse']
            #rmse_flat.append(rmse)
            #plt.scatter(e, rmse, marker = '+', label=f"RMSE of flat esitmates with \u03B5 = {e}")
            for idx, degree in enumerate(hh_error_dict[e][N]['hh']):
                #print(flat_error_dict[e][N]['hh'][degree]['rmse'])
                rmse = hh_error_dict[e][N]['flat'][degree]['rmse']
                if degree == 2:
                    rmse_flat_2.append(rmse)
                if degree == 3:
                    rmse_flat_3.append(rmse)
                if degree == 4:
                    rmse_flat_4.append(rmse)
            for idx, degree in enumerate(hh_error_dict[e][N]['hh']):
                #print(flat_error_dict[e][N]['hh'][degree]['rmse'])
                rmse = hh_error_dict[e][N]['hh'][degree]['rmse']
                if degree == 2:
                    rmse_degree2.append(rmse)
                if degree == 3:
                    rmse_degree3.append(rmse)
                if degree == 4:
                    rmse_degree4.append(rmse)

                #plt.scatter(e, rmse, marker = 'o', label=f"RMSE of HH esitmates with degree = {degree} and \u03B5 = {e}")
        
        plt.scatter(epsilons, rmse_flat_2, marker = '+', label=f"RMSE of flat esitmates")
        plt.scatter(epsilons, rmse_degree2, marker = '+', label=f"RMSE of HH esitmates")
        
        #plt.yscale('log')
        plt.legend()
        plt.xlabel('Epsilons')
        plt.ylabel('RMSE of esitmates')
        plt.title(f'Central: Flat vs HH with N = {N} and B=2')
        plt_name = f'hh_beat_flat={N}_B=4'
        plt.savefig(owd + path + plt_name, bbox_inches='tight')
        plt.show()
        plt.scatter(epsilons, rmse_flat_3, marker = '+', label=f"RMSE of flat esitmates")
        plt.scatter(epsilons, rmse_degree3, marker = '+', label=f"RMSE of HH esitmates")
        
        #plt.yscale('log')
        plt.legend()
        plt.xlabel('Epsilons')
        plt.ylabel('RMSE of esitmates')
        plt.title(f'Central: Flat vs HH with N = {N} and B=3')
        plt_name = f'hh_beat_flat={N}_B=4'
        plt.savefig(owd + path + plt_name, bbox_inches='tight')
        plt.show()
        
        plt.scatter(epsilons, rmse_flat_4, marker = '+', label=f"RMSE of flat esitmates")
        plt.scatter(epsilons, rmse_degree4, marker = '+', label=f"RMSE of HH esitmates")
        #plt.yscale('log')
        plt.legend()
        plt.xlabel('Epsilons')
        plt.ylabel('RMSE of esitmates')
        plt.title(f'Central: Flat vs HH with N = {N} and B=4')
        plt_name = f'hh_beat_flat={N}_B=4'
        plt.savefig(owd + path + plt_name, bbox_inches='tight')
        plt.show()

        
path = '/plots/central/hh_beat_flat/'
hh_better_plots(epsilons, n[2:], degrees, hh_error_dict, path)

# %%
hh_error_dict
